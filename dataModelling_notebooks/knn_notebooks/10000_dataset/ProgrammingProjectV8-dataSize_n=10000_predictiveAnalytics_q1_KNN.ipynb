# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
# cd D:\Group-7

# %%
#retrieving data
parkingdata = pd.read_csv("parking_duration_of_parking_event_vs_street_ID.csv")
parkingdata = parkingdata.sample(n = 10000)
parkingdata.size
# Out:
# 130000

# %%
parkingdata.head(5)
# Out:
#                Area Name      Street Name Between Street 1  \
# 5608179      Queensberry    DUDLEY STREET      KING STREET
# 151998           Spencer   SPENCER STREET    BOURKE STREET
# 2002710          The Mac  SWANSTON STREET  FRANKLIN STREET
# 4391539  Victoria Market  FRANKLIN STREET     QUEEN STREET
# 5213472           Titles     QUEEN STREET  LA TROBE STREET
#
#            Between Street 2  Side Of Street Street Marker  \
# 5608179      WILLIAM STREET               4         7101S
# 151998    Lt COLLINS STREET               2         1536E
# 2002710     LA TROBE STREET               5         4621W
# 4391539    ELIZABETH STREET               1         C6644
# 5213472  Lt LONSDALE STREET               1         C1266
#
#                    Arrival Time          Departure Time  \
# 5608179  12/03/2012 07:10:30 PM  12/03/2012 07:11:54 PM
# 151998   05/10/2011 08:08:04 PM  05/10/2011 08:30:00 PM
# 2002710  25/11/2011 10:44:20 AM  25/11/2011 10:45:46 AM
# 4391539  05/02/2012 09:45:00 AM  05/02/2012 10:11:31 AM
# 5213472  29/02/2012 05:45:26 PM  29/02/2012 05:47:44 PM
#
#          Duration of Parking Event (in seconds)                       Sign  \
# 5608179                                      84  3P TKT A M-SAT 7:30-20:30
# 151998                                     1316      2P MTR M-F 18:00-2030
# 2002710                                      86      1P MTR M-F 9:30-16:00
# 4391539                                    1591          2P SUN 7:30-18:30
# 5213472                                     138    1P MTR M-SAT 7:30-19:30
#
#          In Violation?  Street ID  Device ID
# 5608179              0        614       2739
# 151998               0       1285        764
# 2002710              0       1329       3550
# 4391539              0        681       2899
# 5213472              0       1171        736

# %%
parkingdata.tail(5)
# Out:
#          Area Name      Street Name     Between Street 1  Between Street 2  \
# 8585511     Titles   WILLIAM STREET      FRANKLIN STREET  A'BECKETT STREET
# 6800601  Southbank     DODDS STREET  SOUTHBANK BOULEVARD      GRANT STREET
# 2510032      Banks     QUEEN STREET        FLINDERS LANE   FLINDERS STREET
# 898920      Titles  LA TROBE STREET         QUEEN STREET  ELIZABETH STREET
# 7592490    Spencer    BOURKE STREET       SPENCER STREET       KING STREET
#
#          Side Of Street Street Marker            Arrival Time  \
# 8585511               5         5345W  13/06/2012 05:42:05 PM
# 6800601               2         8338E  19/04/2012 10:01:37 AM
# 2510032               5          975W  09/12/2011 08:50:55 AM
# 898920                4         3833S  26/10/2011 10:42:47 AM
# 7592490               3         2486N  14/05/2012 06:00:55 PM
#
#                  Departure Time  Duration of Parking Event (in seconds)  \
# 8585511  13/06/2012 06:19:26 PM                                    2241
# 6800601  19/04/2012 10:02:59 AM                                      82
# 2510032  09/12/2011 08:52:42 AM                                     107
# 898920   26/10/2011 11:07:19 AM                                    1472
# 7592490  14/05/2012 07:30:00 PM                                    5345
#
#                               Sign  In Violation?  Street ID  Device ID
# 8585511  3P TKT A M-SAT 7:30-20:30              0       1428       5047
# 6800601    3P TKT A M-F 7:30-18:30              0        591       4623
# 2510032    1P MTR M-SAT 7:30-19:30              0       1171        693
# 898920       1P MTR M-F 9:30-19:30              0        856       2292
# 7592490  1/2P MTR M-SAT 7:30-19:30              1        123       1380

# %% [markdown]
# ## Data Wrangling

# %%
#checking the datatype of all the features
parkingdata.dtypes
# Out:
# Area Name                                 object
# Street Name                               object
# Between Street 1                          object
# Between Street 2                          object
# Side Of Street                             int64
# Street Marker                             object
# Arrival Time                              object
# Departure Time                            object
# Duration of Parking Event (in seconds)     int64
# Sign                                      object
# In Violation?                              int64
# Street ID                                  int64
# Device ID                                  int64
# dtype: object

# %%
#Checking values of Area Name feature for typos
parkingdata['Area Name'].value_counts()
# Out:
# Queensberry        1014
# Princes Theatre     756
# Victoria Market     730
# Regency             638
# Southbank           633
# The Mac             609
# Hyatt               597
# Titles              542
# Rialto              451
# County              444
# City Square         437
# Magistrates         396
# Hardware            392
# Courtney            388
# Spencer             377
# Chinatown           369
# Banks               349
# RACV                311
# Jolimont            288
# Supreme             185
# Tavistock            52
# Docklands            39
# West Melbourne        3
# Name: Area Name, dtype: int64

# %%
#Converting all the feature attributes to uppercase for uniformity

parkingdata['Area Name'] = parkingdata['Area Name'].str.upper()
parkingdata['Street Name'] = parkingdata['Street Name'].str.upper()
parkingdata['Between Street 1'] = parkingdata['Between Street 1'].str.upper()
parkingdata['Between Street 2'] = parkingdata['Between Street 2'].str.upper()
parkingdata['Street Marker'] = parkingdata['Street Marker'].str.upper()
parkingdata['Sign'] = parkingdata['Sign'].str.upper()

parkingdata.head(5)
# Out:
#                Area Name      Street Name Between Street 1  \
# 5608179      QUEENSBERRY    DUDLEY STREET      KING STREET
# 151998           SPENCER   SPENCER STREET    BOURKE STREET
# 2002710          THE MAC  SWANSTON STREET  FRANKLIN STREET
# 4391539  VICTORIA MARKET  FRANKLIN STREET     QUEEN STREET
# 5213472           TITLES     QUEEN STREET  LA TROBE STREET
#
#            Between Street 2  Side Of Street Street Marker  \
# 5608179      WILLIAM STREET               4         7101S
# 151998    LT COLLINS STREET               2         1536E
# 2002710     LA TROBE STREET               5         4621W
# 4391539    ELIZABETH STREET               1         C6644
# 5213472  LT LONSDALE STREET               1         C1266
#
#                    Arrival Time          Departure Time  \
# 5608179  12/03/2012 07:10:30 PM  12/03/2012 07:11:54 PM
# 151998   05/10/2011 08:08:04 PM  05/10/2011 08:30:00 PM
# 2002710  25/11/2011 10:44:20 AM  25/11/2011 10:45:46 AM
# 4391539  05/02/2012 09:45:00 AM  05/02/2012 10:11:31 AM
# 5213472  29/02/2012 05:45:26 PM  29/02/2012 05:47:44 PM
#
#          Duration of Parking Event (in seconds)                       Sign  \
# 5608179                                      84  3P TKT A M-SAT 7:30-20:30
# 151998                                     1316      2P MTR M-F 18:00-2030
# 2002710                                      86      1P MTR M-F 9:30-16:00
# 4391539                                    1591          2P SUN 7:30-18:30
# 5213472                                     138    1P MTR M-SAT 7:30-19:30
#
#          In Violation?  Street ID  Device ID
# 5608179              0        614       2739
# 151998               0       1285        764
# 2002710              0       1329       3550
# 4391539              0        681       2899
# 5213472              0       1171        736

# %%
sns.boxplot(parkingdata['Duration of Parking Event (in seconds)'])

# %%
#Removing all redundant extra whitespaces
for x in parkingdata.columns:
    if parkingdata[x].dtype == object:
        parkingdata[x] = parkingdata[x].str.strip()

# %%
#Checking values of Street Name feature for typos
pd.set_option('display.max_rows', 10000)
parkingdata['Street Name'].value_counts()
# Out:
# LONSDALE STREET             953
# QUEEN STREET                747
# LA TROBE STREET             591
# EXHIBITION STREET           586
# FRANKLIN STREET             546
# COLLINS STREET              516
# ELIZABETH STREET            477
# RUSSELL STREET              425
# BOURKE STREET               404
# LT LONSDALE STREET          343
# SPRING STREET               295
# LT COLLINS STREET           287
# KING STREET                 281
# FLINDERS LANE               278
# ERROL STREET                230
# WILLIAM STREET              196
# COVENTRY STREET             163
# LT BOURKE STREET            161
# VICTORIA STREET             159
# FLINDERS STREET             157
# A'BECKETT STREET            156
# SPENCER STREET              148
# QUEENSBERRY STREET          124
# CAPEL STREET                113
# ALBERT STREET               101
# THERRY STREET               101
# GRANT STREET                100
# KAVANAGH STREET              82
# O'CONNELL STREET             81
# COBDEN STREET                78
# DORCAS STREET                76
# SWANSTON STREET              72
# LEVESON STREET               72
# HOWARD STREET                49
# CHETWYND STREET              45
# ST ANDREWS PLACE             40
# SOUTHBANK BOULEVARD          39
# CLARENDON STREET             39
# DUDLEY STREET                36
# STURT STREET                 36
# FRANCIS STREET               35
# WALSH STREET                 33
# CURZON STREET                33
# ROSSLYN STREET               31
# DODDS STREET                 31
# PEEL STREET                  31
# LANSDOWNE STREET             29
# MARKET STREET                29
# WILLS STREET                 28
# CATHEDRAL PLACE              27
# WELLINGTON PARADE            24
# CITY ROAD                    24
# BALSTON STREET               21
# JEFFCOTT STREET              21
# MACKENZIE STREET             20
# CHURCH STREET                19
# LT LA TROBE STREET           19
# WELLS STREET                 19
# MILES STREET                 18
# PRINCESS STREET              15
# ST KILDA ROAD                15
# EADES PLACE                  15
# DRYBURGH STREET              14
# NICHOLSON STREET             14
# FAWKNER STREET                9
# BOND STREET                   9
# GISBORNE STREET               8
# RODEN STREET                  7
# PARLIAMENT PLACE              6
# ANTHONY STREET                4
# BATMAN STREET                 4
# LT DRYBURGH STREET SOUTH      3
# UNION STREET                  2
# Name: Street Name, dtype: int64

# %%
#Checking values of Between Street 1 feature for typos
parkingdata['Between Street 1'].value_counts()
# Out:
# KING STREET            927
# QUEEN STREET           822
# WILLIAM STREET         618
# QUEENSBERRY STREET     602
# RUSSELL STREET         561
# SWANSTON STREET        473
# SPENCER STREET         463
# EXHIBITION STREET      452
# LT LONSDALE STREET     444
# LONSDALE STREET        351
# LT COLLINS STREET      345
# VICTORIA STREET        309
# COLLINS STREET         300
# BOURKE STREET          296
# ELIZABETH STREET       261
# LT BOURKE STREET       258
# FLINDERS LANE          211
# LA TROBE STREET        153
# THERRY STREET          147
# WILLAM STREET          142
# FRANKLIN STREET        137
# WELLS STREET           123
# A'BECKETT STREET       122
# DODDS STREET           112
# ERROL STREET            92
# O'CONNELL STREET        91
# SOUTHBANK BOULEVARD     86
# STURT STREET            81
# FLINDERS STREET         79
# HOWARD STREET           77
# VICTORIA PARADE         76
# KINGS WAY               71
# BALSTON STREET          68
# PEEL STREET             61
# COBDEN STREET           52
# PELHAM STREET           52
# ALBERT STREET           48
# MACARTHUR STREET        40
# GISBORNE STREET         40
# NICHOLSON STREET        35
# LANSDOWNE STREET        31
# CITY ROAD               30
# CHETWYND STREET         27
# WALSH STREET            24
# COVENTRY STREET         23
# MORRISON PLACE          22
# SPRING STREET           19
# GREY STREET             18
# LOTHIAN STREET          14
# CAPEL STREET            13
# DORCAS STREET           11
# BATMAN STREET           10
# ST KILDA ROAD           10
# MOORE STREET             9
# ST ANDREWS PLACE         8
# GIPPS STREET             8
# JEFFCOTT STREET          7
# KAVANAGH STREET          7
# EADES STREET             6
# MILTON STREET            5
# JOLIMONT ROAD            5
# GEORGE STREET            4
# HOTHAM STREET            3
# LEVESON STREET           2
# GRANT STREET             2
# CATHEDRAL PLACE          1
# ABBOTSFORD STREET        1
# PROVOST STREET           1
# DRYBURGH STREET          1
# Name: Between Street 1, dtype: int64

# %%
#Checking values of Between Street 1 feature for typos
parkingdata['Between Street 2'].value_counts()
# Out:
# WILLIAM STREET         908
# ELIZABETH STREET       846
# VICTORIA STREET        779
# QUEEN STREET           749
# EXHIBITION STREET      545
# LONSDALE STREET        478
# KING STREET            463
# SPRING STREET          455
# RUSSELL STREET         407
# FLINDERS LANE          379
# LT BOURKE STREET       351
# COLLINS STREET         345
# LT COLLINS STREET      296
# SWANSTON STREET        261
# BOURKE STREET          258
# LA TROBE STREET        252
# FLINDERS STREET        211
# LT LONSDALE STREET     195
# FRANKLIN STREET        147
# DODDS STREET           124
# ST KILDA ROAD          123
# LANSDOWNE STREET       108
# LEVESON STREET          92
# POWER STREET            92
# QUEENSBERRY STREET      87
# WELLS STREET            85
# CAPEL STREET            69
# THERRY STREET           66
# A'BECKETT STREET        65
# WALSH STREET            58
# STURT STREET            49
# HAWKE STREET            49
# DUDLEY STREET           37
# MILES STREET            36
# GISBORNE STREET         35
# ELM STREET              34
# STANLEY STREET          32
# EADES STREET            31
# GRANT STREET            29
# CATHEDRAL PLACE         28
# MILTON STREET           28
# KAVANAGH STREET         28
# HOWARD STREET           27
# SPENCER STREET          25
# DORCAS STREET           19
# GIPPS STREET            18
# O'CONNELL STREET        17
# COBDEN STREET           15
# FAWKNER STREET          14
# PEEL STREET             13
# WELLINGTON PARADE       12
# CLARENDON STREET        11
# ABBOTSFORD STREET       11
# ROSSLYN STREET          11
# COVENTRY STREET         11
# JEFFCOTT STREET         10
# FANNING STREET           9
# RODEN STREET             8
# HOTHAM STREET            8
# MOORE STREET             8
# MORRISON PLACE           7
# EADES PLACE              7
# ST ANDREWS PLACE         7
# GREY STREET              6
# LOTHIAN STREET           4
# WADEY STREET             4
# GEORGE STREET            3
# CHETWYND STREET          2
# SOUTHBANK BOULEVARD      2
# CURZON STREET            1
# Name: Between Street 2, dtype: int64

# %%
#check which columns have missing values
parkingdata.columns[parkingdata.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#converting object to datetime
parkingdata['Arrival Time'] = pd.to_datetime(parkingdata['Arrival Time'])
parkingdata['Departure Time'] = pd.to_datetime(parkingdata['Departure Time'])

# %%
#check if object has successfully been converted to datetime
parkingdata.dtypes
# Out:
# Area Name                                         object
# Street Name                                       object
# Between Street 1                                  object
# Between Street 2                                  object
# Side Of Street                                     int64
# Street Marker                                     object
# Arrival Time                              datetime64[ns]
# Departure Time                            datetime64[ns]
# Duration of Parking Event (in seconds)             int64
# Sign                                              object
# In Violation?                                      int64
# Street ID                                          int64
# Device ID                                          int64
# dtype: object

# %%
parkingdata.head(5)
# Out:
#                Area Name      Street Name Between Street 1  \
# 5608179      QUEENSBERRY    DUDLEY STREET      KING STREET
# 151998           SPENCER   SPENCER STREET    BOURKE STREET
# 2002710          THE MAC  SWANSTON STREET  FRANKLIN STREET
# 4391539  VICTORIA MARKET  FRANKLIN STREET     QUEEN STREET
# 5213472           TITLES     QUEEN STREET  LA TROBE STREET
#
#            Between Street 2  Side Of Street Street Marker        Arrival Time  \
# 5608179      WILLIAM STREET               4         7101S 2012-12-03 19:10:30
# 151998    LT COLLINS STREET               2         1536E 2011-05-10 20:08:04
# 2002710     LA TROBE STREET               5         4621W 2011-11-25 10:44:20
# 4391539    ELIZABETH STREET               1         C6644 2012-05-02 09:45:00
# 5213472  LT LONSDALE STREET               1         C1266 2012-02-29 17:45:26
#
#              Departure Time  Duration of Parking Event (in seconds)  \
# 5608179 2012-12-03 19:11:54                                      84
# 151998  2011-05-10 20:30:00                                    1316
# 2002710 2011-11-25 10:45:46                                      86
# 4391539 2012-05-02 10:11:31                                    1591
# 5213472 2012-02-29 17:47:44                                     138
#
#                               Sign  In Violation?  Street ID  Device ID
# 5608179  3P TKT A M-SAT 7:30-20:30              0        614       2739
# 151998       2P MTR M-F 18:00-2030              0       1285        764
# 2002710      1P MTR M-F 9:30-16:00              0       1329       3550
# 4391539          2P SUN 7:30-18:30              0        681       2899
# 5213472    1P MTR M-SAT 7:30-19:30              0       1171        736

# %%
parkingdata.tail(5)
# Out:
#          Area Name      Street Name     Between Street 1  Between Street 2  \
# 8585511     TITLES   WILLIAM STREET      FRANKLIN STREET  A'BECKETT STREET
# 6800601  SOUTHBANK     DODDS STREET  SOUTHBANK BOULEVARD      GRANT STREET
# 2510032      BANKS     QUEEN STREET        FLINDERS LANE   FLINDERS STREET
# 898920      TITLES  LA TROBE STREET         QUEEN STREET  ELIZABETH STREET
# 7592490    SPENCER    BOURKE STREET       SPENCER STREET       KING STREET
#
#          Side Of Street Street Marker        Arrival Time      Departure Time  \
# 8585511               5         5345W 2012-06-13 17:42:05 2012-06-13 18:19:26
# 6800601               2         8338E 2012-04-19 10:01:37 2012-04-19 10:02:59
# 2510032               5          975W 2011-09-12 08:50:55 2011-09-12 08:52:42
# 898920                4         3833S 2011-10-26 10:42:47 2011-10-26 11:07:19
# 7592490               3         2486N 2012-05-14 18:00:55 2012-05-14 19:30:00
#
#          Duration of Parking Event (in seconds)                       Sign  \
# 8585511                                    2241  3P TKT A M-SAT 7:30-20:30
# 6800601                                      82    3P TKT A M-F 7:30-18:30
# 2510032                                     107    1P MTR M-SAT 7:30-19:30
# 898920                                     1472      1P MTR M-F 9:30-19:30
# 7592490                                    5345  1/2P MTR M-SAT 7:30-19:30
#
#          In Violation?  Street ID  Device ID
# 8585511              0       1428       5047
# 6800601              0        591       4623
# 2510032              0       1171        693
# 898920               0        856       2292
# 7592490              1        123       1380

# %% [markdown]
# ### KNN Classification Model on Predicitive Analytics question 1

# %%
#Target field identification
target = parkingdata['In Violation?']
target.head(10)
# Out:
# 5608179     0
# 151998      0
# 2002710     0
# 4391539     0
# 5213472     0
# 7606655     0
# 9944558     0
# 3183941     0
# 10596686    0
# 10738362    0
# Name: In Violation?, dtype: int64

# %%
#Preliminary Target Features identification (Pre-Hill Climbing)

#Convert possible targets to dtype = int
intDf = parkingdata.copy()
#Drop useless fields
intDf.drop('Arrival Time', axis = 1, inplace = True)
intDf.drop('Departure Time', axis = 1, inplace = True)
intDf.drop('Street Marker', axis = 1, inplace = True)
#Drop target field
intDf.drop('In Violation?', axis = 1, inplace = True)
#Drop already int fields (Will add back after)
intDf.drop('Side Of Street', axis = 1, inplace = True)
intDf.drop('Duration of Parking Event (in seconds)', axis = 1, inplace = True)
intDf.drop('Street ID', axis = 1, inplace = True)
intDf.drop('Device ID', axis = 1, inplace = True)

#Transform the remainder non-int fields' values to unique int identifiers
for column in intDf:
    unique_vals = intDf[column].unique()
    intDf[column].replace(to_replace = unique_vals, value = list(range(len(unique_vals))), inplace = True)

#Create dataframe for all the relevant features
features = intDf.copy()

#Add back int fields (If not the target field)
features['Side Of Street'] = parkingdata['Side Of Street']
features['Duration of Parking Event (in seconds)'] = parkingdata['Duration of Parking Event (in seconds)']
features['Street ID'] = parkingdata['Street ID']
features['Device ID'] = parkingdata['Device ID']
#Add back datetime features with only the meaningful subset of data
features['Arrival Hour'] = parkingdata['Arrival Time'].dt.hour
features['Departure Hour'] = parkingdata['Departure Time'].dt.hour

#Table view of features dataframe
features.head(10)
# Out:
#           Area Name  Street Name  Between Street 1  Between Street 2  Sign  \
# 5608179           0            0                 0                 0     0
# 151998            1            1                 1                 1     1
# 2002710           2            2                 2                 2     2
# 4391539           3            3                 3                 3     3
# 5213472           4            4                 4                 4     4
# 7606655           5            5                 5                 5     4
# 9944558           6            6                 6                 6     5
# 3183941           0            7                 7                 7     6
# 10596686          7            8                 8                 8     7
# 10738362          8            9                 9                 9     6
#
#           Side Of Street  Duration of Parking Event (in seconds)  Street ID  \
# 5608179                4                                      84        614
# 151998                 2                                    1316       1285
# 2002710                5                                      86       1329
# 4391539                1                                    1591        681
# 5213472                1                                     138       1171
# 7606655                3                                    3571        123
# 9944558                4                                    4071         16
# 3183941                2                                    3396       1428
# 10596686               2                                     673        627
# 10738362               2                                     155       1323
#
#           Device ID  Arrival Hour  Departure Hour
# 5608179        2739            19              19
# 151998          764            20              20
# 2002710        3550            10              10
# 4391539        2899             9              10
# 5213472         736            17              17
# 7606655        1561            10              11
# 9944558        6443            10              11
# 3183941        3970            12              13
# 10596686        563             8               8
# 10738362       4555            17              17

# %%
#Parameter Tuning

#Define the parameters to tune and the values to tune to
params_KNN = {'n_neighbors': list(range(1, 10)), 
              'weights': ['uniform', 'distance'],
              'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
              'leaf_size': list(range(10, 50, 5)),
              'p': [1, 2, 5]
             }

# %%
#Create the Grid Search to go through the model parameters
cv_method = RepeatedStratifiedKFold(n_splits = 2, 
                                    n_repeats = 1, 
                                    random_state = 4)

gs_KNN = GridSearchCV(estimator = KNeighborsClassifier(), 
                      param_grid = params_KNN, 
                      cv = cv_method,
                      verbose = 1,
                      scoring = 'accuracy', 
                      return_train_score = True,
                      n_jobs = -1)

# %%
#Fit the model with the dataset
bestModel = gs_KNN.fit(features, target)
# Out:
# Fitting 2 folds for each of 1728 candidates, totalling 3456 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed: 26.1min
# [Parallel(n_jobs=-1)]: Done 3456 out of 3456 | elapsed: 36.4min finished

# %%
#Find the best values for the  parameters of the model (Standard output)
gs_KNN.best_params_
# Out:
# {'algorithm': 'brute',
#  'leaf_size': 10,
#  'n_neighbors': 9,
#  'p': 1,
#  'weights': 'distance'}

# %%
#Find the best values for the  parameters of the model (Formatted output)
best_n = bestModel.best_estimator_.get_params()['n_neighbors']
best_w = bestModel.best_estimator_.get_params()['weights']
best_a = bestModel.best_estimator_.get_params()['algorithm']
best_l = bestModel.best_estimator_.get_params()['leaf_size']
best_p = bestModel.best_estimator_.get_params()['p']

print('Best n_neighbors:', best_n)
print('Best weights:', best_w)
print('Best algorithm:', best_a)
print('Best leaf_size:', best_l)
print('Best p:', best_p)
# Out:
# Best n_neighbors: 9
# Best weights: distance
# Best algorithm: brute
# Best leaf_size: 10
# Best p: 1

# %%
#Visualise the parameter configurations from fitting the model with the dataset
results_KNN = pd.DataFrame(gs_KNN.cv_results_['params'])
results_KNN['test_score'] = gs_KNN.cv_results_['mean_test_score']
results_KNN
# Out:
#       algorithm  leaf_size  n_neighbors  p   weights  test_score
# 0          auto         10            1  1   uniform      0.9067
# 1          auto         10            1  1  distance      0.9067
# 2          auto         10            1  2   uniform      0.9026
# 3          auto         10            1  2  distance      0.9026
# 4          auto         10            1  5   uniform      0.9000
# 5          auto         10            1  5  distance      0.9000
# 6          auto         10            2  1   uniform      0.9108
# 7          auto         10            2  1  distance      0.9069
# 8          auto         10            2  2   uniform      0.9084
# 9          auto         10            2  2  distance      0.9026
# 10         auto         10            2  5   uniform      0.9064
# 11         auto         10            2  5  distance      0.9000
# 12         auto         10            3  1   uniform      0.9140
# 13         auto         10            3  1  distance      0.9153
# 14         auto         10            3  2   uniform      0.9084
# 15         auto         10            3  2  distance      0.9097
# 16         auto         10            3  5   uniform      0.9068
# 17         auto         10            3  5  distance      0.9083
# 18         auto         10            4  1   uniform      0.9154
# 19         auto         10            4  1  distance      0.9157
# 20         auto         10            4  2   uniform      0.9113
# 21         auto         10            4  2  distance      0.9120
# 22         auto         10            4  5   uniform      0.9097
# 23         auto         10            4  5  distance      0.9094
# 24         auto         10            5  1   uniform      0.9158
# 25         auto         10            5  1  distance      0.9186
# 26         auto         10            5  2   uniform      0.9124
# 27         auto         10            5  2  distance      0.9132
# 28         auto         10            5  5   uniform      0.9111
# 29         auto         10            5  5  distance      0.9118
# 30         auto         10            6  1   uniform      0.9147
# 31         auto         10            6  1  distance      0.9199
# 32         auto         10            6  2   uniform      0.9138
# 33         auto         10            6  2  distance      0.9156
# 34         auto         10            6  5   uniform      0.9105
# 35         auto         10            6  5  distance      0.9131
# 36         auto         10            7  1   uniform      0.9179
# 37         auto         10            7  1  distance      0.9208
# 38         auto         10            7  2   uniform      0.9141
# 39         auto         10            7  2  distance      0.9156
# 40         auto         10            7  5   uniform      0.9115
# 41         auto         10            7  5  distance      0.9132
# 42         auto         10            8  1   uniform      0.9168
# 43         auto         10            8  1  distance      0.9216
# 44         auto         10            8  2   uniform      0.9131
# 45         auto         10            8  2  distance      0.9162
# 46         auto         10            8  5   uniform      0.9105
# 47         auto         10            8  5  distance      0.9136
# 48         auto         10            9  1   uniform      0.9163
# 49         auto         10            9  1  distance      0.9218
# 50         auto         10            9  2   uniform      0.9126
# 51         auto         10            9  2  distance      0.9165
# 52         auto         10            9  5   uniform      0.9114
# 53         auto         10            9  5  distance      0.9135
# 54         auto         15            1  1   uniform      0.9067
# 55         auto         15            1  1  distance      0.9067
# 56         auto         15            1  2   uniform      0.9026
# 57         auto         15            1  2  distance      0.9026
# 58         auto         15            1  5   uniform      0.9000
# 59         auto         15            1  5  distance      0.9000
# 60         auto         15            2  1   uniform      0.9108
# 61         auto         15            2  1  distance      0.9069
# 62         auto         15            2  2   uniform      0.9084
# 63         auto         15            2  2  distance      0.9026
# 64         auto         15            2  5   uniform      0.9064
# 65         auto         15            2  5  distance      0.9000
# 66         auto         15            3  1   uniform      0.9140
# 67         auto         15            3  1  distance      0.9153
# 68         auto         15            3  2   uniform      0.9084
# 69         auto         15            3  2  distance      0.9097
# 70         auto         15            3  5   uniform      0.9068
# 71         auto         15            3  5  distance      0.9083
# 72         auto         15            4  1   uniform      0.9154
# 73         auto         15            4  1  distance      0.9157
# 74         auto         15            4  2   uniform      0.9113
# 75         auto         15            4  2  distance      0.9120
# 76         auto         15            4  5   uniform      0.9097
# 77         auto         15            4  5  distance      0.9094
# 78         auto         15            5  1   uniform      0.9158
# 79         auto         15            5  1  distance      0.9186
# 80         auto         15            5  2   uniform      0.9124
# 81         auto         15            5  2  distance      0.9132
# 82         auto         15            5  5   uniform      0.9111
# 83         auto         15            5  5  distance      0.9118
# 84         auto         15            6  1   uniform      0.9147
# 85         auto         15            6  1  distance      0.9199
# 86         auto         15            6  2   uniform      0.9138
# 87         auto         15            6  2  distance      0.9156
# 88         auto         15            6  5   uniform      0.9105
# 89         auto         15            6  5  distance      0.9131
# 90         auto         15            7  1   uniform      0.9179
# 91         auto         15            7  1  distance      0.9208
# 92         auto         15            7  2   uniform      0.9141
# 93         auto         15            7  2  distance      0.9156
# 94         auto         15            7  5   uniform      0.9115
# 95         auto         15            7  5  distance      0.9132
# 96         auto         15            8  1   uniform      0.9168
# 97         auto         15            8  1  distance      0.9216
# 98         auto         15            8  2   uniform      0.9131
# 99         auto         15            8  2  distance      0.9162
# 100        auto         15            8  5   uniform      0.9105
# 101        auto         15            8  5  distance      0.9136
# 102        auto         15            9  1   uniform      0.9163
# 103        auto         15            9  1  distance      0.9218
# 104        auto         15            9  2   uniform      0.9126
# 105        auto         15            9  2  distance      0.9165
# 106        auto         15            9  5   uniform      0.9114
# 107        auto         15            9  5  distance      0.9135
# 108        auto         20            1  1   uniform      0.9068
# 109        auto         20            1  1  distance      0.9068
# 110        auto         20            1  2   uniform      0.9026
# 111        auto         20            1  2  distance      0.9026
# 112        auto         20            1  5   uniform      0.9000
# 113        auto         20            1  5  distance      0.9000
# 114        auto         20            2  1   uniform      0.9107
# 115        auto         20            2  1  distance      0.9069
# 116        auto         20            2  2   uniform      0.9084
# 117        auto         20            2  2  distance      0.9026
# 118        auto         20            2  5   uniform      0.9064
# 119        auto         20            2  5  distance      0.9000
# 120        auto         20            3  1   uniform      0.9140
# 121        auto         20            3  1  distance      0.9153
# 122        auto         20            3  2   uniform      0.9084
# 123        auto         20            3  2  distance      0.9097
# 124        auto         20            3  5   uniform      0.9068
# 125        auto         20            3  5  distance      0.9083
# 126        auto         20            4  1   uniform      0.9152
# 127        auto         20            4  1  distance      0.9157
# 128        auto         20            4  2   uniform      0.9113
# 129        auto         20            4  2  distance      0.9120
# 130        auto         20            4  5   uniform      0.9097
# 131        auto         20            4  5  distance      0.9094
# 132        auto         20            5  1   uniform      0.9158
# 133        auto         20            5  1  distance      0.9186
# 134        auto         20            5  2   uniform      0.9124
# 135        auto         20            5  2  distance      0.9132
# 136        auto         20            5  5   uniform      0.9111
# 137        auto         20            5  5  distance      0.9118
# 138        auto         20            6  1   uniform      0.9147
# 139        auto         20            6  1  distance      0.9199
# 140        auto         20            6  2   uniform      0.9138
# 141        auto         20            6  2  distance      0.9156
# 142        auto         20            6  5   uniform      0.9105
# 143        auto         20            6  5  distance      0.9131
# 144        auto         20            7  1   uniform      0.9178
# 145        auto         20            7  1  distance      0.9207
# 146        auto         20            7  2   uniform      0.9141
# 147        auto         20            7  2  distance      0.9156
# 148        auto         20            7  5   uniform      0.9115
# 149        auto         20            7  5  distance      0.9132
# 150        auto         20            8  1   uniform      0.9167
# 151        auto         20            8  1  distance      0.9216
# 152        auto         20            8  2   uniform      0.9131
# 153        auto         20            8  2  distance      0.9162
# 154        auto         20            8  5   uniform      0.9105
# 155        auto         20            8  5  distance      0.9136
# 156        auto         20            9  1   uniform      0.9163
# 157        auto         20            9  1  distance      0.9218
# 158        auto         20            9  2   uniform      0.9126
# 159        auto         20            9  2  distance      0.9165
# 160        auto         20            9  5   uniform      0.9114
# 161        auto         20            9  5  distance      0.9135
# 162        auto         25            1  1   uniform      0.9068
# 163        auto         25            1  1  distance      0.9068
# 164        auto         25            1  2   uniform      0.9026
# 165        auto         25            1  2  distance      0.9026
# 166        auto         25            1  5   uniform      0.9000
# 167        auto         25            1  5  distance      0.9000
# 168        auto         25            2  1   uniform      0.9107
# 169        auto         25            2  1  distance      0.9069
# 170        auto         25            2  2   uniform      0.9084
# 171        auto         25            2  2  distance      0.9026
# 172        auto         25            2  5   uniform      0.9064
# 173        auto         25            2  5  distance      0.9000
# 174        auto         25            3  1   uniform      0.9140
# 175        auto         25            3  1  distance      0.9153
# 176        auto         25            3  2   uniform      0.9084
# 177        auto         25            3  2  distance      0.9097
# 178        auto         25            3  5   uniform      0.9068
# 179        auto         25            3  5  distance      0.9083
# 180        auto         25            4  1   uniform      0.9152
# 181        auto         25            4  1  distance      0.9157
# 182        auto         25            4  2   uniform      0.9113
# 183        auto         25            4  2  distance      0.9120
# 184        auto         25            4  5   uniform      0.9097
# 185        auto         25            4  5  distance      0.9094
# 186        auto         25            5  1   uniform      0.9158
# 187        auto         25            5  1  distance      0.9186
# 188        auto         25            5  2   uniform      0.9124
# 189        auto         25            5  2  distance      0.9132
# 190        auto         25            5  5   uniform      0.9111
# 191        auto         25            5  5  distance      0.9118
# 192        auto         25            6  1   uniform      0.9147
# 193        auto         25            6  1  distance      0.9199
# 194        auto         25            6  2   uniform      0.9138
# 195        auto         25            6  2  distance      0.9156
# 196        auto         25            6  5   uniform      0.9105
# 197        auto         25            6  5  distance      0.9131
# 198        auto         25            7  1   uniform      0.9178
# 199        auto         25            7  1  distance      0.9207
# 200        auto         25            7  2   uniform      0.9141
# 201        auto         25            7  2  distance      0.9156
# 202        auto         25            7  5   uniform      0.9115
# 203        auto         25            7  5  distance      0.9132
# 204        auto         25            8  1   uniform      0.9167
# 205        auto         25            8  1  distance      0.9216
# 206        auto         25            8  2   uniform      0.9131
# 207        auto         25            8  2  distance      0.9162
# 208        auto         25            8  5   uniform      0.9105
# 209        auto         25            8  5  distance      0.9136
# 210        auto         25            9  1   uniform      0.9163
# 211        auto         25            9  1  distance      0.9218
# 212        auto         25            9  2   uniform      0.9126
# 213        auto         25            9  2  distance      0.9165
# 214        auto         25            9  5   uniform      0.9114
# 215        auto         25            9  5  distance      0.9135
# 216        auto         30            1  1   uniform      0.9068
# 217        auto         30            1  1  distance      0.9068
# 218        auto         30            1  2   uniform      0.9026
# 219        auto         30            1  2  distance      0.9026
# 220        auto         30            1  5   uniform      0.9000
# 221        auto         30            1  5  distance      0.9000
# 222        auto         30            2  1   uniform      0.9107
# 223        auto         30            2  1  distance      0.9069
# 224        auto         30            2  2   uniform      0.9084
# 225        auto         30            2  2  distance      0.9026
# 226        auto         30            2  5   uniform      0.9064
# 227        auto         30            2  5  distance      0.9000
# 228        auto         30            3  1   uniform      0.9140
# 229        auto         30            3  1  distance      0.9153
# 230        auto         30            3  2   uniform      0.9084
# 231        auto         30            3  2  distance      0.9097
# 232        auto         30            3  5   uniform      0.9068
# 233        auto         30            3  5  distance      0.9083
# 234        auto         30            4  1   uniform      0.9152
# 235        auto         30            4  1  distance      0.9157
# 236        auto         30            4  2   uniform      0.9113
# 237        auto         30            4  2  distance      0.9120
# 238        auto         30            4  5   uniform      0.9097
# 239        auto         30            4  5  distance      0.9094
# 240        auto         30            5  1   uniform      0.9158
# 241        auto         30            5  1  distance      0.9186
# 242        auto         30            5  2   uniform      0.9124
# 243        auto         30            5  2  distance      0.9132
# 244        auto         30            5  5   uniform      0.9111
# 245        auto         30            5  5  distance      0.9118
# 246        auto         30            6  1   uniform      0.9147
# 247        auto         30            6  1  distance      0.9199
# 248        auto         30            6  2   uniform      0.9138
# 249        auto         30            6  2  distance      0.9156
# 250        auto         30            6  5   uniform      0.9105
# 251        auto         30            6  5  distance      0.9131
# 252        auto         30            7  1   uniform      0.9178
# 253        auto         30            7  1  distance      0.9207
# 254        auto         30            7  2   uniform      0.9141
# 255        auto         30            7  2  distance      0.9156
# 256        auto         30            7  5   uniform      0.9115
# 257        auto         30            7  5  distance      0.9132
# 258        auto         30            8  1   uniform      0.9167
# 259        auto         30            8  1  distance      0.9216
# 260        auto         30            8  2   uniform      0.9131
# 261        auto         30            8  2  distance      0.9162
# 262        auto         30            8  5   uniform      0.9105
# 263        auto         30            8  5  distance      0.9136
# 264        auto         30            9  1   uniform      0.9163
# 265        auto         30            9  1  distance      0.9218
# 266        auto         30            9  2   uniform      0.9126
# 267        auto         30            9  2  distance      0.9165
# 268        auto         30            9  5   uniform      0.9114
# 269        auto         30            9  5  distance      0.9135
# 270        auto         35            1  1   uniform      0.9068
# 271        auto         35            1  1  distance      0.9068
# 272        auto         35            1  2   uniform      0.9026
# 273        auto         35            1  2  distance      0.9026
# 274        auto         35            1  5   uniform      0.9000
# 275        auto         35            1  5  distance      0.9000
# 276        auto         35            2  1   uniform      0.9107
# 277        auto         35            2  1  distance      0.9069
# 278        auto         35            2  2   uniform      0.9084
# 279        auto         35            2  2  distance      0.9026
# 280        auto         35            2  5   uniform      0.9064
# 281        auto         35            2  5  distance      0.9000
# 282        auto         35            3  1   uniform      0.9140
# 283        auto         35            3  1  distance      0.9153
# 284        auto         35            3  2   uniform      0.9084
# 285        auto         35            3  2  distance      0.9097
# 286        auto         35            3  5   uniform      0.9068
# 287        auto         35            3  5  distance      0.9083
# 288        auto         35            4  1   uniform      0.9152
# 289        auto         35            4  1  distance      0.9157
# 290        auto         35            4  2   uniform      0.9113
# 291        auto         35            4  2  distance      0.9120
# 292        auto         35            4  5   uniform      0.9097
# 293        auto         35            4  5  distance      0.9094
# 294        auto         35            5  1   uniform      0.9158
# 295        auto         35            5  1  distance      0.9186
# 296        auto         35            5  2   uniform      0.9124
# 297        auto         35            5  2  distance      0.9132
# 298        auto         35            5  5   uniform      0.9111
# 299        auto         35            5  5  distance      0.9118
# 300        auto         35            6  1   uniform      0.9147
# 301        auto         35            6  1  distance      0.9199
# 302        auto         35            6  2   uniform      0.9138
# 303        auto         35            6  2  distance      0.9156
# 304        auto         35            6  5   uniform      0.9105
# 305        auto         35            6  5  distance      0.9131
# 306        auto         35            7  1   uniform      0.9178
# 307        auto         35            7  1  distance      0.9207
# 308        auto         35            7  2   uniform      0.9141
# 309        auto         35            7  2  distance      0.9156
# 310        auto         35            7  5   uniform      0.9115
# 311        auto         35            7  5  distance      0.9132
# 312        auto         35            8  1   uniform      0.9167
# 313        auto         35            8  1  distance      0.9216
# 314        auto         35            8  2   uniform      0.9131
# 315        auto         35            8  2  distance      0.9162
# 316        auto         35            8  5   uniform      0.9105
# 317        auto         35            8  5  distance      0.9136
# 318        auto         35            9  1   uniform      0.9163
# 319        auto         35            9  1  distance      0.9218
# 320        auto         35            9  2   uniform      0.9126
# 321        auto         35            9  2  distance      0.9165
# 322        auto         35            9  5   uniform      0.9114
# 323        auto         35            9  5  distance      0.9135
# 324        auto         40            1  1   uniform      0.9069
# 325        auto         40            1  1  distance      0.9069
# 326        auto         40            1  2   uniform      0.9026
# 327        auto         40            1  2  distance      0.9026
# 328        auto         40            1  5   uniform      0.9000
# 329        auto         40            1  5  distance      0.9000
# 330        auto         40            2  1   uniform      0.9109
# 331        auto         40            2  1  distance      0.9069
# 332        auto         40            2  2   uniform      0.9084
# 333        auto         40            2  2  distance      0.9026
# 334        auto         40            2  5   uniform      0.9064
# 335        auto         40            2  5  distance      0.9000
# 336        auto         40            3  1   uniform      0.9138
# 337        auto         40            3  1  distance      0.9151
# 338        auto         40            3  2   uniform      0.9084
# 339        auto         40            3  2  distance      0.9097
# 340        auto         40            3  5   uniform      0.9068
# 341        auto         40            3  5  distance      0.9083
# 342        auto         40            4  1   uniform      0.9152
# 343        auto         40            4  1  distance      0.9157
# 344        auto         40            4  2   uniform      0.9113
# 345        auto         40            4  2  distance      0.9120
# 346        auto         40            4  5   uniform      0.9097
# 347        auto         40            4  5  distance      0.9094
# 348        auto         40            5  1   uniform      0.9158
# 349        auto         40            5  1  distance      0.9186
# 350        auto         40            5  2   uniform      0.9124
# 351        auto         40            5  2  distance      0.9132
# 352        auto         40            5  5   uniform      0.9111
# 353        auto         40            5  5  distance      0.9118
# 354        auto         40            6  1   uniform      0.9147
# 355        auto         40            6  1  distance      0.9199
# 356        auto         40            6  2   uniform      0.9138
# 357        auto         40            6  2  distance      0.9156
# 358        auto         40            6  5   uniform      0.9105
# 359        auto         40            6  5  distance      0.9131
# 360        auto         40            7  1   uniform      0.9178
# 361        auto         40            7  1  distance      0.9208
# 362        auto         40            7  2   uniform      0.9141
# 363        auto         40            7  2  distance      0.9156
# 364        auto         40            7  5   uniform      0.9115
# 365        auto         40            7  5  distance      0.9132
# 366        auto         40            8  1   uniform      0.9166
# 367        auto         40            8  1  distance      0.9216
# 368        auto         40            8  2   uniform      0.9131
# 369        auto         40            8  2  distance      0.9162
# 370        auto         40            8  5   uniform      0.9105
# 371        auto         40            8  5  distance      0.9136
# 372        auto         40            9  1   uniform      0.9163
# 373        auto         40            9  1  distance      0.9218
# 374        auto         40            9  2   uniform      0.9126
# 375        auto         40            9  2  distance      0.9165
# 376        auto         40            9  5   uniform      0.9114
# 377        auto         40            9  5  distance      0.9135
# 378        auto         45            1  1   uniform      0.9069
# 379        auto         45            1  1  distance      0.9069
# 380        auto         45            1  2   uniform      0.9026
# 381        auto         45            1  2  distance      0.9026
# 382        auto         45            1  5   uniform      0.9000
# 383        auto         45            1  5  distance      0.9000
# 384        auto         45            2  1   uniform      0.9109
# 385        auto         45            2  1  distance      0.9069
# 386        auto         45            2  2   uniform      0.9084
# 387        auto         45            2  2  distance      0.9026
# 388        auto         45            2  5   uniform      0.9064
# 389        auto         45            2  5  distance      0.9000
# 390        auto         45            3  1   uniform      0.9138
# 391        auto         45            3  1  distance      0.9151
# 392        auto         45            3  2   uniform      0.9084
# 393        auto         45            3  2  distance      0.9097
# 394        auto         45            3  5   uniform      0.9068
# 395        auto         45            3  5  distance      0.9083
# 396        auto         45            4  1   uniform      0.9152
# 397        auto         45            4  1  distance      0.9157
# 398        auto         45            4  2   uniform      0.9113
# 399        auto         45            4  2  distance      0.9120
# 400        auto         45            4  5   uniform      0.9097
# 401        auto         45            4  5  distance      0.9094
# 402        auto         45            5  1   uniform      0.9158
# 403        auto         45            5  1  distance      0.9186
# 404        auto         45            5  2   uniform      0.9124
# 405        auto         45            5  2  distance      0.9132
# 406        auto         45            5  5   uniform      0.9111
# 407        auto         45            5  5  distance      0.9118
# 408        auto         45            6  1   uniform      0.9147
# 409        auto         45            6  1  distance      0.9199
# 410        auto         45            6  2   uniform      0.9138
# 411        auto         45            6  2  distance      0.9156
# 412        auto         45            6  5   uniform      0.9105
# 413        auto         45            6  5  distance      0.9131
# 414        auto         45            7  1   uniform      0.9178
# 415        auto         45            7  1  distance      0.9208
# 416        auto         45            7  2   uniform      0.9141
# 417        auto         45            7  2  distance      0.9156
# 418        auto         45            7  5   uniform      0.9115
# 419        auto         45            7  5  distance      0.9132
# 420        auto         45            8  1   uniform      0.9166
# 421        auto         45            8  1  distance      0.9216
# 422        auto         45            8  2   uniform      0.9131
# 423        auto         45            8  2  distance      0.9162
# 424        auto         45            8  5   uniform      0.9105
# 425        auto         45            8  5  distance      0.9136
# 426        auto         45            9  1   uniform      0.9163
# 427        auto         45            9  1  distance      0.9218
# 428        auto         45            9  2   uniform      0.9126
# 429        auto         45            9  2  distance      0.9165
# 430        auto         45            9  5   uniform      0.9114
# 431        auto         45            9  5  distance      0.9135
# 432   ball_tree         10            1  1   uniform      0.9067
# 433   ball_tree         10            1  1  distance      0.9067
# 434   ball_tree         10            1  2   uniform      0.9026
# 435   ball_tree         10            1  2  distance      0.9026
# 436   ball_tree         10            1  5   uniform      0.9000
# 437   ball_tree         10            1  5  distance      0.9000
# 438   ball_tree         10            2  1   uniform      0.9109
# 439   ball_tree         10            2  1  distance      0.9069
# 440   ball_tree         10            2  2   uniform      0.9084
# 441   ball_tree         10            2  2  distance      0.9026
# 442   ball_tree         10            2  5   uniform      0.9064
# 443   ball_tree         10            2  5  distance      0.9000
# 444   ball_tree         10            3  1   uniform      0.9139
# 445   ball_tree         10            3  1  distance      0.9152
# 446   ball_tree         10            3  2   uniform      0.9084
# 447   ball_tree         10            3  2  distance      0.9097
# 448   ball_tree         10            3  5   uniform      0.9068
# 449   ball_tree         10            3  5  distance      0.9083
# 450   ball_tree         10            4  1   uniform      0.9155
# 451   ball_tree         10            4  1  distance      0.9158
# 452   ball_tree         10            4  2   uniform      0.9113
# 453   ball_tree         10            4  2  distance      0.9120
# 454   ball_tree         10            4  5   uniform      0.9097
# 455   ball_tree         10            4  5  distance      0.9094
# 456   ball_tree         10            5  1   uniform      0.9158
# 457   ball_tree         10            5  1  distance      0.9186
# 458   ball_tree         10            5  2   uniform      0.9124
# 459   ball_tree         10            5  2  distance      0.9132
# 460   ball_tree         10            5  5   uniform      0.9111
# 461   ball_tree         10            5  5  distance      0.9118
# 462   ball_tree         10            6  1   uniform      0.9147
# 463   ball_tree         10            6  1  distance      0.9199
# 464   ball_tree         10            6  2   uniform      0.9138
# 465   ball_tree         10            6  2  distance      0.9156
# 466   ball_tree         10            6  5   uniform      0.9105
# 467   ball_tree         10            6  5  distance      0.9131
# 468   ball_tree         10            7  1   uniform      0.9178
# 469   ball_tree         10            7  1  distance      0.9208
# 470   ball_tree         10            7  2   uniform      0.9141
# 471   ball_tree         10            7  2  distance      0.9156
# 472   ball_tree         10            7  5   uniform      0.9115
# 473   ball_tree         10            7  5  distance      0.9132
# 474   ball_tree         10            8  1   uniform      0.9167
# 475   ball_tree         10            8  1  distance      0.9216
# 476   ball_tree         10            8  2   uniform      0.9131
# 477   ball_tree         10            8  2  distance      0.9162
# 478   ball_tree         10            8  5   uniform      0.9105
# 479   ball_tree         10            8  5  distance      0.9136
# 480   ball_tree         10            9  1   uniform      0.9163
# 481   ball_tree         10            9  1  distance      0.9218
# 482   ball_tree         10            9  2   uniform      0.9126
# 483   ball_tree         10            9  2  distance      0.9165
# 484   ball_tree         10            9  5   uniform      0.9114
# 485   ball_tree         10            9  5  distance      0.9135
# 486   ball_tree         15            1  1   uniform      0.9067
# 487   ball_tree         15            1  1  distance      0.9067
# 488   ball_tree         15            1  2   uniform      0.9026
# 489   ball_tree         15            1  2  distance      0.9026
# 490   ball_tree         15            1  5   uniform      0.9000
# 491   ball_tree         15            1  5  distance      0.9000
# 492   ball_tree         15            2  1   uniform      0.9109
# 493   ball_tree         15            2  1  distance      0.9069
# 494   ball_tree         15            2  2   uniform      0.9084
# 495   ball_tree         15            2  2  distance      0.9026
# 496   ball_tree         15            2  5   uniform      0.9064
# 497   ball_tree         15            2  5  distance      0.9000
# 498   ball_tree         15            3  1   uniform      0.9139
# 499   ball_tree         15            3  1  distance      0.9152
# 500   ball_tree         15            3  2   uniform      0.9084
# 501   ball_tree         15            3  2  distance      0.9097
# 502   ball_tree         15            3  5   uniform      0.9068
# 503   ball_tree         15            3  5  distance      0.9083
# 504   ball_tree         15            4  1   uniform      0.9155
# 505   ball_tree         15            4  1  distance      0.9158
# 506   ball_tree         15            4  2   uniform      0.9113
# 507   ball_tree         15            4  2  distance      0.9120
# 508   ball_tree         15            4  5   uniform      0.9097
# 509   ball_tree         15            4  5  distance      0.9094
# 510   ball_tree         15            5  1   uniform      0.9158
# 511   ball_tree         15            5  1  distance      0.9186
# 512   ball_tree         15            5  2   uniform      0.9124
# 513   ball_tree         15            5  2  distance      0.9132
# 514   ball_tree         15            5  5   uniform      0.9111
# 515   ball_tree         15            5  5  distance      0.9118
# 516   ball_tree         15            6  1   uniform      0.9147
# 517   ball_tree         15            6  1  distance      0.9199
# 518   ball_tree         15            6  2   uniform      0.9138
# 519   ball_tree         15            6  2  distance      0.9156
# 520   ball_tree         15            6  5   uniform      0.9105
# 521   ball_tree         15            6  5  distance      0.9131
# 522   ball_tree         15            7  1   uniform      0.9178
# 523   ball_tree         15            7  1  distance      0.9208
# 524   ball_tree         15            7  2   uniform      0.9141
# 525   ball_tree         15            7  2  distance      0.9156
# 526   ball_tree         15            7  5   uniform      0.9115
# 527   ball_tree         15            7  5  distance      0.9132
# 528   ball_tree         15            8  1   uniform      0.9167
# 529   ball_tree         15            8  1  distance      0.9216
# 530   ball_tree         15            8  2   uniform      0.9131
# 531   ball_tree         15            8  2  distance      0.9162
# 532   ball_tree         15            8  5   uniform      0.9105
# 533   ball_tree         15            8  5  distance      0.9136
# 534   ball_tree         15            9  1   uniform      0.9163
# 535   ball_tree         15            9  1  distance      0.9218
# 536   ball_tree         15            9  2   uniform      0.9126
# 537   ball_tree         15            9  2  distance      0.9165
# 538   ball_tree         15            9  5   uniform      0.9114
# 539   ball_tree         15            9  5  distance      0.9135
# 540   ball_tree         20            1  1   uniform      0.9068
# 541   ball_tree         20            1  1  distance      0.9068
# 542   ball_tree         20            1  2   uniform      0.9026
# 543   ball_tree         20            1  2  distance      0.9026
# 544   ball_tree         20            1  5   uniform      0.9000
# 545   ball_tree         20            1  5  distance      0.9000
# 546   ball_tree         20            2  1   uniform      0.9107
# 547   ball_tree         20            2  1  distance      0.9069
# 548   ball_tree         20            2  2   uniform      0.9084
# 549   ball_tree         20            2  2  distance      0.9026
# 550   ball_tree         20            2  5   uniform      0.9064
# 551   ball_tree         20            2  5  distance      0.9000
# 552   ball_tree         20            3  1   uniform      0.9139
# 553   ball_tree         20            3  1  distance      0.9152
# 554   ball_tree         20            3  2   uniform      0.9084
# 555   ball_tree         20            3  2  distance      0.9097
# 556   ball_tree         20            3  5   uniform      0.9068
# 557   ball_tree         20            3  5  distance      0.9083
# 558   ball_tree         20            4  1   uniform      0.9153
# 559   ball_tree         20            4  1  distance      0.9158
# 560   ball_tree         20            4  2   uniform      0.9113
# 561   ball_tree         20            4  2  distance      0.9120
# 562   ball_tree         20            4  5   uniform      0.9097
# 563   ball_tree         20            4  5  distance      0.9094
# 564   ball_tree         20            5  1   uniform      0.9158
# 565   ball_tree         20            5  1  distance      0.9186
# 566   ball_tree         20            5  2   uniform      0.9124
# 567   ball_tree         20            5  2  distance      0.9132
# 568   ball_tree         20            5  5   uniform      0.9111
# 569   ball_tree         20            5  5  distance      0.9118
# 570   ball_tree         20            6  1   uniform      0.9147
# 571   ball_tree         20            6  1  distance      0.9199
# 572   ball_tree         20            6  2   uniform      0.9138
# 573   ball_tree         20            6  2  distance      0.9156
# 574   ball_tree         20            6  5   uniform      0.9105
# 575   ball_tree         20            6  5  distance      0.9131
# 576   ball_tree         20            7  1   uniform      0.9179
# 577   ball_tree         20            7  1  distance      0.9208
# 578   ball_tree         20            7  2   uniform      0.9141
# 579   ball_tree         20            7  2  distance      0.9156
# 580   ball_tree         20            7  5   uniform      0.9115
# 581   ball_tree         20            7  5  distance      0.9132
# 582   ball_tree         20            8  1   uniform      0.9168
# 583   ball_tree         20            8  1  distance      0.9216
# 584   ball_tree         20            8  2   uniform      0.9131
# 585   ball_tree         20            8  2  distance      0.9162
# 586   ball_tree         20            8  5   uniform      0.9105
# 587   ball_tree         20            8  5  distance      0.9136
# 588   ball_tree         20            9  1   uniform      0.9163
# 589   ball_tree         20            9  1  distance      0.9218
# 590   ball_tree         20            9  2   uniform      0.9126
# 591   ball_tree         20            9  2  distance      0.9165
# 592   ball_tree         20            9  5   uniform      0.9114
# 593   ball_tree         20            9  5  distance      0.9135
# 594   ball_tree         25            1  1   uniform      0.9068
# 595   ball_tree         25            1  1  distance      0.9068
# 596   ball_tree         25            1  2   uniform      0.9026
# 597   ball_tree         25            1  2  distance      0.9026
# 598   ball_tree         25            1  5   uniform      0.9000
# 599   ball_tree         25            1  5  distance      0.9000
# 600   ball_tree         25            2  1   uniform      0.9107
# 601   ball_tree         25            2  1  distance      0.9069
# 602   ball_tree         25            2  2   uniform      0.9084
# 603   ball_tree         25            2  2  distance      0.9026
# 604   ball_tree         25            2  5   uniform      0.9064
# 605   ball_tree         25            2  5  distance      0.9000
# 606   ball_tree         25            3  1   uniform      0.9139
# 607   ball_tree         25            3  1  distance      0.9152
# 608   ball_tree         25            3  2   uniform      0.9084
# 609   ball_tree         25            3  2  distance      0.9097
# 610   ball_tree         25            3  5   uniform      0.9068
# 611   ball_tree         25            3  5  distance      0.9083
# 612   ball_tree         25            4  1   uniform      0.9153
# 613   ball_tree         25            4  1  distance      0.9158
# 614   ball_tree         25            4  2   uniform      0.9113
# 615   ball_tree         25            4  2  distance      0.9120
# 616   ball_tree         25            4  5   uniform      0.9097
# 617   ball_tree         25            4  5  distance      0.9094
# 618   ball_tree         25            5  1   uniform      0.9158
# 619   ball_tree         25            5  1  distance      0.9186
# 620   ball_tree         25            5  2   uniform      0.9124
# 621   ball_tree         25            5  2  distance      0.9132
# 622   ball_tree         25            5  5   uniform      0.9111
# 623   ball_tree         25            5  5  distance      0.9118
# 624   ball_tree         25            6  1   uniform      0.9147
# 625   ball_tree         25            6  1  distance      0.9199
# 626   ball_tree         25            6  2   uniform      0.9138
# 627   ball_tree         25            6  2  distance      0.9156
# 628   ball_tree         25            6  5   uniform      0.9105
# 629   ball_tree         25            6  5  distance      0.9131
# 630   ball_tree         25            7  1   uniform      0.9179
# 631   ball_tree         25            7  1  distance      0.9208
# 632   ball_tree         25            7  2   uniform      0.9141
# 633   ball_tree         25            7  2  distance      0.9156
# 634   ball_tree         25            7  5   uniform      0.9115
# 635   ball_tree         25            7  5  distance      0.9132
# 636   ball_tree         25            8  1   uniform      0.9168
# 637   ball_tree         25            8  1  distance      0.9216
# 638   ball_tree         25            8  2   uniform      0.9131
# 639   ball_tree         25            8  2  distance      0.9162
# 640   ball_tree         25            8  5   uniform      0.9105
# 641   ball_tree         25            8  5  distance      0.9136
# 642   ball_tree         25            9  1   uniform      0.9163
# 643   ball_tree         25            9  1  distance      0.9218
# 644   ball_tree         25            9  2   uniform      0.9126
# 645   ball_tree         25            9  2  distance      0.9165
# 646   ball_tree         25            9  5   uniform      0.9114
# 647   ball_tree         25            9  5  distance      0.9135
# 648   ball_tree         30            1  1   uniform      0.9068
# 649   ball_tree         30            1  1  distance      0.9068
# 650   ball_tree         30            1  2   uniform      0.9026
# 651   ball_tree         30            1  2  distance      0.9026
# 652   ball_tree         30            1  5   uniform      0.9000
# 653   ball_tree         30            1  5  distance      0.9000
# 654   ball_tree         30            2  1   uniform      0.9107
# 655   ball_tree         30            2  1  distance      0.9069
# 656   ball_tree         30            2  2   uniform      0.9084
# 657   ball_tree         30            2  2  distance      0.9026
# 658   ball_tree         30            2  5   uniform      0.9064
# 659   ball_tree         30            2  5  distance      0.9000
# 660   ball_tree         30            3  1   uniform      0.9139
# 661   ball_tree         30            3  1  distance      0.9152
# 662   ball_tree         30            3  2   uniform      0.9084
# 663   ball_tree         30            3  2  distance      0.9097
# 664   ball_tree         30            3  5   uniform      0.9068
# 665   ball_tree         30            3  5  distance      0.9083
# 666   ball_tree         30            4  1   uniform      0.9153
# 667   ball_tree         30            4  1  distance      0.9158
# 668   ball_tree         30            4  2   uniform      0.9113
# 669   ball_tree         30            4  2  distance      0.9120
# 670   ball_tree         30            4  5   uniform      0.9097
# 671   ball_tree         30            4  5  distance      0.9094
# 672   ball_tree         30            5  1   uniform      0.9158
# 673   ball_tree         30            5  1  distance      0.9186
# 674   ball_tree         30            5  2   uniform      0.9124
# 675   ball_tree         30            5  2  distance      0.9132
# 676   ball_tree         30            5  5   uniform      0.9111
# 677   ball_tree         30            5  5  distance      0.9118
# 678   ball_tree         30            6  1   uniform      0.9147
# 679   ball_tree         30            6  1  distance      0.9199
# 680   ball_tree         30            6  2   uniform      0.9138
# 681   ball_tree         30            6  2  distance      0.9156
# 682   ball_tree         30            6  5   uniform      0.9105
# 683   ball_tree         30            6  5  distance      0.9131
# 684   ball_tree         30            7  1   uniform      0.9179
# 685   ball_tree         30            7  1  distance      0.9208
# 686   ball_tree         30            7  2   uniform      0.9141
# 687   ball_tree         30            7  2  distance      0.9156
# 688   ball_tree         30            7  5   uniform      0.9115
# 689   ball_tree         30            7  5  distance      0.9132
# 690   ball_tree         30            8  1   uniform      0.9168
# 691   ball_tree         30            8  1  distance      0.9216
# 692   ball_tree         30            8  2   uniform      0.9131
# 693   ball_tree         30            8  2  distance      0.9162
# 694   ball_tree         30            8  5   uniform      0.9105
# 695   ball_tree         30            8  5  distance      0.9136
# 696   ball_tree         30            9  1   uniform      0.9163
# 697   ball_tree         30            9  1  distance      0.9218
# 698   ball_tree         30            9  2   uniform      0.9126
# 699   ball_tree         30            9  2  distance      0.9165
# 700   ball_tree         30            9  5   uniform      0.9114
# 701   ball_tree         30            9  5  distance      0.9135
# 702   ball_tree         35            1  1   uniform      0.9068
# 703   ball_tree         35            1  1  distance      0.9068
# 704   ball_tree         35            1  2   uniform      0.9026
# 705   ball_tree         35            1  2  distance      0.9026
# 706   ball_tree         35            1  5   uniform      0.9000
# 707   ball_tree         35            1  5  distance      0.9000
# 708   ball_tree         35            2  1   uniform      0.9107
# 709   ball_tree         35            2  1  distance      0.9069
# 710   ball_tree         35            2  2   uniform      0.9084
# 711   ball_tree         35            2  2  distance      0.9026
# 712   ball_tree         35            2  5   uniform      0.9064
# 713   ball_tree         35            2  5  distance      0.9000
# 714   ball_tree         35            3  1   uniform      0.9139
# 715   ball_tree         35            3  1  distance      0.9152
# 716   ball_tree         35            3  2   uniform      0.9084
# 717   ball_tree         35            3  2  distance      0.9097
# 718   ball_tree         35            3  5   uniform      0.9068
# 719   ball_tree         35            3  5  distance      0.9083
# 720   ball_tree         35            4  1   uniform      0.9153
# 721   ball_tree         35            4  1  distance      0.9158
# 722   ball_tree         35            4  2   uniform      0.9113
# 723   ball_tree         35            4  2  distance      0.9120
# 724   ball_tree         35            4  5   uniform      0.9097
# 725   ball_tree         35            4  5  distance      0.9094
# 726   ball_tree         35            5  1   uniform      0.9158
# 727   ball_tree         35            5  1  distance      0.9186
# 728   ball_tree         35            5  2   uniform      0.9124
# 729   ball_tree         35            5  2  distance      0.9132
# 730   ball_tree         35            5  5   uniform      0.9111
# 731   ball_tree         35            5  5  distance      0.9118
# 732   ball_tree         35            6  1   uniform      0.9147
# 733   ball_tree         35            6  1  distance      0.9199
# 734   ball_tree         35            6  2   uniform      0.9138
# 735   ball_tree         35            6  2  distance      0.9156
# 736   ball_tree         35            6  5   uniform      0.9105
# ...
# 1482      brute         25            5  1   uniform      0.9158
# 1483      brute         25            5  1  distance      0.9186
# 1484      brute         25            5  2   uniform      0.9124
# 1485      brute         25            5  2  distance      0.9132
# 1486      brute         25            5  5   uniform      0.9111
# 1487      brute         25            5  5  distance      0.9118
# 1488      brute         25            6  1   uniform      0.9147
# 1489      brute         25            6  1  distance      0.9199
# 1490      brute         25            6  2   uniform      0.9138
# 1491      brute         25            6  2  distance      0.9156
# 1492      brute         25            6  5   uniform      0.9105
# 1493      brute         25            6  5  distance      0.9131
# 1494      brute         25            7  1   uniform      0.9180
# 1495      brute         25            7  1  distance      0.9207
# 1496      brute         25            7  2   uniform      0.9141
# 1497      brute         25            7  2  distance      0.9156
# 1498      brute         25            7  5   uniform      0.9115
# 1499      brute         25            7  5  distance      0.9132
# 1500      brute         25            8  1   uniform      0.9168
# 1501      brute         25            8  1  distance      0.9216
# 1502      brute         25            8  2   uniform      0.9131
# 1503      brute         25            8  2  distance      0.9162
# 1504      brute         25            8  5   uniform      0.9105
# 1505      brute         25            8  5  distance      0.9136
# 1506      brute         25            9  1   uniform      0.9165
# 1507      brute         25            9  1  distance      0.9220
# 1508      brute         25            9  2   uniform      0.9126
# 1509      brute         25            9  2  distance      0.9165
# 1510      brute         25            9  5   uniform      0.9114
# 1511      brute         25            9  5  distance      0.9135
# 1512      brute         30            1  1   uniform      0.9067
# 1513      brute         30            1  1  distance      0.9067
# 1514      brute         30            1  2   uniform      0.9026
# 1515      brute         30            1  2  distance      0.9026
# 1516      brute         30            1  5   uniform      0.9000
# 1517      brute         30            1  5  distance      0.9000
# 1518      brute         30            2  1   uniform      0.9108
# 1519      brute         30            2  1  distance      0.9069
# 1520      brute         30            2  2   uniform      0.9084
# 1521      brute         30            2  2  distance      0.9026
# 1522      brute         30            2  5   uniform      0.9064
# 1523      brute         30            2  5  distance      0.9000
# 1524      brute         30            3  1   uniform      0.9138
# 1525      brute         30            3  1  distance      0.9151
# 1526      brute         30            3  2   uniform      0.9084
# 1527      brute         30            3  2  distance      0.9097
# 1528      brute         30            3  5   uniform      0.9068
# 1529      brute         30            3  5  distance      0.9083
# 1530      brute         30            4  1   uniform      0.9154
# 1531      brute         30            4  1  distance      0.9157
# 1532      brute         30            4  2   uniform      0.9113
# 1533      brute         30            4  2  distance      0.9120
# 1534      brute         30            4  5   uniform      0.9097
# 1535      brute         30            4  5  distance      0.9094
# 1536      brute         30            5  1   uniform      0.9158
# 1537      brute         30            5  1  distance      0.9186
# 1538      brute         30            5  2   uniform      0.9124
# 1539      brute         30            5  2  distance      0.9132
# 1540      brute         30            5  5   uniform      0.9111
# 1541      brute         30            5  5  distance      0.9118
# 1542      brute         30            6  1   uniform      0.9147
# 1543      brute         30            6  1  distance      0.9199
# 1544      brute         30            6  2   uniform      0.9138
# 1545      brute         30            6  2  distance      0.9156
# 1546      brute         30            6  5   uniform      0.9105
# 1547      brute         30            6  5  distance      0.9131
# 1548      brute         30            7  1   uniform      0.9180
# 1549      brute         30            7  1  distance      0.9207
# 1550      brute         30            7  2   uniform      0.9141
# 1551      brute         30            7  2  distance      0.9156
# 1552      brute         30            7  5   uniform      0.9115
# 1553      brute         30            7  5  distance      0.9132
# 1554      brute         30            8  1   uniform      0.9168
# 1555      brute         30            8  1  distance      0.9216
# 1556      brute         30            8  2   uniform      0.9131
# 1557      brute         30            8  2  distance      0.9162
# 1558      brute         30            8  5   uniform      0.9105
# 1559      brute         30            8  5  distance      0.9136
# 1560      brute         30            9  1   uniform      0.9165
# 1561      brute         30            9  1  distance      0.9220
# 1562      brute         30            9  2   uniform      0.9126
# 1563      brute         30            9  2  distance      0.9165
# 1564      brute         30            9  5   uniform      0.9114
# 1565      brute         30            9  5  distance      0.9135
# 1566      brute         35            1  1   uniform      0.9067
# 1567      brute         35            1  1  distance      0.9067
# 1568      brute         35            1  2   uniform      0.9026
# 1569      brute         35            1  2  distance      0.9026
# 1570      brute         35            1  5   uniform      0.9000
# 1571      brute         35            1  5  distance      0.9000
# 1572      brute         35            2  1   uniform      0.9108
# 1573      brute         35            2  1  distance      0.9069
# 1574      brute         35            2  2   uniform      0.9084
# 1575      brute         35            2  2  distance      0.9026
# 1576      brute         35            2  5   uniform      0.9064
# 1577      brute         35            2  5  distance      0.9000
# 1578      brute         35            3  1   uniform      0.9138
# 1579      brute         35            3  1  distance      0.9151
# 1580      brute         35            3  2   uniform      0.9084
# 1581      brute         35            3  2  distance      0.9097
# 1582      brute         35            3  5   uniform      0.9068
# 1583      brute         35            3  5  distance      0.9083
# 1584      brute         35            4  1   uniform      0.9154
# 1585      brute         35            4  1  distance      0.9157
# 1586      brute         35            4  2   uniform      0.9113
# 1587      brute         35            4  2  distance      0.9120
# 1588      brute         35            4  5   uniform      0.9097
# 1589      brute         35            4  5  distance      0.9094
# 1590      brute         35            5  1   uniform      0.9158
# 1591      brute         35            5  1  distance      0.9186
# 1592      brute         35            5  2   uniform      0.9124
# 1593      brute         35            5  2  distance      0.9132
# 1594      brute         35            5  5   uniform      0.9111
# 1595      brute         35            5  5  distance      0.9118
# 1596      brute         35            6  1   uniform      0.9147
# 1597      brute         35            6  1  distance      0.9199
# 1598      brute         35            6  2   uniform      0.9138
# 1599      brute         35            6  2  distance      0.9156
# 1600      brute         35            6  5   uniform      0.9105
# 1601      brute         35            6  5  distance      0.9131
# 1602      brute         35            7  1   uniform      0.9180
# 1603      brute         35            7  1  distance      0.9207
# 1604      brute         35            7  2   uniform      0.9141
# 1605      brute         35            7  2  distance      0.9156
# 1606      brute         35            7  5   uniform      0.9115
# 1607      brute         35            7  5  distance      0.9132
# 1608      brute         35            8  1   uniform      0.9168
# 1609      brute         35            8  1  distance      0.9216
# 1610      brute         35            8  2   uniform      0.9131
# 1611      brute         35            8  2  distance      0.9162
# 1612      brute         35            8  5   uniform      0.9105
# 1613      brute         35            8  5  distance      0.9136
# 1614      brute         35            9  1   uniform      0.9165
# 1615      brute         35            9  1  distance      0.9220
# 1616      brute         35            9  2   uniform      0.9126
# 1617      brute         35            9  2  distance      0.9165
# 1618      brute         35            9  5   uniform      0.9114
# 1619      brute         35            9  5  distance      0.9135
# 1620      brute         40            1  1   uniform      0.9067
# 1621      brute         40            1  1  distance      0.9067
# 1622      brute         40            1  2   uniform      0.9026
# 1623      brute         40            1  2  distance      0.9026
# 1624      brute         40            1  5   uniform      0.9000
# 1625      brute         40            1  5  distance      0.9000
# 1626      brute         40            2  1   uniform      0.9108
# 1627      brute         40            2  1  distance      0.9069
# 1628      brute         40            2  2   uniform      0.9084
# 1629      brute         40            2  2  distance      0.9026
# 1630      brute         40            2  5   uniform      0.9064
# 1631      brute         40            2  5  distance      0.9000
# 1632      brute         40            3  1   uniform      0.9138
# 1633      brute         40            3  1  distance      0.9151
# 1634      brute         40            3  2   uniform      0.9084
# 1635      brute         40            3  2  distance      0.9097
# 1636      brute         40            3  5   uniform      0.9068
# 1637      brute         40            3  5  distance      0.9083
# 1638      brute         40            4  1   uniform      0.9154
# 1639      brute         40            4  1  distance      0.9157
# 1640      brute         40            4  2   uniform      0.9113
# 1641      brute         40            4  2  distance      0.9120
# 1642      brute         40            4  5   uniform      0.9097
# 1643      brute         40            4  5  distance      0.9094
# 1644      brute         40            5  1   uniform      0.9158
# 1645      brute         40            5  1  distance      0.9186
# 1646      brute         40            5  2   uniform      0.9124
# 1647      brute         40            5  2  distance      0.9132
# 1648      brute         40            5  5   uniform      0.9111
# 1649      brute         40            5  5  distance      0.9118
# 1650      brute         40            6  1   uniform      0.9147
# 1651      brute         40            6  1  distance      0.9199
# 1652      brute         40            6  2   uniform      0.9138
# 1653      brute         40            6  2  distance      0.9156
# 1654      brute         40            6  5   uniform      0.9105
# 1655      brute         40            6  5  distance      0.9131
# 1656      brute         40            7  1   uniform      0.9180
# 1657      brute         40            7  1  distance      0.9207
# 1658      brute         40            7  2   uniform      0.9141
# 1659      brute         40            7  2  distance      0.9156
# 1660      brute         40            7  5   uniform      0.9115
# 1661      brute         40            7  5  distance      0.9132
# 1662      brute         40            8  1   uniform      0.9168
# 1663      brute         40            8  1  distance      0.9216
# 1664      brute         40            8  2   uniform      0.9131
# 1665      brute         40            8  2  distance      0.9162
# 1666      brute         40            8  5   uniform      0.9105
# 1667      brute         40            8  5  distance      0.9136
# 1668      brute         40            9  1   uniform      0.9165
# 1669      brute         40            9  1  distance      0.9220
# 1670      brute         40            9  2   uniform      0.9126
# 1671      brute         40            9  2  distance      0.9165
# 1672      brute         40            9  5   uniform      0.9114
# 1673      brute         40            9  5  distance      0.9135
# 1674      brute         45            1  1   uniform      0.9067
# 1675      brute         45            1  1  distance      0.9067
# 1676      brute         45            1  2   uniform      0.9026
# 1677      brute         45            1  2  distance      0.9026
# 1678      brute         45            1  5   uniform      0.9000
# 1679      brute         45            1  5  distance      0.9000
# 1680      brute         45            2  1   uniform      0.9108
# 1681      brute         45            2  1  distance      0.9069
# 1682      brute         45            2  2   uniform      0.9084
# 1683      brute         45            2  2  distance      0.9026
# 1684      brute         45            2  5   uniform      0.9064
# 1685      brute         45            2  5  distance      0.9000
# 1686      brute         45            3  1   uniform      0.9138
# 1687      brute         45            3  1  distance      0.9151
# 1688      brute         45            3  2   uniform      0.9084
# 1689      brute         45            3  2  distance      0.9097
# 1690      brute         45            3  5   uniform      0.9068
# 1691      brute         45            3  5  distance      0.9083
# 1692      brute         45            4  1   uniform      0.9154
# 1693      brute         45            4  1  distance      0.9157
# 1694      brute         45            4  2   uniform      0.9113
# 1695      brute         45            4  2  distance      0.9120
# 1696      brute         45            4  5   uniform      0.9097
# 1697      brute         45            4  5  distance      0.9094
# 1698      brute         45            5  1   uniform      0.9158
# 1699      brute         45            5  1  distance      0.9186
# 1700      brute         45            5  2   uniform      0.9124
# 1701      brute         45            5  2  distance      0.9132
# 1702      brute         45            5  5   uniform      0.9111
# 1703      brute         45            5  5  distance      0.9118
# 1704      brute         45            6  1   uniform      0.9147
# 1705      brute         45            6  1  distance      0.9199
# 1706      brute         45            6  2   uniform      0.9138
# 1707      brute         45            6  2  distance      0.9156
# 1708      brute         45            6  5   uniform      0.9105
# 1709      brute         45            6  5  distance      0.9131
# 1710      brute         45            7  1   uniform      0.9180
# 1711      brute         45            7  1  distance      0.9207
# 1712      brute         45            7  2   uniform      0.9141
# 1713      brute         45            7  2  distance      0.9156
# 1714      brute         45            7  5   uniform      0.9115
# 1715      brute         45            7  5  distance      0.9132
# 1716      brute         45            8  1   uniform      0.9168
# 1717      brute         45            8  1  distance      0.9216
# 1718      brute         45            8  2   uniform      0.9131
# 1719      brute         45            8  2  distance      0.9162
# 1720      brute         45            8  5   uniform      0.9105
# 1721      brute         45            8  5  distance      0.9136
# 1722      brute         45            9  1   uniform      0.9165
# 1723      brute         45            9  1  distance      0.9220
# 1724      brute         45            9  2   uniform      0.9126
# 1725      brute         45            9  2  distance      0.9165
# 1726      brute         45            9  5   uniform      0.9114
# 1727      brute         45            9  5  distance      0.9135

# %%
#Define model with the optimal parameter values
knn = metric = KNeighborsClassifier(n_neighbors = best_n, 
                               weights = best_w, 
                               algorithm = best_a, 
                               leaf_size = best_l, 
                               p = best_p)

# %%
# Hill climbing w/ KNN
new_Ind = []
cur_MaxScore = 0.0
col_num = len(features.columns)
col_Ind_Random = shuffle(range(0, col_num), random_state = 1)
features_array = features.values

for cur_f in range(col_num):
    new_Ind.append(col_Ind_Random[cur_f])
    newData = features_array[:, new_Ind]
    x_train, x_test, y_train, y_test = train_test_split(newData, target, test_size=0.2, random_state=1)
    fit = knn.fit(x_train, y_train)
    cur_Score = knn.score(x_test, y_test)
    
    if cur_Score < cur_MaxScore:
        new_Ind.remove(col_Ind_Random[cur_f])
    else:
        cur_MaxScore = cur_Score
        print ("Score with " + str(len(new_Ind)) + " selected features: " + str(cur_Score))
print("\nIndexs of the desired features")
print(new_Ind)
# Out:
# Score with 1 selected features: 0.8545
# Score with 2 selected features: 0.8575
# Score with 3 selected features: 0.9035
# Score with 4 selected features: 0.906
# Score with 5 selected features: 0.922
# Score with 6 selected features: 0.922
# Score with 7 selected features: 0.923
#
# Indexs of the desired features
# [2, 4, 6, 0, 7, 10, 5]

# %%
#Create new dataframe from hill climbing output
features_hc = pd.DataFrame()
for index in new_Ind:
    colName = features.columns[index]
    features_hc[colName] = features[colName]
features_hc.head(10)
# Out:
#           Between Street 1  Sign  Duration of Parking Event (in seconds)  \
# 5608179                  0     0                                      84
# 151998                   1     1                                    1316
# 2002710                  2     2                                      86
# 4391539                  3     3                                    1591
# 5213472                  4     4                                     138
# 7606655                  5     4                                    3571
# 9944558                  6     5                                    4071
# 3183941                  7     6                                    3396
# 10596686                 8     7                                     673
# 10738362                 9     6                                     155
#
#           Area Name  Street ID  Departure Hour  Side Of Street
# 5608179           0        614              19               4
# 151998            1       1285              20               2
# 2002710           2       1329              10               5
# 4391539           3        681              10               1
# 5213472           4       1171              17               1
# 7606655           5        123              11               3
# 9944558           6         16              11               4
# 3183941           0       1428              13               2
# 10596686          7        627               8               2
# 10738362          8       1323              17               2

# %%
#Fit the model with the dataset (New Hill Climbing Features)
bestModel = gs_KNN.fit(features_hc, target)
# Out:
# Fitting 2 folds for each of 1728 candidates, totalling 3456 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 840 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1290 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 1840 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 2490 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 3240 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 3456 out of 3456 | elapsed: 26.6min finished

# %%
#Find the best values for the  parameters of the model (Standard output) AFTER HILL CLIMBING
gs_KNN.best_params_
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 20,
#  'n_neighbors': 7,
#  'p': 1,
#  'weights': 'distance'}

# %%
#Find the best values for the  parameters of the model (Formatted output) AFTER HILL CLIMBING
best_n_hc = bestModel.best_estimator_.get_params()['n_neighbors']
best_w_hc = bestModel.best_estimator_.get_params()['weights']
best_a_hc =  bestModel.best_estimator_.get_params()['algorithm']
best_l_hc =  bestModel.best_estimator_.get_params()['leaf_size']
best_p_hc =  bestModel.best_estimator_.get_params()['p']

print('Best n_neighbors:', best_n_hc)
print('Best weights:', best_w_hc)
print('Best algorithm:', best_a_hc)
print('Best leaf_size:', best_l_hc)
print('Best p:', best_p_hc)
# Out:
# Best n_neighbors: 7
# Best weights: distance
# Best algorithm: auto
# Best leaf_size: 20
# Best p: 1

# %%
#Visualise the parameter configurations from fitting the model with the dataset AFTER HILL CLIMBING
results_KNN = pd.DataFrame(gs_KNN.cv_results_['params'])
results_KNN['test_score'] = gs_KNN.cv_results_['mean_test_score']
results_KNN
# Out:
#       algorithm  leaf_size  n_neighbors  p   weights  test_score
# 0          auto         10            1  1   uniform      0.8992
# 1          auto         10            1  1  distance      0.8992
# 2          auto         10            1  2   uniform      0.8922
# 3          auto         10            1  2  distance      0.8922
# 4          auto         10            1  5   uniform      0.8936
# 5          auto         10            1  5  distance      0.8936
# 6          auto         10            2  1   uniform      0.9074
# 7          auto         10            2  1  distance      0.8995
# 8          auto         10            2  2   uniform      0.9022
# 9          auto         10            2  2  distance      0.8922
# 10         auto         10            2  5   uniform      0.9012
# 11         auto         10            2  5  distance      0.8936
# 12         auto         10            3  1   uniform      0.9087
# 13         auto         10            3  1  distance      0.9100
# 14         auto         10            3  2   uniform      0.9056
# 15         auto         10            3  2  distance      0.9045
# 16         auto         10            3  5   uniform      0.9030
# 17         auto         10            3  5  distance      0.9009
# 18         auto         10            4  1   uniform      0.9131
# 19         auto         10            4  1  distance      0.9112
# 20         auto         10            4  2   uniform      0.9098
# 21         auto         10            4  2  distance      0.9073
# 22         auto         10            4  5   uniform      0.9078
# 23         auto         10            4  5  distance      0.9056
# 24         auto         10            5  1   uniform      0.9115
# 25         auto         10            5  1  distance      0.9138
# 26         auto         10            5  2   uniform      0.9079
# 27         auto         10            5  2  distance      0.9104
# 28         auto         10            5  5   uniform      0.9060
# 29         auto         10            5  5  distance      0.9065
# 30         auto         10            6  1   uniform      0.9141
# 31         auto         10            6  1  distance      0.9144
# 32         auto         10            6  2   uniform      0.9088
# 33         auto         10            6  2  distance      0.9116
# 34         auto         10            6  5   uniform      0.9071
# 35         auto         10            6  5  distance      0.9094
# 36         auto         10            7  1   uniform      0.9139
# 37         auto         10            7  1  distance      0.9168
# 38         auto         10            7  2   uniform      0.9097
# 39         auto         10            7  2  distance      0.9120
# 40         auto         10            7  5   uniform      0.9083
# 41         auto         10            7  5  distance      0.9100
# 42         auto         10            8  1   uniform      0.9157
# 43         auto         10            8  1  distance      0.9164
# 44         auto         10            8  2   uniform      0.9102
# 45         auto         10            8  2  distance      0.9130
# 46         auto         10            8  5   uniform      0.9106
# 47         auto         10            8  5  distance      0.9102
# 48         auto         10            9  1   uniform      0.9133
# 49         auto         10            9  1  distance      0.9162
# 50         auto         10            9  2   uniform      0.9112
# 51         auto         10            9  2  distance      0.9124
# 52         auto         10            9  5   uniform      0.9108
# 53         auto         10            9  5  distance      0.9114
# 54         auto         15            1  1   uniform      0.8992
# 55         auto         15            1  1  distance      0.8992
# 56         auto         15            1  2   uniform      0.8922
# 57         auto         15            1  2  distance      0.8922
# 58         auto         15            1  5   uniform      0.8936
# 59         auto         15            1  5  distance      0.8936
# 60         auto         15            2  1   uniform      0.9074
# 61         auto         15            2  1  distance      0.8995
# 62         auto         15            2  2   uniform      0.9022
# 63         auto         15            2  2  distance      0.8922
# 64         auto         15            2  5   uniform      0.9012
# 65         auto         15            2  5  distance      0.8936
# 66         auto         15            3  1   uniform      0.9087
# 67         auto         15            3  1  distance      0.9100
# 68         auto         15            3  2   uniform      0.9056
# 69         auto         15            3  2  distance      0.9045
# 70         auto         15            3  5   uniform      0.9030
# 71         auto         15            3  5  distance      0.9009
# 72         auto         15            4  1   uniform      0.9131
# 73         auto         15            4  1  distance      0.9112
# 74         auto         15            4  2   uniform      0.9098
# 75         auto         15            4  2  distance      0.9073
# 76         auto         15            4  5   uniform      0.9078
# 77         auto         15            4  5  distance      0.9056
# 78         auto         15            5  1   uniform      0.9115
# 79         auto         15            5  1  distance      0.9138
# 80         auto         15            5  2   uniform      0.9079
# 81         auto         15            5  2  distance      0.9104
# 82         auto         15            5  5   uniform      0.9060
# 83         auto         15            5  5  distance      0.9065
# 84         auto         15            6  1   uniform      0.9141
# 85         auto         15            6  1  distance      0.9144
# 86         auto         15            6  2   uniform      0.9088
# 87         auto         15            6  2  distance      0.9116
# 88         auto         15            6  5   uniform      0.9071
# 89         auto         15            6  5  distance      0.9094
# 90         auto         15            7  1   uniform      0.9139
# 91         auto         15            7  1  distance      0.9168
# 92         auto         15            7  2   uniform      0.9097
# 93         auto         15            7  2  distance      0.9120
# 94         auto         15            7  5   uniform      0.9083
# 95         auto         15            7  5  distance      0.9100
# 96         auto         15            8  1   uniform      0.9157
# 97         auto         15            8  1  distance      0.9164
# 98         auto         15            8  2   uniform      0.9102
# 99         auto         15            8  2  distance      0.9130
# 100        auto         15            8  5   uniform      0.9106
# 101        auto         15            8  5  distance      0.9102
# 102        auto         15            9  1   uniform      0.9133
# 103        auto         15            9  1  distance      0.9162
# 104        auto         15            9  2   uniform      0.9112
# 105        auto         15            9  2  distance      0.9124
# 106        auto         15            9  5   uniform      0.9108
# 107        auto         15            9  5  distance      0.9114
# 108        auto         20            1  1   uniform      0.8989
# 109        auto         20            1  1  distance      0.8989
# 110        auto         20            1  2   uniform      0.8922
# 111        auto         20            1  2  distance      0.8922
# 112        auto         20            1  5   uniform      0.8936
# 113        auto         20            1  5  distance      0.8936
# 114        auto         20            2  1   uniform      0.9074
# 115        auto         20            2  1  distance      0.8995
# 116        auto         20            2  2   uniform      0.9022
# 117        auto         20            2  2  distance      0.8922
# 118        auto         20            2  5   uniform      0.9012
# 119        auto         20            2  5  distance      0.8936
# 120        auto         20            3  1   uniform      0.9087
# 121        auto         20            3  1  distance      0.9099
# 122        auto         20            3  2   uniform      0.9056
# 123        auto         20            3  2  distance      0.9045
# 124        auto         20            3  5   uniform      0.9030
# 125        auto         20            3  5  distance      0.9009
# 126        auto         20            4  1   uniform      0.9131
# 127        auto         20            4  1  distance      0.9112
# 128        auto         20            4  2   uniform      0.9098
# 129        auto         20            4  2  distance      0.9073
# 130        auto         20            4  5   uniform      0.9078
# 131        auto         20            4  5  distance      0.9056
# 132        auto         20            5  1   uniform      0.9113
# 133        auto         20            5  1  distance      0.9135
# 134        auto         20            5  2   uniform      0.9079
# 135        auto         20            5  2  distance      0.9104
# 136        auto         20            5  5   uniform      0.9060
# 137        auto         20            5  5  distance      0.9065
# 138        auto         20            6  1   uniform      0.9142
# 139        auto         20            6  1  distance      0.9144
# 140        auto         20            6  2   uniform      0.9088
# 141        auto         20            6  2  distance      0.9116
# 142        auto         20            6  5   uniform      0.9071
# 143        auto         20            6  5  distance      0.9094
# 144        auto         20            7  1   uniform      0.9139
# 145        auto         20            7  1  distance      0.9169
# 146        auto         20            7  2   uniform      0.9097
# 147        auto         20            7  2  distance      0.9120
# 148        auto         20            7  5   uniform      0.9083
# 149        auto         20            7  5  distance      0.9100
# 150        auto         20            8  1   uniform      0.9158
# 151        auto         20            8  1  distance      0.9164
# 152        auto         20            8  2   uniform      0.9102
# 153        auto         20            8  2  distance      0.9131
# 154        auto         20            8  5   uniform      0.9106
# 155        auto         20            8  5  distance      0.9102
# 156        auto         20            9  1   uniform      0.9134
# 157        auto         20            9  1  distance      0.9162
# 158        auto         20            9  2   uniform      0.9112
# 159        auto         20            9  2  distance      0.9124
# 160        auto         20            9  5   uniform      0.9108
# 161        auto         20            9  5  distance      0.9114
# 162        auto         25            1  1   uniform      0.8989
# 163        auto         25            1  1  distance      0.8989
# 164        auto         25            1  2   uniform      0.8922
# 165        auto         25            1  2  distance      0.8922
# 166        auto         25            1  5   uniform      0.8936
# 167        auto         25            1  5  distance      0.8936
# 168        auto         25            2  1   uniform      0.9074
# 169        auto         25            2  1  distance      0.8995
# 170        auto         25            2  2   uniform      0.9022
# 171        auto         25            2  2  distance      0.8922
# 172        auto         25            2  5   uniform      0.9012
# 173        auto         25            2  5  distance      0.8936
# 174        auto         25            3  1   uniform      0.9087
# 175        auto         25            3  1  distance      0.9099
# 176        auto         25            3  2   uniform      0.9056
# 177        auto         25            3  2  distance      0.9045
# 178        auto         25            3  5   uniform      0.9030
# 179        auto         25            3  5  distance      0.9009
# 180        auto         25            4  1   uniform      0.9131
# 181        auto         25            4  1  distance      0.9112
# 182        auto         25            4  2   uniform      0.9098
# 183        auto         25            4  2  distance      0.9073
# 184        auto         25            4  5   uniform      0.9078
# 185        auto         25            4  5  distance      0.9056
# 186        auto         25            5  1   uniform      0.9113
# 187        auto         25            5  1  distance      0.9135
# 188        auto         25            5  2   uniform      0.9079
# 189        auto         25            5  2  distance      0.9104
# 190        auto         25            5  5   uniform      0.9060
# 191        auto         25            5  5  distance      0.9065
# 192        auto         25            6  1   uniform      0.9142
# 193        auto         25            6  1  distance      0.9144
# 194        auto         25            6  2   uniform      0.9088
# 195        auto         25            6  2  distance      0.9116
# 196        auto         25            6  5   uniform      0.9071
# 197        auto         25            6  5  distance      0.9094
# 198        auto         25            7  1   uniform      0.9139
# 199        auto         25            7  1  distance      0.9169
# 200        auto         25            7  2   uniform      0.9097
# 201        auto         25            7  2  distance      0.9120
# 202        auto         25            7  5   uniform      0.9083
# 203        auto         25            7  5  distance      0.9100
# 204        auto         25            8  1   uniform      0.9158
# 205        auto         25            8  1  distance      0.9164
# 206        auto         25            8  2   uniform      0.9102
# 207        auto         25            8  2  distance      0.9131
# 208        auto         25            8  5   uniform      0.9106
# 209        auto         25            8  5  distance      0.9102
# 210        auto         25            9  1   uniform      0.9134
# 211        auto         25            9  1  distance      0.9162
# 212        auto         25            9  2   uniform      0.9112
# 213        auto         25            9  2  distance      0.9124
# 214        auto         25            9  5   uniform      0.9108
# 215        auto         25            9  5  distance      0.9114
# 216        auto         30            1  1   uniform      0.8989
# 217        auto         30            1  1  distance      0.8989
# 218        auto         30            1  2   uniform      0.8922
# 219        auto         30            1  2  distance      0.8922
# 220        auto         30            1  5   uniform      0.8936
# 221        auto         30            1  5  distance      0.8936
# 222        auto         30            2  1   uniform      0.9074
# 223        auto         30            2  1  distance      0.8995
# 224        auto         30            2  2   uniform      0.9022
# 225        auto         30            2  2  distance      0.8922
# 226        auto         30            2  5   uniform      0.9012
# 227        auto         30            2  5  distance      0.8936
# 228        auto         30            3  1   uniform      0.9087
# 229        auto         30            3  1  distance      0.9099
# 230        auto         30            3  2   uniform      0.9056
# 231        auto         30            3  2  distance      0.9045
# 232        auto         30            3  5   uniform      0.9030
# 233        auto         30            3  5  distance      0.9009
# 234        auto         30            4  1   uniform      0.9131
# 235        auto         30            4  1  distance      0.9112
# 236        auto         30            4  2   uniform      0.9098
# 237        auto         30            4  2  distance      0.9073
# 238        auto         30            4  5   uniform      0.9078
# 239        auto         30            4  5  distance      0.9056
# 240        auto         30            5  1   uniform      0.9113
# 241        auto         30            5  1  distance      0.9135
# 242        auto         30            5  2   uniform      0.9079
# 243        auto         30            5  2  distance      0.9104
# 244        auto         30            5  5   uniform      0.9060
# 245        auto         30            5  5  distance      0.9065
# 246        auto         30            6  1   uniform      0.9142
# 247        auto         30            6  1  distance      0.9144
# 248        auto         30            6  2   uniform      0.9088
# 249        auto         30            6  2  distance      0.9116
# 250        auto         30            6  5   uniform      0.9071
# 251        auto         30            6  5  distance      0.9094
# 252        auto         30            7  1   uniform      0.9139
# 253        auto         30            7  1  distance      0.9169
# 254        auto         30            7  2   uniform      0.9097
# 255        auto         30            7  2  distance      0.9120
# 256        auto         30            7  5   uniform      0.9083
# 257        auto         30            7  5  distance      0.9100
# 258        auto         30            8  1   uniform      0.9158
# 259        auto         30            8  1  distance      0.9164
# 260        auto         30            8  2   uniform      0.9102
# 261        auto         30            8  2  distance      0.9131
# 262        auto         30            8  5   uniform      0.9106
# 263        auto         30            8  5  distance      0.9102
# 264        auto         30            9  1   uniform      0.9134
# 265        auto         30            9  1  distance      0.9162
# 266        auto         30            9  2   uniform      0.9112
# 267        auto         30            9  2  distance      0.9124
# 268        auto         30            9  5   uniform      0.9108
# 269        auto         30            9  5  distance      0.9114
# 270        auto         35            1  1   uniform      0.8989
# 271        auto         35            1  1  distance      0.8989
# 272        auto         35            1  2   uniform      0.8922
# 273        auto         35            1  2  distance      0.8922
# 274        auto         35            1  5   uniform      0.8936
# 275        auto         35            1  5  distance      0.8936
# 276        auto         35            2  1   uniform      0.9074
# 277        auto         35            2  1  distance      0.8995
# 278        auto         35            2  2   uniform      0.9022
# 279        auto         35            2  2  distance      0.8922
# 280        auto         35            2  5   uniform      0.9012
# 281        auto         35            2  5  distance      0.8936
# 282        auto         35            3  1   uniform      0.9087
# 283        auto         35            3  1  distance      0.9099
# 284        auto         35            3  2   uniform      0.9056
# 285        auto         35            3  2  distance      0.9045
# 286        auto         35            3  5   uniform      0.9030
# 287        auto         35            3  5  distance      0.9009
# 288        auto         35            4  1   uniform      0.9131
# 289        auto         35            4  1  distance      0.9112
# 290        auto         35            4  2   uniform      0.9098
# 291        auto         35            4  2  distance      0.9073
# 292        auto         35            4  5   uniform      0.9078
# 293        auto         35            4  5  distance      0.9056
# 294        auto         35            5  1   uniform      0.9113
# 295        auto         35            5  1  distance      0.9135
# 296        auto         35            5  2   uniform      0.9079
# 297        auto         35            5  2  distance      0.9104
# 298        auto         35            5  5   uniform      0.9060
# 299        auto         35            5  5  distance      0.9065
# 300        auto         35            6  1   uniform      0.9142
# 301        auto         35            6  1  distance      0.9144
# 302        auto         35            6  2   uniform      0.9088
# 303        auto         35            6  2  distance      0.9116
# 304        auto         35            6  5   uniform      0.9071
# 305        auto         35            6  5  distance      0.9094
# 306        auto         35            7  1   uniform      0.9139
# 307        auto         35            7  1  distance      0.9169
# 308        auto         35            7  2   uniform      0.9097
# 309        auto         35            7  2  distance      0.9120
# 310        auto         35            7  5   uniform      0.9083
# 311        auto         35            7  5  distance      0.9100
# 312        auto         35            8  1   uniform      0.9158
# 313        auto         35            8  1  distance      0.9164
# 314        auto         35            8  2   uniform      0.9102
# 315        auto         35            8  2  distance      0.9131
# 316        auto         35            8  5   uniform      0.9106
# 317        auto         35            8  5  distance      0.9102
# 318        auto         35            9  1   uniform      0.9134
# 319        auto         35            9  1  distance      0.9162
# 320        auto         35            9  2   uniform      0.9112
# 321        auto         35            9  2  distance      0.9124
# 322        auto         35            9  5   uniform      0.9108
# 323        auto         35            9  5  distance      0.9114
# 324        auto         40            1  1   uniform      0.8989
# 325        auto         40            1  1  distance      0.8989
# 326        auto         40            1  2   uniform      0.8922
# 327        auto         40            1  2  distance      0.8922
# 328        auto         40            1  5   uniform      0.8936
# 329        auto         40            1  5  distance      0.8936
# 330        auto         40            2  1   uniform      0.9072
# 331        auto         40            2  1  distance      0.8995
# 332        auto         40            2  2   uniform      0.9022
# 333        auto         40            2  2  distance      0.8922
# 334        auto         40            2  5   uniform      0.9012
# 335        auto         40            2  5  distance      0.8936
# 336        auto         40            3  1   uniform      0.9087
# 337        auto         40            3  1  distance      0.9100
# 338        auto         40            3  2   uniform      0.9056
# 339        auto         40            3  2  distance      0.9045
# 340        auto         40            3  5   uniform      0.9030
# 341        auto         40            3  5  distance      0.9009
# 342        auto         40            4  1   uniform      0.9131
# 343        auto         40            4  1  distance      0.9114
# 344        auto         40            4  2   uniform      0.9098
# 345        auto         40            4  2  distance      0.9073
# 346        auto         40            4  5   uniform      0.9078
# 347        auto         40            4  5  distance      0.9056
# 348        auto         40            5  1   uniform      0.9111
# 349        auto         40            5  1  distance      0.9134
# 350        auto         40            5  2   uniform      0.9080
# 351        auto         40            5  2  distance      0.9104
# 352        auto         40            5  5   uniform      0.9060
# 353        auto         40            5  5  distance      0.9065
# 354        auto         40            6  1   uniform      0.9143
# 355        auto         40            6  1  distance      0.9149
# 356        auto         40            6  2   uniform      0.9088
# 357        auto         40            6  2  distance      0.9116
# 358        auto         40            6  5   uniform      0.9071
# 359        auto         40            6  5  distance      0.9094
# 360        auto         40            7  1   uniform      0.9138
# 361        auto         40            7  1  distance      0.9169
# 362        auto         40            7  2   uniform      0.9097
# 363        auto         40            7  2  distance      0.9120
# 364        auto         40            7  5   uniform      0.9083
# 365        auto         40            7  5  distance      0.9100
# 366        auto         40            8  1   uniform      0.9157
# 367        auto         40            8  1  distance      0.9165
# 368        auto         40            8  2   uniform      0.9102
# 369        auto         40            8  2  distance      0.9130
# 370        auto         40            8  5   uniform      0.9106
# 371        auto         40            8  5  distance      0.9102
# 372        auto         40            9  1   uniform      0.9135
# 373        auto         40            9  1  distance      0.9164
# 374        auto         40            9  2   uniform      0.9112
# 375        auto         40            9  2  distance      0.9124
# 376        auto         40            9  5   uniform      0.9108
# 377        auto         40            9  5  distance      0.9114
# 378        auto         45            1  1   uniform      0.8989
# 379        auto         45            1  1  distance      0.8989
# 380        auto         45            1  2   uniform      0.8922
# 381        auto         45            1  2  distance      0.8922
# 382        auto         45            1  5   uniform      0.8936
# 383        auto         45            1  5  distance      0.8936
# 384        auto         45            2  1   uniform      0.9072
# 385        auto         45            2  1  distance      0.8995
# 386        auto         45            2  2   uniform      0.9022
# 387        auto         45            2  2  distance      0.8922
# 388        auto         45            2  5   uniform      0.9012
# 389        auto         45            2  5  distance      0.8936
# 390        auto         45            3  1   uniform      0.9087
# 391        auto         45            3  1  distance      0.9100
# 392        auto         45            3  2   uniform      0.9056
# 393        auto         45            3  2  distance      0.9045
# 394        auto         45            3  5   uniform      0.9030
# 395        auto         45            3  5  distance      0.9009
# 396        auto         45            4  1   uniform      0.9131
# 397        auto         45            4  1  distance      0.9114
# 398        auto         45            4  2   uniform      0.9098
# 399        auto         45            4  2  distance      0.9073
# 400        auto         45            4  5   uniform      0.9078
# 401        auto         45            4  5  distance      0.9056
# 402        auto         45            5  1   uniform      0.9111
# 403        auto         45            5  1  distance      0.9134
# 404        auto         45            5  2   uniform      0.9080
# 405        auto         45            5  2  distance      0.9104
# 406        auto         45            5  5   uniform      0.9060
# 407        auto         45            5  5  distance      0.9065
# 408        auto         45            6  1   uniform      0.9143
# 409        auto         45            6  1  distance      0.9149
# 410        auto         45            6  2   uniform      0.9088
# 411        auto         45            6  2  distance      0.9116
# 412        auto         45            6  5   uniform      0.9071
# 413        auto         45            6  5  distance      0.9094
# 414        auto         45            7  1   uniform      0.9138
# 415        auto         45            7  1  distance      0.9169
# 416        auto         45            7  2   uniform      0.9097
# 417        auto         45            7  2  distance      0.9120
# 418        auto         45            7  5   uniform      0.9083
# 419        auto         45            7  5  distance      0.9100
# 420        auto         45            8  1   uniform      0.9157
# 421        auto         45            8  1  distance      0.9165
# 422        auto         45            8  2   uniform      0.9102
# 423        auto         45            8  2  distance      0.9130
# 424        auto         45            8  5   uniform      0.9106
# 425        auto         45            8  5  distance      0.9102
# 426        auto         45            9  1   uniform      0.9135
# 427        auto         45            9  1  distance      0.9164
# 428        auto         45            9  2   uniform      0.9112
# 429        auto         45            9  2  distance      0.9124
# 430        auto         45            9  5   uniform      0.9108
# 431        auto         45            9  5  distance      0.9114
# 432   ball_tree         10            1  1   uniform      0.8992
# 433   ball_tree         10            1  1  distance      0.8992
# 434   ball_tree         10            1  2   uniform      0.8922
# 435   ball_tree         10            1  2  distance      0.8922
# 436   ball_tree         10            1  5   uniform      0.8936
# 437   ball_tree         10            1  5  distance      0.8936
# 438   ball_tree         10            2  1   uniform      0.9073
# 439   ball_tree         10            2  1  distance      0.8995
# 440   ball_tree         10            2  2   uniform      0.9022
# 441   ball_tree         10            2  2  distance      0.8922
# 442   ball_tree         10            2  5   uniform      0.9012
# 443   ball_tree         10            2  5  distance      0.8936
# 444   ball_tree         10            3  1   uniform      0.9087
# 445   ball_tree         10            3  1  distance      0.9099
# 446   ball_tree         10            3  2   uniform      0.9056
# 447   ball_tree         10            3  2  distance      0.9045
# 448   ball_tree         10            3  5   uniform      0.9030
# 449   ball_tree         10            3  5  distance      0.9009
# 450   ball_tree         10            4  1   uniform      0.9130
# 451   ball_tree         10            4  1  distance      0.9114
# 452   ball_tree         10            4  2   uniform      0.9098
# 453   ball_tree         10            4  2  distance      0.9073
# 454   ball_tree         10            4  5   uniform      0.9078
# 455   ball_tree         10            4  5  distance      0.9056
# 456   ball_tree         10            5  1   uniform      0.9111
# 457   ball_tree         10            5  1  distance      0.9134
# 458   ball_tree         10            5  2   uniform      0.9079
# 459   ball_tree         10            5  2  distance      0.9104
# 460   ball_tree         10            5  5   uniform      0.9060
# 461   ball_tree         10            5  5  distance      0.9065
# 462   ball_tree         10            6  1   uniform      0.9140
# 463   ball_tree         10            6  1  distance      0.9146
# 464   ball_tree         10            6  2   uniform      0.9088
# 465   ball_tree         10            6  2  distance      0.9116
# 466   ball_tree         10            6  5   uniform      0.9071
# 467   ball_tree         10            6  5  distance      0.9094
# 468   ball_tree         10            7  1   uniform      0.9140
# 469   ball_tree         10            7  1  distance      0.9168
# 470   ball_tree         10            7  2   uniform      0.9097
# 471   ball_tree         10            7  2  distance      0.9120
# 472   ball_tree         10            7  5   uniform      0.9083
# 473   ball_tree         10            7  5  distance      0.9100
# 474   ball_tree         10            8  1   uniform      0.9157
# 475   ball_tree         10            8  1  distance      0.9165
# 476   ball_tree         10            8  2   uniform      0.9102
# 477   ball_tree         10            8  2  distance      0.9131
# 478   ball_tree         10            8  5   uniform      0.9106
# 479   ball_tree         10            8  5  distance      0.9102
# 480   ball_tree         10            9  1   uniform      0.9134
# 481   ball_tree         10            9  1  distance      0.9163
# 482   ball_tree         10            9  2   uniform      0.9112
# 483   ball_tree         10            9  2  distance      0.9124
# 484   ball_tree         10            9  5   uniform      0.9108
# 485   ball_tree         10            9  5  distance      0.9114
# 486   ball_tree         15            1  1   uniform      0.8992
# 487   ball_tree         15            1  1  distance      0.8992
# 488   ball_tree         15            1  2   uniform      0.8922
# 489   ball_tree         15            1  2  distance      0.8922
# 490   ball_tree         15            1  5   uniform      0.8936
# 491   ball_tree         15            1  5  distance      0.8936
# 492   ball_tree         15            2  1   uniform      0.9073
# 493   ball_tree         15            2  1  distance      0.8995
# 494   ball_tree         15            2  2   uniform      0.9022
# 495   ball_tree         15            2  2  distance      0.8922
# 496   ball_tree         15            2  5   uniform      0.9012
# 497   ball_tree         15            2  5  distance      0.8936
# 498   ball_tree         15            3  1   uniform      0.9087
# 499   ball_tree         15            3  1  distance      0.9099
# 500   ball_tree         15            3  2   uniform      0.9056
# 501   ball_tree         15            3  2  distance      0.9045
# 502   ball_tree         15            3  5   uniform      0.9030
# 503   ball_tree         15            3  5  distance      0.9009
# 504   ball_tree         15            4  1   uniform      0.9130
# 505   ball_tree         15            4  1  distance      0.9114
# 506   ball_tree         15            4  2   uniform      0.9098
# 507   ball_tree         15            4  2  distance      0.9073
# 508   ball_tree         15            4  5   uniform      0.9078
# 509   ball_tree         15            4  5  distance      0.9056
# 510   ball_tree         15            5  1   uniform      0.9111
# 511   ball_tree         15            5  1  distance      0.9134
# 512   ball_tree         15            5  2   uniform      0.9079
# 513   ball_tree         15            5  2  distance      0.9104
# 514   ball_tree         15            5  5   uniform      0.9060
# 515   ball_tree         15            5  5  distance      0.9065
# 516   ball_tree         15            6  1   uniform      0.9140
# 517   ball_tree         15            6  1  distance      0.9146
# 518   ball_tree         15            6  2   uniform      0.9088
# 519   ball_tree         15            6  2  distance      0.9116
# 520   ball_tree         15            6  5   uniform      0.9071
# 521   ball_tree         15            6  5  distance      0.9094
# 522   ball_tree         15            7  1   uniform      0.9140
# 523   ball_tree         15            7  1  distance      0.9168
# 524   ball_tree         15            7  2   uniform      0.9097
# 525   ball_tree         15            7  2  distance      0.9120
# 526   ball_tree         15            7  5   uniform      0.9083
# 527   ball_tree         15            7  5  distance      0.9100
# 528   ball_tree         15            8  1   uniform      0.9157
# 529   ball_tree         15            8  1  distance      0.9165
# 530   ball_tree         15            8  2   uniform      0.9102
# 531   ball_tree         15            8  2  distance      0.9131
# 532   ball_tree         15            8  5   uniform      0.9106
# 533   ball_tree         15            8  5  distance      0.9102
# 534   ball_tree         15            9  1   uniform      0.9134
# 535   ball_tree         15            9  1  distance      0.9163
# 536   ball_tree         15            9  2   uniform      0.9112
# 537   ball_tree         15            9  2  distance      0.9124
# 538   ball_tree         15            9  5   uniform      0.9108
# 539   ball_tree         15            9  5  distance      0.9114
# 540   ball_tree         20            1  1   uniform      0.8989
# 541   ball_tree         20            1  1  distance      0.8989
# 542   ball_tree         20            1  2   uniform      0.8922
# 543   ball_tree         20            1  2  distance      0.8922
# 544   ball_tree         20            1  5   uniform      0.8936
# 545   ball_tree         20            1  5  distance      0.8936
# 546   ball_tree         20            2  1   uniform      0.9073
# 547   ball_tree         20            2  1  distance      0.8995
# 548   ball_tree         20            2  2   uniform      0.9022
# 549   ball_tree         20            2  2  distance      0.8922
# 550   ball_tree         20            2  5   uniform      0.9012
# 551   ball_tree         20            2  5  distance      0.8936
# 552   ball_tree         20            3  1   uniform      0.9088
# 553   ball_tree         20            3  1  distance      0.9101
# 554   ball_tree         20            3  2   uniform      0.9056
# 555   ball_tree         20            3  2  distance      0.9045
# 556   ball_tree         20            3  5   uniform      0.9030
# 557   ball_tree         20            3  5  distance      0.9009
# 558   ball_tree         20            4  1   uniform      0.9132
# 559   ball_tree         20            4  1  distance      0.9114
# 560   ball_tree         20            4  2   uniform      0.9098
# 561   ball_tree         20            4  2  distance      0.9073
# 562   ball_tree         20            4  5   uniform      0.9078
# 563   ball_tree         20            4  5  distance      0.9056
# 564   ball_tree         20            5  1   uniform      0.9110
# 565   ball_tree         20            5  1  distance      0.9134
# 566   ball_tree         20            5  2   uniform      0.9079
# 567   ball_tree         20            5  2  distance      0.9104
# 568   ball_tree         20            5  5   uniform      0.9060
# 569   ball_tree         20            5  5  distance      0.9065
# 570   ball_tree         20            6  1   uniform      0.9139
# 571   ball_tree         20            6  1  distance      0.9144
# 572   ball_tree         20            6  2   uniform      0.9088
# 573   ball_tree         20            6  2  distance      0.9116
# 574   ball_tree         20            6  5   uniform      0.9071
# 575   ball_tree         20            6  5  distance      0.9094
# 576   ball_tree         20            7  1   uniform      0.9141
# 577   ball_tree         20            7  1  distance      0.9169
# 578   ball_tree         20            7  2   uniform      0.9097
# 579   ball_tree         20            7  2  distance      0.9120
# 580   ball_tree         20            7  5   uniform      0.9083
# 581   ball_tree         20            7  5  distance      0.9100
# 582   ball_tree         20            8  1   uniform      0.9158
# 583   ball_tree         20            8  1  distance      0.9164
# 584   ball_tree         20            8  2   uniform      0.9102
# 585   ball_tree         20            8  2  distance      0.9131
# 586   ball_tree         20            8  5   uniform      0.9106
# 587   ball_tree         20            8  5  distance      0.9102
# 588   ball_tree         20            9  1   uniform      0.9133
# 589   ball_tree         20            9  1  distance      0.9162
# 590   ball_tree         20            9  2   uniform      0.9112
# 591   ball_tree         20            9  2  distance      0.9124
# 592   ball_tree         20            9  5   uniform      0.9108
# 593   ball_tree         20            9  5  distance      0.9114
# 594   ball_tree         25            1  1   uniform      0.8989
# 595   ball_tree         25            1  1  distance      0.8989
# 596   ball_tree         25            1  2   uniform      0.8922
# 597   ball_tree         25            1  2  distance      0.8922
# 598   ball_tree         25            1  5   uniform      0.8936
# 599   ball_tree         25            1  5  distance      0.8936
# 600   ball_tree         25            2  1   uniform      0.9073
# 601   ball_tree         25            2  1  distance      0.8995
# 602   ball_tree         25            2  2   uniform      0.9022
# 603   ball_tree         25            2  2  distance      0.8922
# 604   ball_tree         25            2  5   uniform      0.9012
# 605   ball_tree         25            2  5  distance      0.8936
# 606   ball_tree         25            3  1   uniform      0.9088
# 607   ball_tree         25            3  1  distance      0.9101
# 608   ball_tree         25            3  2   uniform      0.9056
# 609   ball_tree         25            3  2  distance      0.9045
# 610   ball_tree         25            3  5   uniform      0.9030
# 611   ball_tree         25            3  5  distance      0.9009
# 612   ball_tree         25            4  1   uniform      0.9132
# 613   ball_tree         25            4  1  distance      0.9114
# 614   ball_tree         25            4  2   uniform      0.9098
# 615   ball_tree         25            4  2  distance      0.9073
# 616   ball_tree         25            4  5   uniform      0.9078
# 617   ball_tree         25            4  5  distance      0.9056
# 618   ball_tree         25            5  1   uniform      0.9110
# 619   ball_tree         25            5  1  distance      0.9134
# 620   ball_tree         25            5  2   uniform      0.9079
# 621   ball_tree         25            5  2  distance      0.9104
# 622   ball_tree         25            5  5   uniform      0.9060
# 623   ball_tree         25            5  5  distance      0.9065
# 624   ball_tree         25            6  1   uniform      0.9139
# 625   ball_tree         25            6  1  distance      0.9144
# 626   ball_tree         25            6  2   uniform      0.9088
# 627   ball_tree         25            6  2  distance      0.9116
# 628   ball_tree         25            6  5   uniform      0.9071
# 629   ball_tree         25            6  5  distance      0.9094
# 630   ball_tree         25            7  1   uniform      0.9141
# 631   ball_tree         25            7  1  distance      0.9169
# 632   ball_tree         25            7  2   uniform      0.9097
# 633   ball_tree         25            7  2  distance      0.9120
# 634   ball_tree         25            7  5   uniform      0.9083
# 635   ball_tree         25            7  5  distance      0.9100
# 636   ball_tree         25            8  1   uniform      0.9158
# 637   ball_tree         25            8  1  distance      0.9164
# 638   ball_tree         25            8  2   uniform      0.9102
# 639   ball_tree         25            8  2  distance      0.9131
# 640   ball_tree         25            8  5   uniform      0.9106
# 641   ball_tree         25            8  5  distance      0.9102
# 642   ball_tree         25            9  1   uniform      0.9133
# 643   ball_tree         25            9  1  distance      0.9162
# 644   ball_tree         25            9  2   uniform      0.9112
# 645   ball_tree         25            9  2  distance      0.9124
# 646   ball_tree         25            9  5   uniform      0.9108
# 647   ball_tree         25            9  5  distance      0.9114
# 648   ball_tree         30            1  1   uniform      0.8989
# 649   ball_tree         30            1  1  distance      0.8989
# 650   ball_tree         30            1  2   uniform      0.8922
# 651   ball_tree         30            1  2  distance      0.8922
# 652   ball_tree         30            1  5   uniform      0.8936
# 653   ball_tree         30            1  5  distance      0.8936
# 654   ball_tree         30            2  1   uniform      0.9073
# 655   ball_tree         30            2  1  distance      0.8995
# 656   ball_tree         30            2  2   uniform      0.9022
# 657   ball_tree         30            2  2  distance      0.8922
# 658   ball_tree         30            2  5   uniform      0.9012
# 659   ball_tree         30            2  5  distance      0.8936
# 660   ball_tree         30            3  1   uniform      0.9088
# 661   ball_tree         30            3  1  distance      0.9101
# 662   ball_tree         30            3  2   uniform      0.9056
# 663   ball_tree         30            3  2  distance      0.9045
# 664   ball_tree         30            3  5   uniform      0.9030
# 665   ball_tree         30            3  5  distance      0.9009
# 666   ball_tree         30            4  1   uniform      0.9132
# 667   ball_tree         30            4  1  distance      0.9114
# 668   ball_tree         30            4  2   uniform      0.9098
# 669   ball_tree         30            4  2  distance      0.9073
# 670   ball_tree         30            4  5   uniform      0.9078
# 671   ball_tree         30            4  5  distance      0.9056
# 672   ball_tree         30            5  1   uniform      0.9110
# 673   ball_tree         30            5  1  distance      0.9134
# 674   ball_tree         30            5  2   uniform      0.9079
# 675   ball_tree         30            5  2  distance      0.9104
# 676   ball_tree         30            5  5   uniform      0.9060
# 677   ball_tree         30            5  5  distance      0.9065
# 678   ball_tree         30            6  1   uniform      0.9139
# 679   ball_tree         30            6  1  distance      0.9144
# 680   ball_tree         30            6  2   uniform      0.9088
# 681   ball_tree         30            6  2  distance      0.9116
# 682   ball_tree         30            6  5   uniform      0.9071
# 683   ball_tree         30            6  5  distance      0.9094
# 684   ball_tree         30            7  1   uniform      0.9141
# 685   ball_tree         30            7  1  distance      0.9169
# 686   ball_tree         30            7  2   uniform      0.9097
# 687   ball_tree         30            7  2  distance      0.9120
# 688   ball_tree         30            7  5   uniform      0.9083
# 689   ball_tree         30            7  5  distance      0.9100
# 690   ball_tree         30            8  1   uniform      0.9158
# 691   ball_tree         30            8  1  distance      0.9164
# 692   ball_tree         30            8  2   uniform      0.9102
# 693   ball_tree         30            8  2  distance      0.9131
# 694   ball_tree         30            8  5   uniform      0.9106
# 695   ball_tree         30            8  5  distance      0.9102
# 696   ball_tree         30            9  1   uniform      0.9133
# 697   ball_tree         30            9  1  distance      0.9162
# 698   ball_tree         30            9  2   uniform      0.9112
# 699   ball_tree         30            9  2  distance      0.9124
# 700   ball_tree         30            9  5   uniform      0.9108
# 701   ball_tree         30            9  5  distance      0.9114
# 702   ball_tree         35            1  1   uniform      0.8989
# 703   ball_tree         35            1  1  distance      0.8989
# 704   ball_tree         35            1  2   uniform      0.8922
# 705   ball_tree         35            1  2  distance      0.8922
# 706   ball_tree         35            1  5   uniform      0.8936
# 707   ball_tree         35            1  5  distance      0.8936
# 708   ball_tree         35            2  1   uniform      0.9073
# 709   ball_tree         35            2  1  distance      0.8995
# 710   ball_tree         35            2  2   uniform      0.9022
# 711   ball_tree         35            2  2  distance      0.8922
# 712   ball_tree         35            2  5   uniform      0.9012
# 713   ball_tree         35            2  5  distance      0.8936
# 714   ball_tree         35            3  1   uniform      0.9088
# 715   ball_tree         35            3  1  distance      0.9101
# 716   ball_tree         35            3  2   uniform      0.9056
# 717   ball_tree         35            3  2  distance      0.9045
# 718   ball_tree         35            3  5   uniform      0.9030
# 719   ball_tree         35            3  5  distance      0.9009
# 720   ball_tree         35            4  1   uniform      0.9132
# 721   ball_tree         35            4  1  distance      0.9114
# 722   ball_tree         35            4  2   uniform      0.9098
# 723   ball_tree         35            4  2  distance      0.9073
# 724   ball_tree         35            4  5   uniform      0.9078
# 725   ball_tree         35            4  5  distance      0.9056
# 726   ball_tree         35            5  1   uniform      0.9110
# 727   ball_tree         35            5  1  distance      0.9134
# 728   ball_tree         35            5  2   uniform      0.9079
# 729   ball_tree         35            5  2  distance      0.9104
# 730   ball_tree         35            5  5   uniform      0.9060
# 731   ball_tree         35            5  5  distance      0.9065
# 732   ball_tree         35            6  1   uniform      0.9139
# 733   ball_tree         35            6  1  distance      0.9144
# 734   ball_tree         35            6  2   uniform      0.9088
# 735   ball_tree         35            6  2  distance      0.9116
# 736   ball_tree         35            6  5   uniform      0.9071
# ...
# 1482      brute         25            5  1   uniform      0.9110
# 1483      brute         25            5  1  distance      0.9133
# 1484      brute         25            5  2   uniform      0.9079
# 1485      brute         25            5  2  distance      0.9104
# 1486      brute         25            5  5   uniform      0.9060
# 1487      brute         25            5  5  distance      0.9065
# 1488      brute         25            6  1   uniform      0.9145
# 1489      brute         25            6  1  distance      0.9148
# 1490      brute         25            6  2   uniform      0.9088
# 1491      brute         25            6  2  distance      0.9116
# 1492      brute         25            6  5   uniform      0.9071
# 1493      brute         25            6  5  distance      0.9094
# 1494      brute         25            7  1   uniform      0.9141
# 1495      brute         25            7  1  distance      0.9169
# 1496      brute         25            7  2   uniform      0.9097
# 1497      brute         25            7  2  distance      0.9120
# 1498      brute         25            7  5   uniform      0.9083
# 1499      brute         25            7  5  distance      0.9100
# 1500      brute         25            8  1   uniform      0.9156
# 1501      brute         25            8  1  distance      0.9165
# 1502      brute         25            8  2   uniform      0.9102
# 1503      brute         25            8  2  distance      0.9131
# 1504      brute         25            8  5   uniform      0.9106
# 1505      brute         25            8  5  distance      0.9102
# 1506      brute         25            9  1   uniform      0.9136
# 1507      brute         25            9  1  distance      0.9164
# 1508      brute         25            9  2   uniform      0.9112
# 1509      brute         25            9  2  distance      0.9124
# 1510      brute         25            9  5   uniform      0.9108
# 1511      brute         25            9  5  distance      0.9114
# 1512      brute         30            1  1   uniform      0.8995
# 1513      brute         30            1  1  distance      0.8995
# 1514      brute         30            1  2   uniform      0.8922
# 1515      brute         30            1  2  distance      0.8922
# 1516      brute         30            1  5   uniform      0.8936
# 1517      brute         30            1  5  distance      0.8936
# 1518      brute         30            2  1   uniform      0.9075
# 1519      brute         30            2  1  distance      0.8995
# 1520      brute         30            2  2   uniform      0.9022
# 1521      brute         30            2  2  distance      0.8922
# 1522      brute         30            2  5   uniform      0.9012
# 1523      brute         30            2  5  distance      0.8936
# 1524      brute         30            3  1   uniform      0.9085
# 1525      brute         30            3  1  distance      0.9098
# 1526      brute         30            3  2   uniform      0.9056
# 1527      brute         30            3  2  distance      0.9045
# 1528      brute         30            3  5   uniform      0.9030
# 1529      brute         30            3  5  distance      0.9009
# 1530      brute         30            4  1   uniform      0.9130
# 1531      brute         30            4  1  distance      0.9115
# 1532      brute         30            4  2   uniform      0.9098
# 1533      brute         30            4  2  distance      0.9073
# 1534      brute         30            4  5   uniform      0.9078
# 1535      brute         30            4  5  distance      0.9056
# 1536      brute         30            5  1   uniform      0.9110
# 1537      brute         30            5  1  distance      0.9133
# 1538      brute         30            5  2   uniform      0.9079
# 1539      brute         30            5  2  distance      0.9104
# 1540      brute         30            5  5   uniform      0.9060
# 1541      brute         30            5  5  distance      0.9065
# 1542      brute         30            6  1   uniform      0.9145
# 1543      brute         30            6  1  distance      0.9148
# 1544      brute         30            6  2   uniform      0.9088
# 1545      brute         30            6  2  distance      0.9116
# 1546      brute         30            6  5   uniform      0.9071
# 1547      brute         30            6  5  distance      0.9094
# 1548      brute         30            7  1   uniform      0.9141
# 1549      brute         30            7  1  distance      0.9169
# 1550      brute         30            7  2   uniform      0.9097
# 1551      brute         30            7  2  distance      0.9120
# 1552      brute         30            7  5   uniform      0.9083
# 1553      brute         30            7  5  distance      0.9100
# 1554      brute         30            8  1   uniform      0.9156
# 1555      brute         30            8  1  distance      0.9165
# 1556      brute         30            8  2   uniform      0.9102
# 1557      brute         30            8  2  distance      0.9131
# 1558      brute         30            8  5   uniform      0.9106
# 1559      brute         30            8  5  distance      0.9102
# 1560      brute         30            9  1   uniform      0.9136
# 1561      brute         30            9  1  distance      0.9164
# 1562      brute         30            9  2   uniform      0.9112
# 1563      brute         30            9  2  distance      0.9124
# 1564      brute         30            9  5   uniform      0.9108
# 1565      brute         30            9  5  distance      0.9114
# 1566      brute         35            1  1   uniform      0.8995
# 1567      brute         35            1  1  distance      0.8995
# 1568      brute         35            1  2   uniform      0.8922
# 1569      brute         35            1  2  distance      0.8922
# 1570      brute         35            1  5   uniform      0.8936
# 1571      brute         35            1  5  distance      0.8936
# 1572      brute         35            2  1   uniform      0.9075
# 1573      brute         35            2  1  distance      0.8995
# 1574      brute         35            2  2   uniform      0.9022
# 1575      brute         35            2  2  distance      0.8922
# 1576      brute         35            2  5   uniform      0.9012
# 1577      brute         35            2  5  distance      0.8936
# 1578      brute         35            3  1   uniform      0.9085
# 1579      brute         35            3  1  distance      0.9098
# 1580      brute         35            3  2   uniform      0.9056
# 1581      brute         35            3  2  distance      0.9045
# 1582      brute         35            3  5   uniform      0.9030
# 1583      brute         35            3  5  distance      0.9009
# 1584      brute         35            4  1   uniform      0.9130
# 1585      brute         35            4  1  distance      0.9115
# 1586      brute         35            4  2   uniform      0.9098
# 1587      brute         35            4  2  distance      0.9073
# 1588      brute         35            4  5   uniform      0.9078
# 1589      brute         35            4  5  distance      0.9056
# 1590      brute         35            5  1   uniform      0.9110
# 1591      brute         35            5  1  distance      0.9133
# 1592      brute         35            5  2   uniform      0.9079
# 1593      brute         35            5  2  distance      0.9104
# 1594      brute         35            5  5   uniform      0.9060
# 1595      brute         35            5  5  distance      0.9065
# 1596      brute         35            6  1   uniform      0.9145
# 1597      brute         35            6  1  distance      0.9148
# 1598      brute         35            6  2   uniform      0.9088
# 1599      brute         35            6  2  distance      0.9116
# 1600      brute         35            6  5   uniform      0.9071
# 1601      brute         35            6  5  distance      0.9094
# 1602      brute         35            7  1   uniform      0.9141
# 1603      brute         35            7  1  distance      0.9169
# 1604      brute         35            7  2   uniform      0.9097
# 1605      brute         35            7  2  distance      0.9120
# 1606      brute         35            7  5   uniform      0.9083
# 1607      brute         35            7  5  distance      0.9100
# 1608      brute         35            8  1   uniform      0.9156
# 1609      brute         35            8  1  distance      0.9165
# 1610      brute         35            8  2   uniform      0.9102
# 1611      brute         35            8  2  distance      0.9131
# 1612      brute         35            8  5   uniform      0.9106
# 1613      brute         35            8  5  distance      0.9102
# 1614      brute         35            9  1   uniform      0.9136
# 1615      brute         35            9  1  distance      0.9164
# 1616      brute         35            9  2   uniform      0.9112
# 1617      brute         35            9  2  distance      0.9124
# 1618      brute         35            9  5   uniform      0.9108
# 1619      brute         35            9  5  distance      0.9114
# 1620      brute         40            1  1   uniform      0.8995
# 1621      brute         40            1  1  distance      0.8995
# 1622      brute         40            1  2   uniform      0.8922
# 1623      brute         40            1  2  distance      0.8922
# 1624      brute         40            1  5   uniform      0.8936
# 1625      brute         40            1  5  distance      0.8936
# 1626      brute         40            2  1   uniform      0.9075
# 1627      brute         40            2  1  distance      0.8995
# 1628      brute         40            2  2   uniform      0.9022
# 1629      brute         40            2  2  distance      0.8922
# 1630      brute         40            2  5   uniform      0.9012
# 1631      brute         40            2  5  distance      0.8936
# 1632      brute         40            3  1   uniform      0.9085
# 1633      brute         40            3  1  distance      0.9098
# 1634      brute         40            3  2   uniform      0.9056
# 1635      brute         40            3  2  distance      0.9045
# 1636      brute         40            3  5   uniform      0.9030
# 1637      brute         40            3  5  distance      0.9009
# 1638      brute         40            4  1   uniform      0.9130
# 1639      brute         40            4  1  distance      0.9115
# 1640      brute         40            4  2   uniform      0.9098
# 1641      brute         40            4  2  distance      0.9073
# 1642      brute         40            4  5   uniform      0.9078
# 1643      brute         40            4  5  distance      0.9056
# 1644      brute         40            5  1   uniform      0.9110
# 1645      brute         40            5  1  distance      0.9133
# 1646      brute         40            5  2   uniform      0.9079
# 1647      brute         40            5  2  distance      0.9104
# 1648      brute         40            5  5   uniform      0.9060
# 1649      brute         40            5  5  distance      0.9065
# 1650      brute         40            6  1   uniform      0.9145
# 1651      brute         40            6  1  distance      0.9148
# 1652      brute         40            6  2   uniform      0.9088
# 1653      brute         40            6  2  distance      0.9116
# 1654      brute         40            6  5   uniform      0.9071
# 1655      brute         40            6  5  distance      0.9094
# 1656      brute         40            7  1   uniform      0.9141
# 1657      brute         40            7  1  distance      0.9169
# 1658      brute         40            7  2   uniform      0.9097
# 1659      brute         40            7  2  distance      0.9120
# 1660      brute         40            7  5   uniform      0.9083
# 1661      brute         40            7  5  distance      0.9100
# 1662      brute         40            8  1   uniform      0.9156
# 1663      brute         40            8  1  distance      0.9165
# 1664      brute         40            8  2   uniform      0.9102
# 1665      brute         40            8  2  distance      0.9131
# 1666      brute         40            8  5   uniform      0.9106
# 1667      brute         40            8  5  distance      0.9102
# 1668      brute         40            9  1   uniform      0.9136
# 1669      brute         40            9  1  distance      0.9164
# 1670      brute         40            9  2   uniform      0.9112
# 1671      brute         40            9  2  distance      0.9124
# 1672      brute         40            9  5   uniform      0.9108
# 1673      brute         40            9  5  distance      0.9114
# 1674      brute         45            1  1   uniform      0.8995
# 1675      brute         45            1  1  distance      0.8995
# 1676      brute         45            1  2   uniform      0.8922
# 1677      brute         45            1  2  distance      0.8922
# 1678      brute         45            1  5   uniform      0.8936
# 1679      brute         45            1  5  distance      0.8936
# 1680      brute         45            2  1   uniform      0.9075
# 1681      brute         45            2  1  distance      0.8995
# 1682      brute         45            2  2   uniform      0.9022
# 1683      brute         45            2  2  distance      0.8922
# 1684      brute         45            2  5   uniform      0.9012
# 1685      brute         45            2  5  distance      0.8936
# 1686      brute         45            3  1   uniform      0.9085
# 1687      brute         45            3  1  distance      0.9098
# 1688      brute         45            3  2   uniform      0.9056
# 1689      brute         45            3  2  distance      0.9045
# 1690      brute         45            3  5   uniform      0.9030
# 1691      brute         45            3  5  distance      0.9009
# 1692      brute         45            4  1   uniform      0.9130
# 1693      brute         45            4  1  distance      0.9115
# 1694      brute         45            4  2   uniform      0.9098
# 1695      brute         45            4  2  distance      0.9073
# 1696      brute         45            4  5   uniform      0.9078
# 1697      brute         45            4  5  distance      0.9056
# 1698      brute         45            5  1   uniform      0.9110
# 1699      brute         45            5  1  distance      0.9133
# 1700      brute         45            5  2   uniform      0.9079
# 1701      brute         45            5  2  distance      0.9104
# 1702      brute         45            5  5   uniform      0.9060
# 1703      brute         45            5  5  distance      0.9065
# 1704      brute         45            6  1   uniform      0.9145
# 1705      brute         45            6  1  distance      0.9148
# 1706      brute         45            6  2   uniform      0.9088
# 1707      brute         45            6  2  distance      0.9116
# 1708      brute         45            6  5   uniform      0.9071
# 1709      brute         45            6  5  distance      0.9094
# 1710      brute         45            7  1   uniform      0.9141
# 1711      brute         45            7  1  distance      0.9169
# 1712      brute         45            7  2   uniform      0.9097
# 1713      brute         45            7  2  distance      0.9120
# 1714      brute         45            7  5   uniform      0.9083
# 1715      brute         45            7  5  distance      0.9100
# 1716      brute         45            8  1   uniform      0.9156
# 1717      brute         45            8  1  distance      0.9165
# 1718      brute         45            8  2   uniform      0.9102
# 1719      brute         45            8  2  distance      0.9131
# 1720      brute         45            8  5   uniform      0.9106
# 1721      brute         45            8  5  distance      0.9102
# 1722      brute         45            9  1   uniform      0.9136
# 1723      brute         45            9  1  distance      0.9164
# 1724      brute         45            9  2   uniform      0.9112
# 1725      brute         45            9  2  distance      0.9124
# 1726      brute         45            9  5   uniform      0.9108
# 1727      brute         45            9  5  distance      0.9114

# %%
#Re-Define model with the optimal parameter values AFTER HILL CLIMBING
knn = metric = KNeighborsClassifier(n_neighbors = best_n_hc, 
                               weights = best_w_hc, 
                               algorithm = best_a_hc, 
                               leaf_size = best_l_hc, 
                               p = best_p_hc)

# %%
#Defining training and testing groups
x_train, x_test, y_train, y_test = train_test_split(features_hc, target, test_size = 0.5, random_state = 4)

#Training the model previously defined
knn.fit(x_train, y_train)

#Obtaining and printing out results from the model (Confusion Matrix)
predicted = knn.predict(x_test)
cm = confusion_matrix(y_test,predicted)
print("Confusion Matrix")
print(cm)

#Printing the numerical result of the confusion matrix
print("\n[Train/test split] score: {:.5f}".format(knn.score(x_test, y_test)))
# Out:
# Confusion Matrix
# [[4165  154]
#  [ 282  399]]
#
# [Train/test split] score: 0.91280

# %%
#Repeat with KFold - creating groups
kf = KFold(n_splits = 5, random_state = 4, shuffle = True)

#Print statement for debuging
# for train_index, test_index in kf.split(features_hc):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     x_train, x_test = features_hc.iloc[train_index], features_hc.iloc[test_index]
#     y_train, y_test = target.iloc[train_index], target.iloc[test_index]

#Repeat with KFold - Training model (previously defined) and obtaining its output
kFoldTotal = 0
for k, (train_index, test_index) in enumerate(kf.split(features_hc)):
    x_train, x_test = features_hc.iloc[train_index], features_hc.iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]
    knn.fit(x_train, y_train)
    kFoldTotal += knn.score(x_test, y_test)
    print("[fold {0}] score: {1:.5f}".format(k, knn.score(x_test, y_test)))

#Printing out the results
roundedTotal = round(kFoldTotal/5, 5)
print("\nKNN mean score [5 folds] = " + str(roundedTotal))
# Out:
# [fold 0] score: 0.91550
# [fold 1] score: 0.92350
# [fold 2] score: 0.91550
# [fold 3] score: 0.92250
# [fold 4] score: 0.92900
#
# KNN mean score [5 folds] = 0.9212
