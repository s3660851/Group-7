# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
import math

# %%
# cd D:\Group-7

# %%
#retrieving data
parkingdata = pd.read_csv("parking-small.csv")
parkingdata.shape
# Out:
# (999, 13)

# %%
parkingdata.head(5)
# Out:
#          Area Name      Street Name  Between Street 1    Between Street 2  \
# 0  Victoria Market    THERRY STREET      QUEEN STREET    ELIZABETH STREET
# 1         Courtney      PEEL STREET  O'CONNELL STREET  QUEENSBERRY STREET
# 2  Victoria Market  FRANKLIN STREET      QUEEN STREET    ELIZABETH STREET
# 3        Chinatown  LONSDALE STREET   SWANSTON STREET      RUSSELL STREET
# 4        Southbank     GRANT STREET      WELLS STREET       ST KILDA ROAD
#
#    Side Of Street Street Marker            Arrival Time  \
# 0               4         7021S  24/08/2012 11:34:36 AM
# 1               2         5398E  17/03/2012 01:07:59 PM
# 2               1         C6624  17/02/2012 01:54:34 PM
# 3               3         2888N  27/11/2011 03:03:19 PM
# 4               3         9870N  21/04/2012 03:08:32 PM
#
#            Departure Time  Duration of Parking Event (in seconds)  \
# 0  24/08/2012 12:49:09 PM                                    4473
# 1  17/03/2012 01:10:06 PM                                     127
# 2  17/02/2012 02:20:17 PM                                    1543
# 3  27/11/2011 04:02:41 PM                                    3562
# 4  21/04/2012 05:06:00 PM                                    7048
#
#                           Sign  In Violation?  Street ID  Device ID
# 0      LZ 15M M-SAT 7:30-19:30              1       1346       3770
# 1  1/2P A RPE M-SUN 7:30-23:00              0       1101       3472
# 2      2P MTR M-SAT 7:30-20:30              0        681       2805
# 3            1P SUN 7:30-18:30              0        894       1770
# 4    2P TKT A M-SAT 7:30-18:30              0        728       4584

# %%
parkingdata.tail(5)
# Out:
#            Area Name      Street Name    Between Street 1    Between Street 2  \
# 994  Princes Theatre    SPRING STREET     LONSDALE STREET    Lt BOURKE STREET
# 995         Hardware  LONSDALE STREET        QUEEN STREET    ELIZABETH STREET
# 996      Magistrates  LA TROBE STREET         KING STREET      WILLIAM STREET
# 997          Regency   RUSSELL STREET     LA TROBE STREET  Lt LONSDALE STREET
# 998      Magistrates   SPENCER STREET  Lt LONSDALE STREET     LONSDALE STREET
#
#      Side Of Street Street Marker            Arrival Time  \
# 994               5           65W  27/08/2012 05:42:47 PM
# 995               1         C2912  04/04/2012 01:52:51 PM
# 996               4         3891S  14/09/2012 04:59:28 PM
# 997               5          899W  02/11/2011 05:40:34 PM
# 998               5         1555W  22/05/2012 01:24:35 PM
#
#              Departure Time  Duration of Parking Event (in seconds)  \
# 994  27/08/2012 05:45:01 PM                                     134
# 995  04/04/2012 02:22:32 PM                                    1781
# 996  14/09/2012 05:03:19 PM                                     231
# 997  02/11/2011 08:30:00 PM                                   10166
# 998  22/05/2012 02:14:08 PM                                    2973
#
#                           Sign  In Violation?  Street ID  Device ID
# 994    LZ 15M M-SUN 7:30-19:30              0       1288       6986
# 995    1P MTR M-SAT 7:30-19:30              0        894       1941
# 996  2P TKT A M-SAT 7:30-20:30              0        856       2157
# 997    3P MTR M-SAT 7:30-20:30              0       1221        468
# 998    2P TKT A M-F 9:30-16:00              0       1285        951

# %% [markdown]
# ## Data Wrangling

# %%
#checking the datatype of all the features
parkingdata.dtypes
# Out:
# Area Name                                 object
# Street Name                               object
# Between Street 1                          object
# Between Street 2                          object
# Side Of Street                             int64
# Street Marker                             object
# Arrival Time                              object
# Departure Time                            object
# Duration of Parking Event (in seconds)     int64
# Sign                                      object
# In Violation?                              int64
# Street ID                                  int64
# Device ID                                  int64
# dtype: object

# %%
#Checking values of Area Name feature for typos
parkingdata['Area Name'].value_counts()
# Out:
# Queensberry        107
# Regency             75
# Titles              69
# Princes Theatre     67
# The Mac             66
# Victoria Market     63
# Southbank           58
# Hyatt               50
# Chinatown           49
# Hardware            47
# Spencer             42
# Rialto              39
# Courtney            39
# County              38
# City Square         36
# Magistrates         36
# RACV                34
# Banks               32
# Supreme             21
# Jolimont            20
# Tavistock            7
# Docklands            3
# West Melbourne       1
# Name: Area Name, dtype: int64

# %%
#Converting all the feature attributes to uppercase for uniformity

parkingdata['Area Name'] = parkingdata['Area Name'].str.upper()
parkingdata['Street Name'] = parkingdata['Street Name'].str.upper()
parkingdata['Between Street 1'] = parkingdata['Between Street 1'].str.upper()
parkingdata['Between Street 2'] = parkingdata['Between Street 2'].str.upper()
parkingdata['Street Marker'] = parkingdata['Street Marker'].str.upper()
parkingdata['Sign'] = parkingdata['Sign'].str.upper()

parkingdata.head(5)
# Out:
#          Area Name      Street Name  Between Street 1    Between Street 2  \
# 0  VICTORIA MARKET    THERRY STREET      QUEEN STREET    ELIZABETH STREET
# 1         COURTNEY      PEEL STREET  O'CONNELL STREET  QUEENSBERRY STREET
# 2  VICTORIA MARKET  FRANKLIN STREET      QUEEN STREET    ELIZABETH STREET
# 3        CHINATOWN  LONSDALE STREET   SWANSTON STREET      RUSSELL STREET
# 4        SOUTHBANK     GRANT STREET      WELLS STREET       ST KILDA ROAD
#
#    Side Of Street Street Marker            Arrival Time  \
# 0               4         7021S  24/08/2012 11:34:36 AM
# 1               2         5398E  17/03/2012 01:07:59 PM
# 2               1         C6624  17/02/2012 01:54:34 PM
# 3               3         2888N  27/11/2011 03:03:19 PM
# 4               3         9870N  21/04/2012 03:08:32 PM
#
#            Departure Time  Duration of Parking Event (in seconds)  \
# 0  24/08/2012 12:49:09 PM                                    4473
# 1  17/03/2012 01:10:06 PM                                     127
# 2  17/02/2012 02:20:17 PM                                    1543
# 3  27/11/2011 04:02:41 PM                                    3562
# 4  21/04/2012 05:06:00 PM                                    7048
#
#                           Sign  In Violation?  Street ID  Device ID
# 0      LZ 15M M-SAT 7:30-19:30              1       1346       3770
# 1  1/2P A RPE M-SUN 7:30-23:00              0       1101       3472
# 2      2P MTR M-SAT 7:30-20:30              0        681       2805
# 3            1P SUN 7:30-18:30              0        894       1770
# 4    2P TKT A M-SAT 7:30-18:30              0        728       4584

# %%
sns.boxplot(parkingdata['Duration of Parking Event (in seconds)'])

# %%
#Removing all redundant extra whitespaces
for x in parkingdata.columns:
    if parkingdata[x].dtype == object:
        parkingdata[x] = parkingdata[x].str.strip()

# %%
#Checking values of Street Name feature for typos
pd.set_option('display.max_rows', 10000)
parkingdata['Street Name'].value_counts()
# Out:
# LONSDALE STREET             97
# QUEEN STREET                73
# LA TROBE STREET             62
# RUSSELL STREET              58
# FRANKLIN STREET             52
# COLLINS STREET              52
# EXHIBITION STREET           47
# ELIZABETH STREET            47
# BOURKE STREET               47
# SPRING STREET               41
# LT LONSDALE STREET          37
# LT COLLINS STREET           29
# ERROL STREET                24
# WILLIAM STREET              21
# FLINDERS LANE               20
# KING STREET                 18
# LT BOURKE STREET            18
# THERRY STREET               17
# QUEENSBERRY STREET          17
# SPENCER STREET              15
# A'BECKETT STREET            14
# COVENTRY STREET             14
# VICTORIA STREET             13
# FLINDERS STREET             11
# O'CONNELL STREET            11
# CAPEL STREET                 9
# SOUTHBANK BOULEVARD          8
# ALBERT STREET                7
# DORCAS STREET                7
# COBDEN STREET                7
# WALSH STREET                 7
# GRANT STREET                 6
# LEVESON STREET               6
# KAVANAGH STREET              6
# WILLS STREET                 5
# HOWARD STREET                5
# CHETWYND STREET              5
# SWANSTON STREET              5
# BALSTON STREET               5
# FRANCIS STREET               5
# PEEL STREET                  5
# LANSDOWNE STREET             4
# DUDLEY STREET                4
# STURT STREET                 4
# WELLS STREET                 3
# CLARENDON STREET             3
# DODDS STREET                 3
# ST ANDREWS PLACE             3
# CATHEDRAL PLACE              2
# MARKET STREET                2
# MACKENZIE STREET             2
# JEFFCOTT STREET              2
# LT LA TROBE STREET           2
# CURZON STREET                1
# MILES STREET                 1
# ABBOTSFORD STREET            1
# EADES PLACE                  1
# BATMAN STREET                1
# LT DRYBURGH STREET SOUTH     1
# ANTHONY STREET               1
# CITY ROAD                    1
# GISBORNE STREET              1
# ROSSLYN STREET               1
# DRYBURGH STREET              1
# PRINCESS STREET              1
# Name: Street Name, dtype: int64

# %%
#Checking values of Between Street 1 feature for typos
parkingdata['Between Street 1'].value_counts()
# Out:
# QUEEN STREET           103
# KING STREET             92
# WILLIAM STREET          65
# QUEENSBERRY STREET      62
# RUSSELL STREET          57
# LT LONSDALE STREET      53
# SPENCER STREET          53
# SWANSTON STREET         45
# LONSDALE STREET         42
# EXHIBITION STREET       36
# LT COLLINS STREET       33
# VICTORIA STREET         29
# LT BOURKE STREET        28
# BOURKE STREET           23
# ELIZABETH STREET        22
# LA TROBE STREET         22
# COLLINS STREET          21
# FLINDERS LANE           19
# A'BECKETT STREET        18
# ERROL STREET            13
# WILLAM STREET           13
# FRANKLIN STREET         12
# WELLS STREET            11
# FLINDERS STREET         10
# O'CONNELL STREET         9
# COBDEN STREET            8
# DODDS STREET             8
# HOWARD STREET            7
# STURT STREET             7
# BALSTON STREET           6
# SOUTHBANK BOULEVARD      6
# THERRY STREET            6
# VICTORIA PARADE          6
# PEEL STREET              5
# CITY ROAD                5
# KINGS WAY                5
# ALBERT STREET            5
# ST KILDA ROAD            4
# WALSH STREET             3
# MACARTHUR STREET         3
# COVENTRY STREET          3
# LANSDOWNE STREET         3
# PELHAM STREET            3
# LOTHIAN STREET           2
# EADES STREET             2
# GISBORNE STREET          2
# HOTHAM STREET            1
# GIPPS STREET             1
# NICHOLSON STREET         1
# GRANT STREET             1
# GREY STREET              1
# MORRISON PLACE           1
# KAVANAGH STREET          1
# BATMAN STREET            1
# MOORE STREET             1
# Name: Between Street 1, dtype: int64

# %%
#Checking values of Between Street 1 feature for typos
parkingdata['Between Street 2'].value_counts()
# Out:
# ELIZABETH STREET      104
# VICTORIA STREET        86
# WILLIAM STREET         79
# QUEEN STREET           78
# EXHIBITION STREET      56
# LONSDALE STREET        54
# KING STREET            53
# LT BOURKE STREET       42
# SPRING STREET          36
# RUSSELL STREET         35
# COLLINS STREET         33
# FLINDERS LANE          31
# LA TROBE STREET        30
# BOURKE STREET          28
# LT LONSDALE STREET     27
# LT COLLINS STREET      23
# SWANSTON STREET        22
# FLINDERS STREET        19
# DODDS STREET           13
# LEVESON STREET         13
# ST KILDA ROAD          11
# WALSH STREET           10
# HAWKE STREET            8
# QUEENSBERRY STREET      8
# KAVANAGH STREET         8
# MILTON STREET           7
# POWER STREET            7
# A'BECKETT STREET        7
# LANSDOWNE STREET        6
# FRANKLIN STREET         6
# CAPEL STREET            6
# THERRY STREET           6
# CATHEDRAL PLACE         5
# MILES STREET            5
# WELLS STREET            5
# DUDLEY STREET           3
# STURT STREET            3
# DORCAS STREET           3
# SPENCER STREET          3
# EADES STREET            3
# CLARENDON STREET        2
# ELM STREET              2
# GRANT STREET            2
# FAWKNER STREET          1
# GEORGE STREET           1
# JEFFCOTT STREET         1
# HOTHAM STREET           1
# O'CONNELL STREET        1
# GIPPS STREET            1
# STANLEY STREET          1
# ABBOTSFORD STREET       1
# LOTHIAN STREET          1
# COBDEN STREET           1
# GISBORNE STREET         1
# Name: Between Street 2, dtype: int64

# %%
#check which columns have missing values
parkingdata.columns[parkingdata.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#converting object to datetime
parkingdata['Arrival Time'] = pd.to_datetime(parkingdata['Arrival Time'])
parkingdata['Departure Time'] = pd.to_datetime(parkingdata['Departure Time'])

# %%
#check if object has successfully been converted to datetime
parkingdata.dtypes
# Out:
# Area Name                                         object
# Street Name                                       object
# Between Street 1                                  object
# Between Street 2                                  object
# Side Of Street                                     int64
# Street Marker                                     object
# Arrival Time                              datetime64[ns]
# Departure Time                            datetime64[ns]
# Duration of Parking Event (in seconds)             int64
# Sign                                              object
# In Violation?                                      int64
# Street ID                                          int64
# Device ID                                          int64
# dtype: object

# %%
parkingdata.head(5)
# Out:
#          Area Name      Street Name  Between Street 1    Between Street 2  \
# 0  VICTORIA MARKET    THERRY STREET      QUEEN STREET    ELIZABETH STREET
# 1         COURTNEY      PEEL STREET  O'CONNELL STREET  QUEENSBERRY STREET
# 2  VICTORIA MARKET  FRANKLIN STREET      QUEEN STREET    ELIZABETH STREET
# 3        CHINATOWN  LONSDALE STREET   SWANSTON STREET      RUSSELL STREET
# 4        SOUTHBANK     GRANT STREET      WELLS STREET       ST KILDA ROAD
#
#    Side Of Street Street Marker        Arrival Time      Departure Time  \
# 0               4         7021S 2012-08-24 11:34:36 2012-08-24 12:49:09
# 1               2         5398E 2012-03-17 13:07:59 2012-03-17 13:10:06
# 2               1         C6624 2012-02-17 13:54:34 2012-02-17 14:20:17
# 3               3         2888N 2011-11-27 15:03:19 2011-11-27 16:02:41
# 4               3         9870N 2012-04-21 15:08:32 2012-04-21 17:06:00
#
#    Duration of Parking Event (in seconds)                         Sign  \
# 0                                    4473      LZ 15M M-SAT 7:30-19:30
# 1                                     127  1/2P A RPE M-SUN 7:30-23:00
# 2                                    1543      2P MTR M-SAT 7:30-20:30
# 3                                    3562            1P SUN 7:30-18:30
# 4                                    7048    2P TKT A M-SAT 7:30-18:30
#
#    In Violation?  Street ID  Device ID
# 0              1       1346       3770
# 1              0       1101       3472
# 2              0        681       2805
# 3              0        894       1770
# 4              0        728       4584

# %%
parkingdata.tail(5)
# Out:
#            Area Name      Street Name    Between Street 1    Between Street 2  \
# 994  PRINCES THEATRE    SPRING STREET     LONSDALE STREET    LT BOURKE STREET
# 995         HARDWARE  LONSDALE STREET        QUEEN STREET    ELIZABETH STREET
# 996      MAGISTRATES  LA TROBE STREET         KING STREET      WILLIAM STREET
# 997          REGENCY   RUSSELL STREET     LA TROBE STREET  LT LONSDALE STREET
# 998      MAGISTRATES   SPENCER STREET  LT LONSDALE STREET     LONSDALE STREET
#
#      Side Of Street Street Marker        Arrival Time      Departure Time  \
# 994               5           65W 2012-08-27 17:42:47 2012-08-27 17:45:01
# 995               1         C2912 2012-04-04 13:52:51 2012-04-04 14:22:32
# 996               4         3891S 2012-09-14 16:59:28 2012-09-14 17:03:19
# 997               5          899W 2011-02-11 17:40:34 2011-02-11 20:30:00
# 998               5         1555W 2012-05-22 13:24:35 2012-05-22 14:14:08
#
#      Duration of Parking Event (in seconds)                       Sign  \
# 994                                     134    LZ 15M M-SUN 7:30-19:30
# 995                                    1781    1P MTR M-SAT 7:30-19:30
# 996                                     231  2P TKT A M-SAT 7:30-20:30
# 997                                   10166    3P MTR M-SAT 7:30-20:30
# 998                                    2973    2P TKT A M-F 9:30-16:00
#
#      In Violation?  Street ID  Device ID
# 994              0       1288       6986
# 995              0        894       1941
# 996              0        856       2157
# 997              0       1221        468
# 998              0       1285        951

# %% [markdown]
# ### KNN Classification Model on Predicitive Analytics question 2

# %%
#Target field identification
duration = parkingdata['Duration of Parking Event (in seconds)'].copy()

print('Minimum parking duration (seconds): ' + str(duration.min()))
print('Maximum parking duration (seconds): ' + str(duration.max()))
print('\nMinimum parking duration (hour): ' + str(duration.min()/3600))
print('Maximum parking duration (hour): ' + str(duration.max()/3600))
print('\nMinimum parking duration (hour - truncated) < ' + str(math.trunc(duration.min()/3600) + 1))
print('Maximum parking duration (hour - truncated) < ' + str(math.trunc(duration.max()/3600) + 1))

static = 1
for record in duration.values:
    hour = 3600
    index = 0
    while static == 1:
        if record < hour:
            print("\nHour in seconds: " + str(record))
            record = math.trunc(record/3600) + 1
            print("Duration is under " + str(record) + " hours")
            duration.replace(duration[0], record)
            break
        else:
            hour += 3600
# target = duration.copy()
# target.head(10)
# Out:
# Minimum parking duration (seconds): 55
# Maximum parking duration (seconds): 43193
#
# Minimum parking duration (hour): 0.015277777777777777
# Maximum parking duration (hour): 11.998055555555556
#
# Minimum parking duration (hour - truncated) < 1
# Maximum parking duration (hour - truncated) < 12
#
# Hour in seconds: 4473
# Duration is under 2 hours
#
# Hour in seconds: 127
# Duration is under 1 hours
#
# Hour in seconds: 1543
# Duration is under 1 hours
#
# Hour in seconds: 3562
# Duration is under 1 hours
#
# Hour in seconds: 7048
# Duration is under 2 hours
#
# Hour in seconds: 1900
# Duration is under 1 hours
#
# Hour in seconds: 173
# Duration is under 1 hours
#
# Hour in seconds: 674
# Duration is under 1 hours
#
# Hour in seconds: 3597
# Duration is under 1 hours
#
# Hour in seconds: 1994
# Duration is under 1 hours
#
# Hour in seconds: 9125
# Duration is under 3 hours
#
# Hour in seconds: 6066
# Duration is under 2 hours
#
# Hour in seconds: 1136
# Duration is under 1 hours
#
# Hour in seconds: 107
# Duration is under 1 hours
#
# Hour in seconds: 116
# Duration is under 1 hours
#
# Hour in seconds: 9773
# Duration is under 3 hours
#
# Hour in seconds: 485
# Duration is under 1 hours
#
# Hour in seconds: 379
# Duration is under 1 hours
#
# Hour in seconds: 1934
# Duration is under 1 hours
#
# Hour in seconds: 1580
# Duration is under 1 hours
#
# Hour in seconds: 257
# Duration is under 1 hours
#
# Hour in seconds: 286
# Duration is under 1 hours
#
# Hour in seconds: 3009
# Duration is under 1 hours
#
# Hour in seconds: 11616
# Duration is under 4 hours
#
# Hour in seconds: 224
# Duration is under 1 hours
#
# Hour in seconds: 9233
# Duration is under 3 hours
#
# Hour in seconds: 1436
# Duration is under 1 hours
#
# Hour in seconds: 2206
# Duration is under 1 hours
#
# Hour in seconds: 2221
# Duration is under 1 hours
#
# Hour in seconds: 6882
# Duration is under 2 hours
#
# Hour in seconds: 4850
# Duration is under 2 hours
#
# Hour in seconds: 1432
# Duration is under 1 hours
#
# Hour in seconds: 2832
# Duration is under 1 hours
#
# Hour in seconds: 349
# Duration is under 1 hours
#
# Hour in seconds: 10780
# Duration is under 3 hours
#
# Hour in seconds: 526
# Duration is under 1 hours
#
# Hour in seconds: 215
# Duration is under 1 hours
#
# Hour in seconds: 492
# Duration is under 1 hours
#
# Hour in seconds: 591
# Duration is under 1 hours
#
# Hour in seconds: 7193
# Duration is under 2 hours
#
# Hour in seconds: 2036
# Duration is under 1 hours
#
# Hour in seconds: 1601
# Duration is under 1 hours
#
# Hour in seconds: 1590
# Duration is under 1 hours
#
# Hour in seconds: 5194
# Duration is under 2 hours
#
# Hour in seconds: 195
# Duration is under 1 hours
#
# Hour in seconds: 7692
# Duration is under 3 hours
#
# Hour in seconds: 192
# Duration is under 1 hours
#
# Hour in seconds: 310
# Duration is under 1 hours
#
# Hour in seconds: 10894
# Duration is under 4 hours
#
# Hour in seconds: 103
# Duration is under 1 hours
#
# Hour in seconds: 801
# Duration is under 1 hours
#
# Hour in seconds: 225
# Duration is under 1 hours
#
# Hour in seconds: 463
# Duration is under 1 hours
#
# Hour in seconds: 6100
# Duration is under 2 hours
#
# Hour in seconds: 1557
# Duration is under 1 hours
#
# Hour in seconds: 31011
# Duration is under 9 hours
#
# Hour in seconds: 4380
# Duration is under 2 hours
#
# Hour in seconds: 883
# Duration is under 1 hours
#
# Hour in seconds: 1776
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 254
# Duration is under 1 hours
#
# Hour in seconds: 208
# Duration is under 1 hours
#
# Hour in seconds: 63
# Duration is under 1 hours
#
# Hour in seconds: 7637
# Duration is under 3 hours
#
# Hour in seconds: 2012
# Duration is under 1 hours
#
# Hour in seconds: 441
# Duration is under 1 hours
#
# Hour in seconds: 2933
# Duration is under 1 hours
#
# Hour in seconds: 154
# Duration is under 1 hours
#
# Hour in seconds: 761
# Duration is under 1 hours
#
# Hour in seconds: 1816
# Duration is under 1 hours
#
# Hour in seconds: 3099
# Duration is under 1 hours
#
# Hour in seconds: 286
# Duration is under 1 hours
#
# Hour in seconds: 312
# Duration is under 1 hours
#
# Hour in seconds: 7968
# Duration is under 3 hours
#
# Hour in seconds: 4766
# Duration is under 2 hours
#
# Hour in seconds: 7165
# Duration is under 2 hours
#
# Hour in seconds: 950
# Duration is under 1 hours
#
# Hour in seconds: 7057
# Duration is under 2 hours
#
# Hour in seconds: 827
# Duration is under 1 hours
#
# Hour in seconds: 185
# Duration is under 1 hours
#
# Hour in seconds: 396
# Duration is under 1 hours
#
# Hour in seconds: 362
# Duration is under 1 hours
#
# Hour in seconds: 139
# Duration is under 1 hours
#
# Hour in seconds: 264
# Duration is under 1 hours
#
# Hour in seconds: 1736
# Duration is under 1 hours
#
# Hour in seconds: 2198
# Duration is under 1 hours
#
# Hour in seconds: 108
# Duration is under 1 hours
#
# Hour in seconds: 75
# Duration is under 1 hours
#
# Hour in seconds: 230
# Duration is under 1 hours
#
# Hour in seconds: 481
# Duration is under 1 hours
#
# Hour in seconds: 852
# Duration is under 1 hours
#
# Hour in seconds: 311
# Duration is under 1 hours
#
# Hour in seconds: 82
# Duration is under 1 hours
#
# Hour in seconds: 508
# Duration is under 1 hours
#
# Hour in seconds: 249
# Duration is under 1 hours
#
# Hour in seconds: 135
# Duration is under 1 hours
#
# Hour in seconds: 9167
# Duration is under 3 hours
#
# Hour in seconds: 683
# Duration is under 1 hours
#
# Hour in seconds: 979
# Duration is under 1 hours
#
# Hour in seconds: 617
# Duration is under 1 hours
#
# Hour in seconds: 3907
# Duration is under 2 hours
#
# Hour in seconds: 2151
# Duration is under 1 hours
#
# Hour in seconds: 4882
# Duration is under 2 hours
#
# Hour in seconds: 128
# Duration is under 1 hours
#
# Hour in seconds: 473
# Duration is under 1 hours
#
# Hour in seconds: 9527
# Duration is under 3 hours
#
# Hour in seconds: 2374
# Duration is under 1 hours
#
# Hour in seconds: 2580
# Duration is under 1 hours
#
# Hour in seconds: 220
# Duration is under 1 hours
#
# Hour in seconds: 426
# Duration is under 1 hours
#
# Hour in seconds: 352
# Duration is under 1 hours
#
# Hour in seconds: 3758
# Duration is under 2 hours
#
# Hour in seconds: 2759
# Duration is under 1 hours
#
# Hour in seconds: 3386
# Duration is under 1 hours
#
# Hour in seconds: 97
# Duration is under 1 hours
#
# Hour in seconds: 1178
# Duration is under 1 hours
#
# Hour in seconds: 938
# Duration is under 1 hours
#
# Hour in seconds: 6957
# Duration is under 2 hours
#
# Hour in seconds: 3116
# Duration is under 1 hours
#
# Hour in seconds: 1529
# Duration is under 1 hours
#
# Hour in seconds: 8394
# Duration is under 3 hours
#
# Hour in seconds: 256
# Duration is under 1 hours
#
# Hour in seconds: 1306
# Duration is under 1 hours
#
# Hour in seconds: 338
# Duration is under 1 hours
#
# Hour in seconds: 328
# Duration is under 1 hours
#
# Hour in seconds: 148
# Duration is under 1 hours
#
# Hour in seconds: 396
# Duration is under 1 hours
#
# Hour in seconds: 1870
# Duration is under 1 hours
#
# Hour in seconds: 991
# Duration is under 1 hours
#
# Hour in seconds: 4490
# Duration is under 2 hours
#
# Hour in seconds: 1258
# Duration is under 1 hours
#
# Hour in seconds: 402
# Duration is under 1 hours
#
# Hour in seconds: 572
# Duration is under 1 hours
#
# Hour in seconds: 65
# Duration is under 1 hours
#
# Hour in seconds: 7210
# Duration is under 3 hours
#
# Hour in seconds: 148
# Duration is under 1 hours
#
# Hour in seconds: 105
# Duration is under 1 hours
#
# Hour in seconds: 107
# Duration is under 1 hours
#
# Hour in seconds: 355
# Duration is under 1 hours
#
# Hour in seconds: 3736
# Duration is under 2 hours
#
# Hour in seconds: 123
# Duration is under 1 hours
#
# Hour in seconds: 2976
# Duration is under 1 hours
#
# Hour in seconds: 197
# Duration is under 1 hours
#
# Hour in seconds: 9857
# Duration is under 3 hours
#
# Hour in seconds: 2496
# Duration is under 1 hours
#
# Hour in seconds: 153
# Duration is under 1 hours
#
# Hour in seconds: 1338
# Duration is under 1 hours
#
# Hour in seconds: 73
# Duration is under 1 hours
#
# Hour in seconds: 741
# Duration is under 1 hours
#
# Hour in seconds: 294
# Duration is under 1 hours
#
# Hour in seconds: 7956
# Duration is under 3 hours
#
# Hour in seconds: 2779
# Duration is under 1 hours
#
# Hour in seconds: 2370
# Duration is under 1 hours
#
# Hour in seconds: 1172
# Duration is under 1 hours
#
# Hour in seconds: 1278
# Duration is under 1 hours
#
# Hour in seconds: 8853
# Duration is under 3 hours
#
# Hour in seconds: 368
# Duration is under 1 hours
#
# Hour in seconds: 2779
# Duration is under 1 hours
#
# Hour in seconds: 227
# Duration is under 1 hours
#
# Hour in seconds: 4072
# Duration is under 2 hours
#
# Hour in seconds: 339
# Duration is under 1 hours
#
# Hour in seconds: 2806
# Duration is under 1 hours
#
# Hour in seconds: 1548
# Duration is under 1 hours
#
# Hour in seconds: 2178
# Duration is under 1 hours
#
# Hour in seconds: 1347
# Duration is under 1 hours
#
# Hour in seconds: 648
# Duration is under 1 hours
#
# Hour in seconds: 125
# Duration is under 1 hours
#
# Hour in seconds: 3855
# Duration is under 2 hours
#
# Hour in seconds: 3102
# Duration is under 1 hours
#
# Hour in seconds: 1100
# Duration is under 1 hours
#
# Hour in seconds: 637
# Duration is under 1 hours
#
# Hour in seconds: 1079
# Duration is under 1 hours
#
# Hour in seconds: 657
# Duration is under 1 hours
#
# Hour in seconds: 3998
# Duration is under 2 hours
#
# Hour in seconds: 97
# Duration is under 1 hours
#
# Hour in seconds: 8240
# Duration is under 3 hours
#
# Hour in seconds: 1329
# Duration is under 1 hours
#
# Hour in seconds: 4914
# Duration is under 2 hours
#
# Hour in seconds: 6842
# Duration is under 2 hours
#
# Hour in seconds: 3852
# Duration is under 2 hours
#
# Hour in seconds: 452
# Duration is under 1 hours
#
# Hour in seconds: 1863
# Duration is under 1 hours
#
# Hour in seconds: 1292
# Duration is under 1 hours
#
# Hour in seconds: 106
# Duration is under 1 hours
#
# Hour in seconds: 96
# Duration is under 1 hours
#
# Hour in seconds: 453
# Duration is under 1 hours
#
# Hour in seconds: 11094
# Duration is under 4 hours
#
# Hour in seconds: 517
# Duration is under 1 hours
#
# Hour in seconds: 809
# Duration is under 1 hours
#
# Hour in seconds: 4010
# Duration is under 2 hours
#
# Hour in seconds: 2448
# Duration is under 1 hours
#
# Hour in seconds: 644
# Duration is under 1 hours
#
# Hour in seconds: 1255
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 82
# Duration is under 1 hours
#
# Hour in seconds: 6926
# Duration is under 2 hours
#
# Hour in seconds: 340
# Duration is under 1 hours
#
# Hour in seconds: 373
# Duration is under 1 hours
#
# Hour in seconds: 5463
# Duration is under 2 hours
#
# Hour in seconds: 2183
# Duration is under 1 hours
#
# Hour in seconds: 7397
# Duration is under 3 hours
#
# Hour in seconds: 653
# Duration is under 1 hours
#
# Hour in seconds: 76
# Duration is under 1 hours
#
# Hour in seconds: 2599
# Duration is under 1 hours
#
# Hour in seconds: 118
# Duration is under 1 hours
#
# Hour in seconds: 216
# Duration is under 1 hours
#
# Hour in seconds: 4476
# Duration is under 2 hours
#
# Hour in seconds: 1402
# Duration is under 1 hours
#
# Hour in seconds: 261
# Duration is under 1 hours
#
# Hour in seconds: 83
# Duration is under 1 hours
#
# Hour in seconds: 1653
# Duration is under 1 hours
#
# Hour in seconds: 1071
# Duration is under 1 hours
#
# Hour in seconds: 292
# Duration is under 1 hours
#
# Hour in seconds: 813
# Duration is under 1 hours
#
# Hour in seconds: 21915
# Duration is under 7 hours
#
# Hour in seconds: 2163
# Duration is under 1 hours
#
# Hour in seconds: 285
# Duration is under 1 hours
#
# Hour in seconds: 4264
# Duration is under 2 hours
#
# Hour in seconds: 108
# Duration is under 1 hours
#
# Hour in seconds: 117
# Duration is under 1 hours
#
# Hour in seconds: 39593
# Duration is under 11 hours
#
# Hour in seconds: 4987
# Duration is under 2 hours
#
# Hour in seconds: 5845
# Duration is under 2 hours
#
# Hour in seconds: 391
# Duration is under 1 hours
#
# Hour in seconds: 2960
# Duration is under 1 hours
#
# Hour in seconds: 837
# Duration is under 1 hours
#
# Hour in seconds: 2278
# Duration is under 1 hours
#
# Hour in seconds: 3633
# Duration is under 2 hours
#
# Hour in seconds: 80
# Duration is under 1 hours
#
# Hour in seconds: 648
# Duration is under 1 hours
#
# Hour in seconds: 61
# Duration is under 1 hours
#
# Hour in seconds: 102
# Duration is under 1 hours
#
# Hour in seconds: 1405
# Duration is under 1 hours
#
# Hour in seconds: 64
# Duration is under 1 hours
#
# Hour in seconds: 3272
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 2689
# Duration is under 1 hours
#
# Hour in seconds: 2325
# Duration is under 1 hours
#
# Hour in seconds: 3348
# Duration is under 1 hours
#
# Hour in seconds: 5260
# Duration is under 2 hours
#
# Hour in seconds: 211
# Duration is under 1 hours
#
# Hour in seconds: 2051
# Duration is under 1 hours
#
# Hour in seconds: 67
# Duration is under 1 hours
#
# Hour in seconds: 4161
# Duration is under 2 hours
#
# Hour in seconds: 302
# Duration is under 1 hours
#
# Hour in seconds: 485
# Duration is under 1 hours
#
# Hour in seconds: 55
# Duration is under 1 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 163
# Duration is under 1 hours
#
# Hour in seconds: 2235
# Duration is under 1 hours
#
# Hour in seconds: 3600
# Duration is under 2 hours
#
# Hour in seconds: 1104
# Duration is under 1 hours
#
# Hour in seconds: 577
# Duration is under 1 hours
#
# Hour in seconds: 1392
# Duration is under 1 hours
#
# Hour in seconds: 91
# Duration is under 1 hours
#
# Hour in seconds: 3282
# Duration is under 1 hours
#
# Hour in seconds: 6854
# Duration is under 2 hours
#
# Hour in seconds: 83
# Duration is under 1 hours
#
# Hour in seconds: 686
# Duration is under 1 hours
#
# Hour in seconds: 84
# Duration is under 1 hours
#
# Hour in seconds: 4912
# Duration is under 2 hours
#
# Hour in seconds: 507
# Duration is under 1 hours
#
# Hour in seconds: 3362
# Duration is under 1 hours
#
# Hour in seconds: 116
# Duration is under 1 hours
#
# Hour in seconds: 2133
# Duration is under 1 hours
#
# Hour in seconds: 1152
# Duration is under 1 hours
#
# Hour in seconds: 2101
# Duration is under 1 hours
#
# Hour in seconds: 64
# Duration is under 1 hours
#
# Hour in seconds: 1688
# Duration is under 1 hours
#
# Hour in seconds: 197
# Duration is under 1 hours
#
# Hour in seconds: 3852
# Duration is under 2 hours
#
# Hour in seconds: 299
# Duration is under 1 hours
#
# Hour in seconds: 2471
# Duration is under 1 hours
#
# Hour in seconds: 89
# Duration is under 1 hours
#
# Hour in seconds: 65
# Duration is under 1 hours
#
# Hour in seconds: 78
# Duration is under 1 hours
#
# Hour in seconds: 590
# Duration is under 1 hours
#
# Hour in seconds: 4004
# Duration is under 2 hours
#
# Hour in seconds: 1319
# Duration is under 1 hours
#
# Hour in seconds: 3351
# Duration is under 1 hours
#
# Hour in seconds: 3688
# Duration is under 2 hours
#
# Hour in seconds: 2298
# Duration is under 1 hours
#
# Hour in seconds: 313
# Duration is under 1 hours
#
# Hour in seconds: 341
# Duration is under 1 hours
#
# Hour in seconds: 3420
# Duration is under 1 hours
#
# Hour in seconds: 753
# Duration is under 1 hours
#
# Hour in seconds: 550
# Duration is under 1 hours
#
# Hour in seconds: 122
# Duration is under 1 hours
#
# Hour in seconds: 39592
# Duration is under 11 hours
#
# Hour in seconds: 5117
# Duration is under 2 hours
#
# Hour in seconds: 1947
# Duration is under 1 hours
#
# Hour in seconds: 2514
# Duration is under 1 hours
#
# Hour in seconds: 90
# Duration is under 1 hours
#
# Hour in seconds: 2206
# Duration is under 1 hours
#
# Hour in seconds: 63
# Duration is under 1 hours
#
# Hour in seconds: 303
# Duration is under 1 hours
#
# Hour in seconds: 2259
# Duration is under 1 hours
#
# Hour in seconds: 2178
# Duration is under 1 hours
#
# Hour in seconds: 416
# Duration is under 1 hours
#
# Hour in seconds: 3729
# Duration is under 2 hours
#
# Hour in seconds: 244
# Duration is under 1 hours
#
# Hour in seconds: 1479
# Duration is under 1 hours
#
# Hour in seconds: 153
# Duration is under 1 hours
#
# Hour in seconds: 1043
# Duration is under 1 hours
#
# Hour in seconds: 134
# Duration is under 1 hours
#
# Hour in seconds: 106
# Duration is under 1 hours
#
# Hour in seconds: 6114
# Duration is under 2 hours
#
# Hour in seconds: 1313
# Duration is under 1 hours
#
# Hour in seconds: 69
# Duration is under 1 hours
#
# Hour in seconds: 3261
# Duration is under 1 hours
#
# Hour in seconds: 755
# Duration is under 1 hours
#
# Hour in seconds: 946
# Duration is under 1 hours
#
# Hour in seconds: 473
# Duration is under 1 hours
#
# Hour in seconds: 1982
# Duration is under 1 hours
#
# Hour in seconds: 124
# Duration is under 1 hours
#
# Hour in seconds: 1055
# Duration is under 1 hours
#
# Hour in seconds: 194
# Duration is under 1 hours
#
# Hour in seconds: 87
# Duration is under 1 hours
#
# Hour in seconds: 4274
# Duration is under 2 hours
#
# Hour in seconds: 888
# Duration is under 1 hours
#
# Hour in seconds: 769
# Duration is under 1 hours
#
# Hour in seconds: 1386
# Duration is under 1 hours
#
# Hour in seconds: 472
# Duration is under 1 hours
#
# Hour in seconds: 1565
# Duration is under 1 hours
#
# Hour in seconds: 1713
# Duration is under 1 hours
#
# Hour in seconds: 215
# Duration is under 1 hours
#
# Hour in seconds: 856
# Duration is under 1 hours
#
# Hour in seconds: 134
# Duration is under 1 hours
#
# Hour in seconds: 114
# Duration is under 1 hours
#
# Hour in seconds: 77
# Duration is under 1 hours
#
# Hour in seconds: 254
# Duration is under 1 hours
#
# Hour in seconds: 6398
# Duration is under 2 hours
#
# Hour in seconds: 4252
# Duration is under 2 hours
#
# Hour in seconds: 1564
# Duration is under 1 hours
#
# Hour in seconds: 73
# Duration is under 1 hours
#
# Hour in seconds: 2823
# Duration is under 1 hours
#
# Hour in seconds: 178
# Duration is under 1 hours
#
# Hour in seconds: 886
# Duration is under 1 hours
#
# Hour in seconds: 3674
# Duration is under 2 hours
#
# Hour in seconds: 85
# Duration is under 1 hours
#
# Hour in seconds: 563
# Duration is under 1 hours
#
# Hour in seconds: 12999
# Duration is under 4 hours
#
# Hour in seconds: 212
# Duration is under 1 hours
#
# Hour in seconds: 39593
# Duration is under 11 hours
#
# Hour in seconds: 601
# Duration is under 1 hours
#
# Hour in seconds: 153
# Duration is under 1 hours
#
# Hour in seconds: 629
# Duration is under 1 hours
#
# Hour in seconds: 615
# Duration is under 1 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 4438
# Duration is under 2 hours
#
# Hour in seconds: 1513
# Duration is under 1 hours
#
# Hour in seconds: 1151
# Duration is under 1 hours
#
# Hour in seconds: 78
# Duration is under 1 hours
#
# Hour in seconds: 4631
# Duration is under 2 hours
#
# Hour in seconds: 1963
# Duration is under 1 hours
#
# Hour in seconds: 11597
# Duration is under 4 hours
#
# Hour in seconds: 370
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 16617
# Duration is under 5 hours
#
# Hour in seconds: 1489
# Duration is under 1 hours
#
# Hour in seconds: 161
# Duration is under 1 hours
#
# Hour in seconds: 152
# Duration is under 1 hours
#
# Hour in seconds: 1633
# Duration is under 1 hours
#
# Hour in seconds: 136
# Duration is under 1 hours
#
# Hour in seconds: 75
# Duration is under 1 hours
#
# Hour in seconds: 4422
# Duration is under 2 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 623
# Duration is under 1 hours
#
# Hour in seconds: 544
# Duration is under 1 hours
#
# Hour in seconds: 936
# Duration is under 1 hours
#
# Hour in seconds: 4808
# Duration is under 2 hours
#
# Hour in seconds: 66
# Duration is under 1 hours
#
# Hour in seconds: 3206
# Duration is under 1 hours
#
# Hour in seconds: 962
# Duration is under 1 hours
#
# Hour in seconds: 140
# Duration is under 1 hours
#
# Hour in seconds: 313
# Duration is under 1 hours
#
# Hour in seconds: 450
# Duration is under 1 hours
#
# Hour in seconds: 9373
# Duration is under 3 hours
#
# Hour in seconds: 6854
# Duration is under 2 hours
#
# Hour in seconds: 76
# Duration is under 1 hours
#
# Hour in seconds: 329
# Duration is under 1 hours
#
# Hour in seconds: 43193
# Duration is under 12 hours
#
# Hour in seconds: 473
# Duration is under 1 hours
#
# Hour in seconds: 143
# Duration is under 1 hours
#
# Hour in seconds: 3984
# Duration is under 2 hours
#
# Hour in seconds: 2988
# Duration is under 1 hours
#
# Hour in seconds: 61
# Duration is under 1 hours
#
# Hour in seconds: 854
# Duration is under 1 hours
#
# Hour in seconds: 363
# Duration is under 1 hours
#
# Hour in seconds: 862
# Duration is under 1 hours
#
# Hour in seconds: 769
# Duration is under 1 hours
#
# Hour in seconds: 278
# Duration is under 1 hours
#
# Hour in seconds: 16374
# Duration is under 5 hours
#
# Hour in seconds: 1421
# Duration is under 1 hours
#
# Hour in seconds: 155
# Duration is under 1 hours
#
# Hour in seconds: 7790
# Duration is under 3 hours
#
# Hour in seconds: 3662
# Duration is under 2 hours
#
# Hour in seconds: 2996
# Duration is under 1 hours
#
# Hour in seconds: 35472
# Duration is under 10 hours
#
# Hour in seconds: 144
# Duration is under 1 hours
#
# Hour in seconds: 1149
# Duration is under 1 hours
#
# Hour in seconds: 179
# Duration is under 1 hours
#
# Hour in seconds: 3346
# Duration is under 1 hours
#
# Hour in seconds: 64
# Duration is under 1 hours
#
# Hour in seconds: 929
# Duration is under 1 hours
#
# Hour in seconds: 152
# Duration is under 1 hours
#
# Hour in seconds: 1574
# Duration is under 1 hours
#
# Hour in seconds: 99
# Duration is under 1 hours
#
# Hour in seconds: 2887
# Duration is under 1 hours
#
# Hour in seconds: 5926
# Duration is under 2 hours
#
# Hour in seconds: 399
# Duration is under 1 hours
#
# Hour in seconds: 3017
# Duration is under 1 hours
#
# Hour in seconds: 6969
# Duration is under 2 hours
#
# Hour in seconds: 99
# Duration is under 1 hours
#
# Hour in seconds: 194
# Duration is under 1 hours
#
# Hour in seconds: 719
# Duration is under 1 hours
#
# Hour in seconds: 4633
# Duration is under 2 hours
#
# Hour in seconds: 274
# Duration is under 1 hours
#
# Hour in seconds: 81
# Duration is under 1 hours
#
# Hour in seconds: 65
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 2350
# Duration is under 1 hours
#
# Hour in seconds: 694
# Duration is under 1 hours
#
# Hour in seconds: 680
# Duration is under 1 hours
#
# Hour in seconds: 3900
# Duration is under 2 hours
#
# Hour in seconds: 614
# Duration is under 1 hours
#
# Hour in seconds: 894
# Duration is under 1 hours
#
# Hour in seconds: 310
# Duration is under 1 hours
#
# Hour in seconds: 242
# Duration is under 1 hours
#
# Hour in seconds: 8921
# Duration is under 3 hours
#
# Hour in seconds: 1610
# Duration is under 1 hours
#
# Hour in seconds: 307
# Duration is under 1 hours
#
# Hour in seconds: 29655
# Duration is under 9 hours
#
# Hour in seconds: 4397
# Duration is under 2 hours
#
# Hour in seconds: 69
# Duration is under 1 hours
#
# Hour in seconds: 1282
# Duration is under 1 hours
#
# Hour in seconds: 995
# Duration is under 1 hours
#
# Hour in seconds: 778
# Duration is under 1 hours
#
# Hour in seconds: 1302
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 4371
# Duration is under 2 hours
#
# Hour in seconds: 4871
# Duration is under 2 hours
#
# Hour in seconds: 107
# Duration is under 1 hours
#
# Hour in seconds: 719
# Duration is under 1 hours
#
# Hour in seconds: 2331
# Duration is under 1 hours
#
# Hour in seconds: 11516
# Duration is under 4 hours
#
# Hour in seconds: 486
# Duration is under 1 hours
#
# Hour in seconds: 102
# Duration is under 1 hours
#
# Hour in seconds: 66
# Duration is under 1 hours
#
# Hour in seconds: 1461
# Duration is under 1 hours
#
# Hour in seconds: 693
# Duration is under 1 hours
#
# Hour in seconds: 1917
# Duration is under 1 hours
#
# Hour in seconds: 612
# Duration is under 1 hours
#
# Hour in seconds: 2201
# Duration is under 1 hours
#
# Hour in seconds: 595
# Duration is under 1 hours
#
# Hour in seconds: 1957
# Duration is under 1 hours
#
# Hour in seconds: 1864
# Duration is under 1 hours
#
# Hour in seconds: 287
# Duration is under 1 hours
#
# Hour in seconds: 162
# Duration is under 1 hours
#
# Hour in seconds: 2508
# Duration is under 1 hours
#
# Hour in seconds: 3336
# Duration is under 1 hours
#
# Hour in seconds: 5056
# Duration is under 2 hours
#
# Hour in seconds: 9031
# Duration is under 3 hours
#
# Hour in seconds: 111
# Duration is under 1 hours
#
# Hour in seconds: 116
# Duration is under 1 hours
#
# Hour in seconds: 63
# Duration is under 1 hours
#
# Hour in seconds: 3446
# Duration is under 1 hours
#
# Hour in seconds: 2950
# Duration is under 1 hours
#
# Hour in seconds: 6658
# Duration is under 2 hours
#
# Hour in seconds: 231
# Duration is under 1 hours
#
# Hour in seconds: 291
# Duration is under 1 hours
#
# Hour in seconds: 2157
# Duration is under 1 hours
#
# Hour in seconds: 2734
# Duration is under 1 hours
#
# Hour in seconds: 133
# Duration is under 1 hours
#
# Hour in seconds: 212
# Duration is under 1 hours
#
# Hour in seconds: 699
# Duration is under 1 hours
#
# Hour in seconds: 3042
# Duration is under 1 hours
#
# Hour in seconds: 8424
# Duration is under 3 hours
#
# Hour in seconds: 1001
# Duration is under 1 hours
#
# Hour in seconds: 261
# Duration is under 1 hours
#
# Hour in seconds: 6398
# Duration is under 2 hours
#
# Hour in seconds: 4516
# Duration is under 2 hours
#
# Hour in seconds: 2405
# Duration is under 1 hours
#
# Hour in seconds: 1865
# Duration is under 1 hours
#
# Hour in seconds: 2883
# Duration is under 1 hours
#
# Hour in seconds: 1920
# Duration is under 1 hours
#
# Hour in seconds: 204
# Duration is under 1 hours
#
# Hour in seconds: 2447
# Duration is under 1 hours
#
# Hour in seconds: 1334
# Duration is under 1 hours
#
# Hour in seconds: 359
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 3427
# Duration is under 1 hours
#
# Hour in seconds: 963
# Duration is under 1 hours
#
# Hour in seconds: 1805
# Duration is under 1 hours
#
# Hour in seconds: 86
# Duration is under 1 hours
#
# Hour in seconds: 900
# Duration is under 1 hours
#
# Hour in seconds: 12227
# Duration is under 4 hours
#
# Hour in seconds: 244
# Duration is under 1 hours
#
# Hour in seconds: 123
# Duration is under 1 hours
#
# Hour in seconds: 189
# Duration is under 1 hours
#
# Hour in seconds: 480
# Duration is under 1 hours
#
# Hour in seconds: 5089
# Duration is under 2 hours
#
# Hour in seconds: 1416
# Duration is under 1 hours
#
# Hour in seconds: 624
# Duration is under 1 hours
#
# Hour in seconds: 243
# Duration is under 1 hours
#
# Hour in seconds: 72
# Duration is under 1 hours
#
# Hour in seconds: 215
# Duration is under 1 hours
#
# Hour in seconds: 65
# Duration is under 1 hours
#
# Hour in seconds: 436
# Duration is under 1 hours
#
# Hour in seconds: 541
# Duration is under 1 hours
#
# Hour in seconds: 1726
# Duration is under 1 hours
#
# Hour in seconds: 373
# Duration is under 1 hours
#
# Hour in seconds: 1249
# Duration is under 1 hours
#
# Hour in seconds: 66
# Duration is under 1 hours
#
# Hour in seconds: 1300
# Duration is under 1 hours
#
# Hour in seconds: 1483
# Duration is under 1 hours
#
# Hour in seconds: 1247
# Duration is under 1 hours
#
# Hour in seconds: 2105
# Duration is under 1 hours
#
# Hour in seconds: 134
# Duration is under 1 hours
#
# Hour in seconds: 2160
# Duration is under 1 hours
#
# Hour in seconds: 1432
# Duration is under 1 hours
#
# Hour in seconds: 853
# Duration is under 1 hours
#
# Hour in seconds: 83
# Duration is under 1 hours
#
# Hour in seconds: 2177
# Duration is under 1 hours
#
# Hour in seconds: 1791
# Duration is under 1 hours
#
# Hour in seconds: 154
# Duration is under 1 hours
#
# Hour in seconds: 4286
# Duration is under 2 hours
#
# Hour in seconds: 12128
# Duration is under 4 hours
#
# Hour in seconds: 2894
# Duration is under 1 hours
#
# Hour in seconds: 21883
# Duration is under 7 hours
#
# Hour in seconds: 43192
# Duration is under 12 hours
#
# Hour in seconds: 1973
# Duration is under 1 hours
#
# Hour in seconds: 2011
# Duration is under 1 hours
#
# Hour in seconds: 214
# Duration is under 1 hours
#
# Hour in seconds: 350
# Duration is under 1 hours
#
# Hour in seconds: 6548
# Duration is under 2 hours
#
# Hour in seconds: 1858
# Duration is under 1 hours
#
# Hour in seconds: 105
# Duration is under 1 hours
#
# Hour in seconds: 427
# Duration is under 1 hours
#
# Hour in seconds: 12676
# Duration is under 4 hours
#
# Hour in seconds: 1543
# Duration is under 1 hours
#
# Hour in seconds: 73
# Duration is under 1 hours
#
# Hour in seconds: 746
# Duration is under 1 hours
#
# Hour in seconds: 2421
# Duration is under 1 hours
#
# Hour in seconds: 444
# Duration is under 1 hours
#
# Hour in seconds: 64
# Duration is under 1 hours
#
# Hour in seconds: 811
# Duration is under 1 hours
#
# Hour in seconds: 165
# Duration is under 1 hours
#
# Hour in seconds: 2054
# Duration is under 1 hours
#
# Hour in seconds: 2636
# Duration is under 1 hours
#
# Hour in seconds: 549
# Duration is under 1 hours
#
# Hour in seconds: 81
# Duration is under 1 hours
#
# Hour in seconds: 110
# Duration is under 1 hours
#
# Hour in seconds: 2751
# Duration is under 1 hours
#
# Hour in seconds: 140
# Duration is under 1 hours
#
# Hour in seconds: 903
# Duration is under 1 hours
#
# Hour in seconds: 1811
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 15264
# Duration is under 5 hours
#
# Hour in seconds: 84
# Duration is under 1 hours
#
# Hour in seconds: 64
# Duration is under 1 hours
#
# Hour in seconds: 1774
# Duration is under 1 hours
#
# Hour in seconds: 6905
# Duration is under 2 hours
#
# Hour in seconds: 351
# Duration is under 1 hours
#
# Hour in seconds: 2131
# Duration is under 1 hours
#
# Hour in seconds: 103
# Duration is under 1 hours
#
# Hour in seconds: 4148
# Duration is under 2 hours
#
# Hour in seconds: 264
# Duration is under 1 hours
#
# Hour in seconds: 164
# Duration is under 1 hours
#
# Hour in seconds: 7625
# Duration is under 3 hours
#
# Hour in seconds: 2472
# Duration is under 1 hours
#
# Hour in seconds: 165
# Duration is under 1 hours
#
# Hour in seconds: 101
# Duration is under 1 hours
#
# Hour in seconds: 1560
# Duration is under 1 hours
#
# Hour in seconds: 796
# Duration is under 1 hours
#
# Hour in seconds: 5673
# Duration is under 2 hours
#
# Hour in seconds: 1555
# Duration is under 1 hours
#
# Hour in seconds: 1160
# Duration is under 1 hours
#
# Hour in seconds: 386
# Duration is under 1 hours
#
# Hour in seconds: 8658
# Duration is under 3 hours
#
# Hour in seconds: 264
# Duration is under 1 hours
#
# Hour in seconds: 2025
# Duration is under 1 hours
#
# Hour in seconds: 428
# Duration is under 1 hours
#
# Hour in seconds: 2852
# Duration is under 1 hours
#
# Hour in seconds: 439
# Duration is under 1 hours
#
# Hour in seconds: 33403
# Duration is under 10 hours
#
# Hour in seconds: 736
# Duration is under 1 hours
#
# Hour in seconds: 110
# Duration is under 1 hours
#
# Hour in seconds: 8362
# Duration is under 3 hours
#
# Hour in seconds: 75
# Duration is under 1 hours
#
# Hour in seconds: 122
# Duration is under 1 hours
#
# Hour in seconds: 459
# Duration is under 1 hours
#
# Hour in seconds: 2760
# Duration is under 1 hours
#
# Hour in seconds: 4728
# Duration is under 2 hours
#
# Hour in seconds: 3582
# Duration is under 1 hours
#
# Hour in seconds: 5991
# Duration is under 2 hours
#
# Hour in seconds: 1595
# Duration is under 1 hours
#
# Hour in seconds: 8094
# Duration is under 3 hours
#
# Hour in seconds: 2346
# Duration is under 1 hours
#
# Hour in seconds: 1017
# Duration is under 1 hours
#
# Hour in seconds: 3237
# Duration is under 1 hours
#
# Hour in seconds: 235
# Duration is under 1 hours
#
# Hour in seconds: 482
# Duration is under 1 hours
#
# Hour in seconds: 65
# Duration is under 1 hours
#
# Hour in seconds: 3704
# Duration is under 2 hours
#
# Hour in seconds: 374
# Duration is under 1 hours
#
# Hour in seconds: 4441
# Duration is under 2 hours
#
# Hour in seconds: 517
# Duration is under 1 hours
#
# Hour in seconds: 102
# Duration is under 1 hours
#
# Hour in seconds: 2163
# Duration is under 1 hours
#
# Hour in seconds: 1775
# Duration is under 1 hours
#
# Hour in seconds: 2358
# Duration is under 1 hours
#
# Hour in seconds: 66
# Duration is under 1 hours
#
# Hour in seconds: 646
# Duration is under 1 hours
#
# Hour in seconds: 7944
# Duration is under 3 hours
#
# Hour in seconds: 136
# Duration is under 1 hours
#
# Hour in seconds: 830
# Duration is under 1 hours
#
# Hour in seconds: 7301
# Duration is under 3 hours
#
# Hour in seconds: 3649
# Duration is under 2 hours
#
# Hour in seconds: 3593
# Duration is under 1 hours
#
# Hour in seconds: 401
# Duration is under 1 hours
#
# Hour in seconds: 2316
# Duration is under 1 hours
#
# Hour in seconds: 253
# Duration is under 1 hours
#
# Hour in seconds: 1653
# Duration is under 1 hours
#
# Hour in seconds: 251
# Duration is under 1 hours
#
# Hour in seconds: 369
# Duration is under 1 hours
#
# Hour in seconds: 151
# Duration is under 1 hours
#
# Hour in seconds: 61
# Duration is under 1 hours
#
# Hour in seconds: 73
# Duration is under 1 hours
#
# Hour in seconds: 477
# Duration is under 1 hours
#
# Hour in seconds: 412
# Duration is under 1 hours
#
# Hour in seconds: 3333
# Duration is under 1 hours
#
# Hour in seconds: 11038
# Duration is under 4 hours
#
# Hour in seconds: 8615
# Duration is under 3 hours
#
# Hour in seconds: 92
# Duration is under 1 hours
#
# Hour in seconds: 319
# Duration is under 1 hours
#
# Hour in seconds: 76
# Duration is under 1 hours
#
# Hour in seconds: 6752
# Duration is under 2 hours
#
# Hour in seconds: 107
# Duration is under 1 hours
#
# Hour in seconds: 21446
# Duration is under 6 hours
#
# Hour in seconds: 1483
# Duration is under 1 hours
#
# Hour in seconds: 3553
# Duration is under 1 hours
#
# Hour in seconds: 1395
# Duration is under 1 hours
#
# Hour in seconds: 88
# Duration is under 1 hours
#
# Hour in seconds: 343
# Duration is under 1 hours
#
# Hour in seconds: 69
# Duration is under 1 hours
#
# Hour in seconds: 631
# Duration is under 1 hours
#
# Hour in seconds: 293
# Duration is under 1 hours
#
# Hour in seconds: 174
# Duration is under 1 hours
#
# Hour in seconds: 2517
# Duration is under 1 hours
#
# Hour in seconds: 4172
# Duration is under 2 hours
#
# Hour in seconds: 238
# Duration is under 1 hours
#
# Hour in seconds: 1236
# Duration is under 1 hours
#
# Hour in seconds: 85
# Duration is under 1 hours
#
# Hour in seconds: 365
# Duration is under 1 hours
#
# Hour in seconds: 3112
# Duration is under 1 hours
#
# Hour in seconds: 1705
# Duration is under 1 hours
#
# Hour in seconds: 3991
# Duration is under 2 hours
#
# Hour in seconds: 13777
# Duration is under 4 hours
#
# Hour in seconds: 61
# Duration is under 1 hours
#
# Hour in seconds: 88
# Duration is under 1 hours
#
# Hour in seconds: 5252
# Duration is under 2 hours
#
# Hour in seconds: 973
# Duration is under 1 hours
#
# Hour in seconds: 130
# Duration is under 1 hours
#
# Hour in seconds: 324
# Duration is under 1 hours
#
# Hour in seconds: 969
# Duration is under 1 hours
#
# Hour in seconds: 140
# Duration is under 1 hours
#
# Hour in seconds: 634
# Duration is under 1 hours
#
# Hour in seconds: 2010
# Duration is under 1 hours
#
# Hour in seconds: 363
# Duration is under 1 hours
#
# Hour in seconds: 124
# Duration is under 1 hours
#
# Hour in seconds: 304
# Duration is under 1 hours
#
# Hour in seconds: 9507
# Duration is under 3 hours
#
# Hour in seconds: 196
# Duration is under 1 hours
#
# Hour in seconds: 703
# Duration is under 1 hours
#
# Hour in seconds: 459
# Duration is under 1 hours
#
# Hour in seconds: 149
# Duration is under 1 hours
#
# Hour in seconds: 1227
# Duration is under 1 hours
#
# Hour in seconds: 5561
# Duration is under 2 hours
#
# Hour in seconds: 129
# Duration is under 1 hours
#
# Hour in seconds: 6493
# Duration is under 2 hours
#
# Hour in seconds: 658
# Duration is under 1 hours
#
# Hour in seconds: 5400
# Duration is under 2 hours
#
# Hour in seconds: 5573
# Duration is under 2 hours
#
# Hour in seconds: 78
# Duration is under 1 hours
#
# Hour in seconds: 1489
# Duration is under 1 hours
#
# Hour in seconds: 2096
# Duration is under 1 hours
#
# Hour in seconds: 1421
# Duration is under 1 hours
#
# Hour in seconds: 5078
# Duration is under 2 hours
#
# Hour in seconds: 1035
# Duration is under 1 hours
#
# Hour in seconds: 213
# Duration is under 1 hours
#
# Hour in seconds: 3600
# Duration is under 2 hours
#
# Hour in seconds: 687
# Duration is under 1 hours
#
# Hour in seconds: 3349
# Duration is under 1 hours
#
# Hour in seconds: 2687
# Duration is under 1 hours
#
# Hour in seconds: 687
# Duration is under 1 hours
#
# Hour in seconds: 3590
# Duration is under 1 hours
#
# Hour in seconds: 380
# Duration is under 1 hours
#
# Hour in seconds: 780
# Duration is under 1 hours
#
# Hour in seconds: 724
# Duration is under 1 hours
#
# Hour in seconds: 2594
# Duration is under 1 hours
#
# Hour in seconds: 7059
# Duration is under 2 hours
#
# Hour in seconds: 215
# Duration is under 1 hours
#
# Hour in seconds: 236
# Duration is under 1 hours
#
# Hour in seconds: 464
# Duration is under 1 hours
#
# Hour in seconds: 392
# Duration is under 1 hours
#
# Hour in seconds: 1257
# Duration is under 1 hours
#
# Hour in seconds: 2992
# Duration is under 1 hours
#
# Hour in seconds: 2006
# Duration is under 1 hours
#
# Hour in seconds: 1727
# Duration is under 1 hours
#
# Hour in seconds: 287
# Duration is under 1 hours
#
# Hour in seconds: 1326
# Duration is under 1 hours
#
# Hour in seconds: 2981
# Duration is under 1 hours
#
# Hour in seconds: 4659
# Duration is under 2 hours
#
# Hour in seconds: 1104
# Duration is under 1 hours
#
# Hour in seconds: 475
# Duration is under 1 hours
#
# Hour in seconds: 70
# Duration is under 1 hours
#
# Hour in seconds: 98
# Duration is under 1 hours
#
# Hour in seconds: 9273
# Duration is under 3 hours
#
# Hour in seconds: 710
# Duration is under 1 hours
#
# Hour in seconds: 89
# Duration is under 1 hours
#
# Hour in seconds: 104
# Duration is under 1 hours
#
# Hour in seconds: 206
# Duration is under 1 hours
#
# Hour in seconds: 749
# Duration is under 1 hours
#
# Hour in seconds: 188
# Duration is under 1 hours
#
# Hour in seconds: 209
# Duration is under 1 hours
#
# Hour in seconds: 286
# Duration is under 1 hours
#
# Hour in seconds: 63
# Duration is under 1 hours
#
# Hour in seconds: 3204
# Duration is under 1 hours
#
# Hour in seconds: 576
# Duration is under 1 hours
#
# Hour in seconds: 6314
# Duration is under 2 hours
#
# Hour in seconds: 1099
# Duration is under 1 hours
#
# Hour in seconds: 174
# Duration is under 1 hours
#
# Hour in seconds: 364
# Duration is under 1 hours
#
# Hour in seconds: 279
# Duration is under 1 hours
#
# Hour in seconds: 115
# Duration is under 1 hours
#
# Hour in seconds: 1044
# Duration is under 1 hours
#
# Hour in seconds: 1011
# Duration is under 1 hours
#
# Hour in seconds: 247
# Duration is under 1 hours
#
# Hour in seconds: 6420
# Duration is under 2 hours
#
# Hour in seconds: 2068
# Duration is under 1 hours
#
# Hour in seconds: 72
# Duration is under 1 hours
#
# Hour in seconds: 3009
# Duration is under 1 hours
#
# Hour in seconds: 3902
# Duration is under 2 hours
#
# Hour in seconds: 212
# Duration is under 1 hours
#
# Hour in seconds: 280
# Duration is under 1 hours
#
# Hour in seconds: 2522
# Duration is under 1 hours
#
# Hour in seconds: 62
# Duration is under 1 hours
#
# Hour in seconds: 448
# Duration is under 1 hours
#
# Hour in seconds: 283
# Duration is under 1 hours
#
# Hour in seconds: 194
# Duration is under 1 hours
#
# Hour in seconds: 2985
# Duration is under 1 hours
#
# Hour in seconds: 10131
# Duration is under 3 hours
#
# Hour in seconds: 2286
# Duration is under 1 hours
#
# Hour in seconds: 2980
# Duration is under 1 hours
#
# Hour in seconds: 387
# Duration is under 1 hours
#
# Hour in seconds: 4178
# Duration is under 2 hours
#
# Hour in seconds: 926
# Duration is under 1 hours
#
# Hour in seconds: 2078
# Duration is under 1 hours
#
# Hour in seconds: 5025
# Duration is under 2 hours
#
# Hour in seconds: 43193
# Duration is under 12 hours
#
# Hour in seconds: 4965
# Duration is under 2 hours
#
# Hour in seconds: 837
# Duration is under 1 hours
#
# Hour in seconds: 2530
# Duration is under 1 hours
#
# Hour in seconds: 1744
# Duration is under 1 hours
#
# Hour in seconds: 177
# Duration is under 1 hours
#
# Hour in seconds: 3600
# Duration is under 2 hours
#
# Hour in seconds: 3518
# Duration is under 1 hours
#
# Hour in seconds: 423
# Duration is under 1 hours
#
# Hour in seconds: 377
# Duration is under 1 hours
#
# Hour in seconds: 10245
# Duration is under 3 hours
#
# Hour in seconds: 1638
# Duration is under 1 hours
#
# Hour in seconds: 112
# Duration is under 1 hours
#
# Hour in seconds: 467
# Duration is under 1 hours
#
# Hour in seconds: 1209
# Duration is under 1 hours
#
# Hour in seconds: 257
# Duration is under 1 hours
#
# Hour in seconds: 1617
# Duration is under 1 hours
#
# Hour in seconds: 440
# Duration is under 1 hours
#
# Hour in seconds: 532
# Duration is under 1 hours
#
# Hour in seconds: 1429
# Duration is under 1 hours
#
# Hour in seconds: 268
# Duration is under 1 hours
#
# Hour in seconds: 3030
# Duration is under 1 hours
#
# Hour in seconds: 4142
# Duration is under 2 hours
#
# Hour in seconds: 280
# Duration is under 1 hours
#
# Hour in seconds: 180
# Duration is under 1 hours
#
# Hour in seconds: 2544
# Duration is under 1 hours
#
# Hour in seconds: 357
# Duration is under 1 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 1355
# Duration is under 1 hours
#
# Hour in seconds: 2445
# Duration is under 1 hours
#
# Hour in seconds: 3511
# Duration is under 1 hours
#
# Hour in seconds: 782
# Duration is under 1 hours
#
# Hour in seconds: 3466
# Duration is under 1 hours
#
# Hour in seconds: 405
# Duration is under 1 hours
#
# Hour in seconds: 171
# Duration is under 1 hours
#
# Hour in seconds: 1280
# Duration is under 1 hours
#
# Hour in seconds: 4220
# Duration is under 2 hours
#
# Hour in seconds: 199
# Duration is under 1 hours
#
# Hour in seconds: 531
# Duration is under 1 hours
#
# Hour in seconds: 843
# Duration is under 1 hours
#
# Hour in seconds: 67
# Duration is under 1 hours
#
# Hour in seconds: 2316
# Duration is under 1 hours
#
# Hour in seconds: 3330
# Duration is under 1 hours
#
# Hour in seconds: 89
# Duration is under 1 hours
#
# Hour in seconds: 82
# Duration is under 1 hours
#
# Hour in seconds: 411
# Duration is under 1 hours
#
# Hour in seconds: 256
# Duration is under 1 hours
#
# Hour in seconds: 3657
# Duration is under 2 hours
#
# Hour in seconds: 229
# Duration is under 1 hours
#
# Hour in seconds: 222
# Duration is under 1 hours
#
# Hour in seconds: 3447
# Duration is under 1 hours
#
# Hour in seconds: 1774
# Duration is under 1 hours
#
# Hour in seconds: 68
# Duration is under 1 hours
#
# Hour in seconds: 3668
# Duration is under 2 hours
#
# Hour in seconds: 149
# Duration is under 1 hours
#
# Hour in seconds: 145
# Duration is under 1 hours
#
# Hour in seconds: 6017
# Duration is under 2 hours
#
# Hour in seconds: 14961
# Duration is under 5 hours
#
# Hour in seconds: 4571
# Duration is under 2 hours
#
# Hour in seconds: 2043
# Duration is under 1 hours
#
# Hour in seconds: 271
# Duration is under 1 hours
#
# Hour in seconds: 93
# Duration is under 1 hours
#
# Hour in seconds: 110
# Duration is under 1 hours
#
# Hour in seconds: 81
# Duration is under 1 hours
#
# Hour in seconds: 1017
# Duration is under 1 hours
#
# Hour in seconds: 2487
# Duration is under 1 hours
#
# Hour in seconds: 3469
# Duration is under 1 hours
#
# Hour in seconds: 1079
# Duration is under 1 hours
#
# Hour in seconds: 7579
# Duration is under 3 hours
#
# Hour in seconds: 1124
# Duration is under 1 hours
#
# Hour in seconds: 934
# Duration is under 1 hours
#
# Hour in seconds: 9164
# Duration is under 3 hours
#
# Hour in seconds: 79
# Duration is under 1 hours
#
# Hour in seconds: 1157
# Duration is under 1 hours
#
# Hour in seconds: 5059
# Duration is under 2 hours
#
# Hour in seconds: 789
# Duration is under 1 hours
#
# Hour in seconds: 628
# Duration is under 1 hours
#
# Hour in seconds: 716
# Duration is under 1 hours
#
# Hour in seconds: 3087
# Duration is under 1 hours
#
# Hour in seconds: 2763
# Duration is under 1 hours
#
# Hour in seconds: 771
# Duration is under 1 hours
#
# Hour in seconds: 1307
# Duration is under 1 hours
#
# Hour in seconds: 223
# Duration is under 1 hours
#
# Hour in seconds: 93
# Duration is under 1 hours
#
# Hour in seconds: 2754
# Duration is under 1 hours
#
# Hour in seconds: 39593
# Duration is under 11 hours
#
# Hour in seconds: 2132
# Duration is under 1 hours
#
# Hour in seconds: 305
# Duration is under 1 hours
#
# Hour in seconds: 127
# Duration is under 1 hours
#
# Hour in seconds: 294
# Duration is under 1 hours
#
# Hour in seconds: 716
# Duration is under 1 hours
#
# Hour in seconds: 10400
# Duration is under 3 hours
#
# Hour in seconds: 659
# Duration is under 1 hours
#
# Hour in seconds: 542
# Duration is under 1 hours
#
# Hour in seconds: 275
# Duration is under 1 hours
#
# Hour in seconds: 844
# Duration is under 1 hours
#
# Hour in seconds: 399
# Duration is under 1 hours
#
# Hour in seconds: 7832
# Duration is under 3 hours
#
# Hour in seconds: 121
# Duration is under 1 hours
#
# Hour in seconds: 1926
# Duration is under 1 hours
#
# Hour in seconds: 143
# Duration is under 1 hours
#
# Hour in seconds: 1404
# Duration is under 1 hours
#
# Hour in seconds: 1130
# Duration is under 1 hours
#
# Hour in seconds: 542
# Duration is under 1 hours
#
# Hour in seconds: 4282
# Duration is under 2 hours
#
# Hour in seconds: 2305
# Duration is under 1 hours
#
# Hour in seconds: 4592
# Duration is under 2 hours
#
# Hour in seconds: 945
# Duration is under 1 hours
#
# Hour in seconds: 537
# Duration is under 1 hours
#
# Hour in seconds: 66
# Duration is under 1 hours
#
# Hour in seconds: 1317
# Duration is under 1 hours
#
# Hour in seconds: 733
# Duration is under 1 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 190
# Duration is under 1 hours
#
# Hour in seconds: 123
# Duration is under 1 hours
#
# Hour in seconds: 1053
# Duration is under 1 hours
#
# Hour in seconds: 775
# Duration is under 1 hours
#
# Hour in seconds: 2772
# Duration is under 1 hours
#
# Hour in seconds: 1583
# Duration is under 1 hours
#
# Hour in seconds: 1326
# Duration is under 1 hours
#
# Hour in seconds: 8968
# Duration is under 3 hours
#
# Hour in seconds: 5474
# Duration is under 2 hours
#
# Hour in seconds: 2234
# Duration is under 1 hours
#
# Hour in seconds: 154
# Duration is under 1 hours
#
# Hour in seconds: 236
# Duration is under 1 hours
#
# Hour in seconds: 2374
# Duration is under 1 hours
#
# Hour in seconds: 1963
# Duration is under 1 hours
#
# Hour in seconds: 156
# Duration is under 1 hours
#
# Hour in seconds: 404
# Duration is under 1 hours
#
# Hour in seconds: 425
# Duration is under 1 hours
#
# Hour in seconds: 96
# Duration is under 1 hours
#
# Hour in seconds: 39593
# Duration is under 11 hours
#
# Hour in seconds: 1852
# Duration is under 1 hours
#
# Hour in seconds: 4797
# Duration is under 2 hours
#
# Hour in seconds: 3508
# Duration is under 1 hours
#
# Hour in seconds: 4836
# Duration is under 2 hours
#
# Hour in seconds: 541
# Duration is under 1 hours
#
# Hour in seconds: 196
# Duration is under 1 hours
#
# Hour in seconds: 256
# Duration is under 1 hours
#
# Hour in seconds: 381
# Duration is under 1 hours
#
# Hour in seconds: 2676
# Duration is under 1 hours
#
# Hour in seconds: 1231
# Duration is under 1 hours
#
# Hour in seconds: 154
# Duration is under 1 hours
#
# Hour in seconds: 77
# Duration is under 1 hours
#
# Hour in seconds: 2558
# Duration is under 1 hours
#
# Hour in seconds: 133
# Duration is under 1 hours
#
# Hour in seconds: 533
# Duration is under 1 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 4939
# Duration is under 2 hours
#
# Hour in seconds: 154
# Duration is under 1 hours
#
# Hour in seconds: 271
# Duration is under 1 hours
#
# Hour in seconds: 2841
# Duration is under 1 hours
#
# Hour in seconds: 6882
# Duration is under 2 hours
#
# Hour in seconds: 537
# Duration is under 1 hours
#
# Hour in seconds: 1636
# Duration is under 1 hours
#
# Hour in seconds: 197
# Duration is under 1 hours
#
# Hour in seconds: 1816
# Duration is under 1 hours
#
# Hour in seconds: 1667
# Duration is under 1 hours
#
# Hour in seconds: 3710
# Duration is under 2 hours
#
# Hour in seconds: 373
# Duration is under 1 hours
#
# Hour in seconds: 103
# Duration is under 1 hours
#
# Hour in seconds: 559
# Duration is under 1 hours
#
# Hour in seconds: 1672
# Duration is under 1 hours
#
# Hour in seconds: 943
# Duration is under 1 hours
#
# Hour in seconds: 1777
# Duration is under 1 hours
#
# Hour in seconds: 401
# Duration is under 1 hours
#
# Hour in seconds: 1920
# Duration is under 1 hours
#
# Hour in seconds: 234
# Duration is under 1 hours
#
# Hour in seconds: 75
# Duration is under 1 hours
#
# Hour in seconds: 207
# Duration is under 1 hours
#
# Hour in seconds: 557
# Duration is under 1 hours
#
# Hour in seconds: 1951
# Duration is under 1 hours
#
# Hour in seconds: 62
# Duration is under 1 hours
#
# Hour in seconds: 4039
# Duration is under 2 hours
#
# Hour in seconds: 92
# Duration is under 1 hours
#
# Hour in seconds: 94
# Duration is under 1 hours
#
# Hour in seconds: 1677
# Duration is under 1 hours
#
# Hour in seconds: 3746
# Duration is under 2 hours
#
# Hour in seconds: 463
# Duration is under 1 hours
#
# Hour in seconds: 77
# Duration is under 1 hours
#
# Hour in seconds: 5197
# Duration is under 2 hours
#
# Hour in seconds: 22139
# Duration is under 7 hours
#
# Hour in seconds: 576
# Duration is under 1 hours
#
# Hour in seconds: 100
# Duration is under 1 hours
#
# Hour in seconds: 80
# Duration is under 1 hours
#
# Hour in seconds: 994
# Duration is under 1 hours
#
# Hour in seconds: 318
# Duration is under 1 hours
#
# Hour in seconds: 1770
# Duration is under 1 hours
#
# Hour in seconds: 185
# Duration is under 1 hours
#
# Hour in seconds: 219
# Duration is under 1 hours
#
# Hour in seconds: 63
# Duration is under 1 hours
#
# Hour in seconds: 862
# Duration is under 1 hours
#
# Hour in seconds: 5252
# Duration is under 2 hours
#
# Hour in seconds: 439
# Duration is under 1 hours
#
# Hour in seconds: 4341
# Duration is under 2 hours
#
# Hour in seconds: 4583
# Duration is under 2 hours
#
# Hour in seconds: 4574
# Duration is under 2 hours
#
# Hour in seconds: 72
# Duration is under 1 hours
#
# Hour in seconds: 391
# Duration is under 1 hours
#
# Hour in seconds: 2656
# Duration is under 1 hours
#
# Hour in seconds: 1343
# Duration is under 1 hours
#
# Hour in seconds: 218
# Duration is under 1 hours
#
# Hour in seconds: 571
# Duration is under 1 hours
#
# Hour in seconds: 508
# Duration is under 1 hours
#
# Hour in seconds: 105
# Duration is under 1 hours
#
# Hour in seconds: 3648
# Duration is under 2 hours
#
# Hour in seconds: 182
# Duration is under 1 hours
#
# Hour in seconds: 1504
# Duration is under 1 hours
#
# Hour in seconds: 220
# Duration is under 1 hours
#
# Hour in seconds: 216
# Duration is under 1 hours
#
# Hour in seconds: 841
# Duration is under 1 hours
#
# Hour in seconds: 73
# Duration is under 1 hours
#
# Hour in seconds: 4878
# Duration is under 2 hours
#
# Hour in seconds: 623
# Duration is under 1 hours
#
# Hour in seconds: 12308
# Duration is under 4 hours
#
# Hour in seconds: 295
# Duration is under 1 hours
#
# Hour in seconds: 1068
# Duration is under 1 hours
#
# Hour in seconds: 1920
# Duration is under 1 hours
#
# Hour in seconds: 93
# Duration is under 1 hours
#
# Hour in seconds: 245
# Duration is under 1 hours
#
# Hour in seconds: 10802
# Duration is under 4 hours
#
# Hour in seconds: 1871
# Duration is under 1 hours
#
# Hour in seconds: 2099
# Duration is under 1 hours
#
# Hour in seconds: 61
# Duration is under 1 hours
#
# Hour in seconds: 97
# Duration is under 1 hours
#
# Hour in seconds: 151
# Duration is under 1 hours
#
# Hour in seconds: 6183
# Duration is under 2 hours
#
# Hour in seconds: 806
# Duration is under 1 hours
#
# Hour in seconds: 74
# Duration is under 1 hours
#
# Hour in seconds: 184
# Duration is under 1 hours
#
# Hour in seconds: 416
# Duration is under 1 hours
#
# Hour in seconds: 6836
# Duration is under 2 hours
#
# Hour in seconds: 126
# Duration is under 1 hours
#
# Hour in seconds: 3977
# Duration is under 2 hours
#
# Hour in seconds: 134
# Duration is under 1 hours
#
# Hour in seconds: 1781
# Duration is under 1 hours
#
# Hour in seconds: 231
# Duration is under 1 hours
#
# Hour in seconds: 10166
# Duration is under 3 hours
#
# Hour in seconds: 2973
# Duration is under 1 hours

# %%
#Preliminary Target Features identification (Pre-Hill Climbing)

#Convert possible targets to dtype = int
intDf = parkingdata.copy()
#Drop useless fields
intDf.drop('Arrival Time', axis = 1, inplace = True)
intDf.drop('Departure Time', axis = 1, inplace = True)
intDf.drop('Street Marker', axis = 1, inplace = True)
#Drop target field
intDf.drop('Duration of Parking Event (in seconds)', axis = 1, inplace = True)
#Drop already int fields (Will add back after)
intDf.drop('In Violation?', axis = 1, inplace = True)
intDf.drop('Side Of Street', axis = 1, inplace = True)
intDf.drop('Street ID', axis = 1, inplace = True)
intDf.drop('Device ID', axis = 1, inplace = True)

#Transform the remainder non-int fields' values to unique int identifiers
for column in intDf:
    unique_vals = intDf[column].unique()
    intDf[column].replace(to_replace = unique_vals, value = list(range(len(unique_vals))), inplace = True)

#Create dataframe for all the relevant features
features = intDf.copy()

#Add back int fields (If not the target field)
features['In Violation?'] = parkingdata['In Violation?']
features['Side Of Street'] = parkingdata['Side Of Street']
features['Street ID'] = parkingdata['Street ID']
features['Device ID'] = parkingdata['Device ID']
#Add back datetime features with only the meaningful subset of data
features['Arrival Hour'] = parkingdata['Arrival Time'].dt.hour
features['Departure Hour'] = parkingdata['Departure Time'].dt.hour

#Table view of features dataframe
features.head(10)

# %%
#Parameter Tuning

#Define the parameters to tune and the values to tune to
params_KNN = {'n_neighbors': list(range(1, 10)), 
              'weights': ['uniform', 'distance'],
              'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
              'leaf_size': list(range(10, 50, 5)),
              'p': [1, 2, 5]
             }

# %%
#Create the Grid Search to go through the model parameters
cv_method = RepeatedStratifiedKFold(n_splits = 5, 
                                    n_repeats = 1, 
                                    random_state = 4)

gs_KNN = GridSearchCV(estimator = KNeighborsClassifier(), 
                      param_grid = params_KNN, 
                      cv = cv_method,
                      verbose = 1,
                      scoring = 'accuracy', 
                      return_train_score = True)

# %%
#Fit the model with the dataset
bestModel = gs_KNN.fit(features, target)

# %%
#Find the best values for the  parameters of the model (Standard output)
gs_KNN.best_params_

# %%
#Find the best values for the  parameters of the model (Formatted output)
best_n = bestModel.best_estimator_.get_params()['n_neighbors']
best_w = bestModel.best_estimator_.get_params()['weights']
best_a =  bestModel.best_estimator_.get_params()['algorithm']
best_l =  bestModel.best_estimator_.get_params()['leaf_size']
best_p =  bestModel.best_estimator_.get_params()['p']

print('Best n_neighbors:', best_n)
print('Best weights:', best_w)
print('Best algorithm:', best_a)
print('Best leaf_size:', best_l)
print('Best p:', best_p)

# %%
#Visualise the parameter configurations from fitting the model with the dataset
results_KNN = pd.DataFrame(gs_KNN.cv_results_['params'])
results_KNN['test_score'] = gs_KNN.cv_results_['mean_test_score']
results_KNN

# %%
#Define model with the optimal parameter values
knn = metric = KNeighborsClassifier(n_neighbors = best_n, 
                               weights = best_w, 
                               algorithm = best_a, 
                               leaf_size = best_l, 
                               p = best_p)

# %%
# Hill climbing w/ KNN
new_Ind = []
cur_MaxScore = 0.0
col_num = len(features.columns)
col_Ind_Random = shuffle(range(0, col_num), random_state = 1)
features_array = features.values

for cur_f in range(col_num):
    new_Ind.append(col_Ind_Random[cur_f])
    newData = features_array[:, new_Ind]
    x_train, x_test, y_train, y_test = train_test_split(newData, target, test_size=0.2, random_state=1)
    fit = knn.fit(x_train, y_train)
    cur_Score = knn.score(x_test, y_test)
    
    if cur_Score < cur_MaxScore:
        new_Ind.remove(col_Ind_Random[cur_f])
    else:
        cur_MaxScore = cur_Score
        print ("Score with " + str(len(new_Ind)) + " selected features: " + str(cur_Score))
print("\nIndexs of the desired features")
print(new_Ind)

# %%
#Create new dataframe from hill climbing output
features_hc = pd.DataFrame()
for index in new_Ind:
    colName = features.columns[index]
    features_hc[colName] = features[colName]
features_hc.head(10)

# %%
#Fit the model with the dataset (New Hill Climbing Features)
bestModel = gs_KNN.fit(features_hc, target)

# %%
#Find the best values for the  parameters of the model (Standard output) AFTER HILL CLIMBING
gs_KNN.best_params_

# %%
#Find the best values for the  parameters of the model (Formatted output) AFTER HILL CLIMBING
best_n_hc = bestModel.best_estimator_.get_params()['n_neighbors']
best_w_hc = bestModel.best_estimator_.get_params()['weights']
best_a_hc =  bestModel.best_estimator_.get_params()['algorithm']
best_l_hc =  bestModel.best_estimator_.get_params()['leaf_size']
best_p_hc =  bestModel.best_estimator_.get_params()['p']

print('Best n_neighbors:', best_n_hc)
print('Best weights:', best_w_hc)
print('Best algorithm:', best_a_hc)
print('Best leaf_size:', best_l_hc)
print('Best p:', best_p_hc)

# %%
#Visualise the parameter configurations from fitting the model with the dataset AFTER HILL CLIMBING
results_KNN = pd.DataFrame(gs_KNN.cv_results_['params'])
results_KNN['test_score'] = gs_KNN.cv_results_['mean_test_score']
results_KNN

# %%
#Re-Define model with the optimal parameter values AFTER HILL CLIMBING
knn = metric = KNeighborsClassifier(n_neighbors = best_n_hc, 
                               weights = best_w_hc, 
                               algorithm = best_a_hc, 
                               leaf_size = best_l_hc, 
                               p = best_p_hc)

# %%
#Defining training and testing groups
x_train, x_test, y_train, y_test = train_test_split(features_hc, target, test_size = 0.5, random_state = 4)

#Training the model previously defined
knn.fit(x_train, y_train)

#Obtaining and printing out results from the model (Confusion Matrix)
predicted = knn.predict(x_test)
cm = confusion_matrix(y_test,predicted)
print("Confusion Matrix")
print(cm)

#Printing the numerical result of the confusion matrix
print("\n[Train/test split] score: {:.5f}".format(knn.score(x_test, y_test)))

# %%
#Repeat with KFold - creating groups
kf = KFold(n_splits = 5, random_state = 4, shuffle = True)

#Print statement for debuging
# for train_index, test_index in kf.split(features_hc):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     x_train, x_test = features_hc.iloc[train_index], features_hc.iloc[test_index]
#     y_train, y_test = target.iloc[train_index], target.iloc[test_index]

#Repeat with KFold - Training model (previously defined) and obtaining its output
kFoldTotal = 0
for k, (train_index, test_index) in enumerate(kf.split(features_hc)):
    x_train, x_test = features_hc.iloc[train_index], features_hc.iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]
    knn.fit(x_train, y_train)
    kFoldTotal += knn.score(x_test, y_test)
    print("[fold {0}] score: {1:.5f}".format(k, knn.score(x_test, y_test)))

#Printing out the results
roundedTotal = round(kFoldTotal/5, 5)
print("\nKNN mean score [5 folds] = " + str(roundedTotal))
