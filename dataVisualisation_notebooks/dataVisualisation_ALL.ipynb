# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
sns.set()
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
# cd D:\Group-7

# %%
#retrieving data
parkingdata = pd.read_csv("parking_duration_of_parking_event_vs_street_ID.csv")
parkingdata.shape
# Out:
# (12208178, 13)

# %%
parkingdata.head(5)
# Out:
#          Area Name        Street Name  Between Street 1    Between Street 2  \
# 0            Banks      MARKET STREET     FLINDERS LANE     FLINDERS STREET
# 1        Chinatown     RUSSELL STREET     BOURKE STREET   Lt COLLINS STREET
# 2         Courtney   ELIZABETH STREET     PELHAM STREET  QUEENSBERRY STREET
# 3  Princes Theatre  EXHIBITION STREET  Lt BOURKE STREET       BOURKE STREET
# 4  Princes Theatre  EXHIBITION STREET     BOURKE STREET   Lt COLLINS STREET
#
#    Side Of Street Street Marker            Arrival Time  \
# 0               5         1263W  01/10/2011 12:01:10 AM
# 1               2          742E  01/10/2011 12:01:11 AM
# 2               2         4744E  01/10/2011 12:01:11 AM
# 3               2          452E  01/10/2011 12:01:13 AM
# 4               5          429W  01/10/2011 12:01:14 AM
#
#            Departure Time  Duration of Parking Event (in seconds)  \
# 0  01/10/2011 12:02:44 AM                                      94
# 1  01/10/2011 03:58:20 AM                                   14229
# 2  01/10/2011 11:00:19 AM                                   39548
# 3  01/10/2011 12:37:42 AM                                    2189
# 4  01/10/2011 05:28:10 AM                                   19616
#
#                          Sign  In Violation?  Street ID  Device ID
# 0     2P DIS M-SUN 0:00-23:59              0        957       1667
# 1       4P DIS AOT 12:00-7:30              0       1221        525
# 2     2P DIS M-SUN 0:00-23:59              1        627       3202
# 3     2P DIS M-SUN 0:00-23:59              0        647        201
# 4  TKT AREA M-SUN 0:00 - 7:30              0        647        176

# %%
parkingdata.tail(5)
# Out:
#                 Area Name      Street Name  Between Street 1  \
# 12208173        Chinatown   RUSSELL STREET  Lt BOURKE STREET
# 12208174        Chinatown   RUSSELL STREET     BOURKE STREET
# 12208175      City Square    FLINDERS LANE  ELIZABETH STREET
# 12208176      City Square    FLINDERS LANE  ELIZABETH STREET
# 12208177  Princes Theatre  LONSDALE STREET    RUSSELL STREET
#
#            Between Street 2  Side Of Street Street Marker  \
# 12208173      BOURKE STREET               2          770E
# 12208174  Lt COLLINS STREET               5          765W
# 12208175    SWANSTON STREET               4         1777S
# 12208176    SWANSTON STREET               4         1775S
# 12208177  EXHIBITION STREET               4         2843S
#
#                     Arrival Time          Departure Time  \
# 12208173  30/09/2012 11:47:56 PM  30/09/2012 11:57:52 PM
# 12208174  30/09/2012 11:48:34 PM  30/09/2012 11:50:02 PM
# 12208175  30/09/2012 11:48:41 PM  30/09/2012 11:51:57 PM
# 12208176  30/09/2012 11:49:43 PM  30/09/2012 11:52:54 PM
# 12208177  30/09/2012 11:52:29 PM  30/09/2012 11:59:00 PM
#
#           Duration of Parking Event (in seconds)                     Sign  \
# 12208173                                     596  2P DIS M-SUN 0:00-23:59
# 12208174                                      88  2P DIS M-SUN 0:00-23:59
# 12208175                                     196  2P DIS M-SUN 0:00-23:59
# 12208176                                     191  2P DIS M-SUN 0:00-23:59
# 12208177                                     391    2P DIS AOT 0:00-23:59
#
#           In Violation?  Street ID  Device ID
# 12208173              0       1221       7815
# 12208174              0       1221        689
# 12208175              0        669       6758
# 12208176              0        669       1407
# 12208177              0        894       6954

# %% [markdown]
# ## Data Wrangling

# %%
#checking the datatype of all the features
parkingdata.dtypes
# Out:
# Area Name                                 object
# Street Name                               object
# Between Street 1                          object
# Between Street 2                          object
# Side Of Street                             int64
# Street Marker                             object
# Arrival Time                              object
# Departure Time                            object
# Duration of Parking Event (in seconds)     int64
# Sign                                      object
# In Violation?                              int64
# Street ID                                  int64
# Device ID                                  int64
# dtype: object

# %%
#Checking values of Area Name feature for typos
parkingdata['Area Name'].value_counts()
# Out:
# Queensberry        1251600
# Princes Theatre     904186
# Victoria Market     845505
# Regency             774955
# Southbank           772985
# The Mac             748260
# Hyatt               718992
# Titles              684197
# Rialto              544591
# City Square         527002
# County              518606
# Hardware            499803
# Chinatown           482723
# Courtney            473033
# Magistrates         456578
# Banks               446577
# Spencer             444369
# RACV                395147
# Jolimont            353732
# Supreme             235165
# Tavistock            64306
# Docklands            62753
# West Melbourne        3113
# Name: Area Name, dtype: int64

# %%
#Converting all the feature attributes to uppercase for uniformity

parkingdata['Area Name'] = parkingdata['Area Name'].str.upper()
parkingdata['Street Name'] = parkingdata['Street Name'].str.upper()
parkingdata['Between Street 1'] = parkingdata['Between Street 1'].str.upper()
parkingdata['Between Street 2'] = parkingdata['Between Street 2'].str.upper()
parkingdata['Street Marker'] = parkingdata['Street Marker'].str.upper()
parkingdata['Sign'] = parkingdata['Sign'].str.upper()

parkingdata.head(5)
# Out:
#          Area Name        Street Name  Between Street 1    Between Street 2  \
# 0            BANKS      MARKET STREET     FLINDERS LANE     FLINDERS STREET
# 1        CHINATOWN     RUSSELL STREET     BOURKE STREET   LT COLLINS STREET
# 2         COURTNEY   ELIZABETH STREET     PELHAM STREET  QUEENSBERRY STREET
# 3  PRINCES THEATRE  EXHIBITION STREET  LT BOURKE STREET       BOURKE STREET
# 4  PRINCES THEATRE  EXHIBITION STREET     BOURKE STREET   LT COLLINS STREET
#
#    Side Of Street Street Marker            Arrival Time  \
# 0               5         1263W  01/10/2011 12:01:10 AM
# 1               2          742E  01/10/2011 12:01:11 AM
# 2               2         4744E  01/10/2011 12:01:11 AM
# 3               2          452E  01/10/2011 12:01:13 AM
# 4               5          429W  01/10/2011 12:01:14 AM
#
#            Departure Time  Duration of Parking Event (in seconds)  \
# 0  01/10/2011 12:02:44 AM                                      94
# 1  01/10/2011 03:58:20 AM                                   14229
# 2  01/10/2011 11:00:19 AM                                   39548
# 3  01/10/2011 12:37:42 AM                                    2189
# 4  01/10/2011 05:28:10 AM                                   19616
#
#                          Sign  In Violation?  Street ID  Device ID
# 0     2P DIS M-SUN 0:00-23:59              0        957       1667
# 1       4P DIS AOT 12:00-7:30              0       1221        525
# 2     2P DIS M-SUN 0:00-23:59              1        627       3202
# 3     2P DIS M-SUN 0:00-23:59              0        647        201
# 4  TKT AREA M-SUN 0:00 - 7:30              0        647        176

# %%
# FAWKNER STREET           15485
# COVENTRY STREET          12842
# HOTHAM STREET            12091
# COBDEN STREET            11235
# FANNING STREET           11099
# ABBOTSFORD STREET        11063
# GREY STREET              10484
# RODEN STREET             10005
# MOORE STREET              9377
# MORRISON PLACE            8504
# LOTHIAN STREET            8168
# EADES PLACE               6783
# GEORGE STREET             6291
# WADEY STREET              4036
# CHETWYND STREET           2834
# MILLER STREET             2173
# SOUTHBANK BOULEVARD       1335
# CURZON STREET              574
# MUNSTER TERRACE            564
# DRYBURGH STREET            165
# Name: Between Street 2, dtype: int64

# %%
#check which columns have missing values
parkingdata.columns[parkingdata.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#converting object to datetime
parkingdata['Arrival Time'] = pd.to_datetime(parkingdata['Arrival Time'])
parkingdata['Departure Time'] = pd.to_datetime(parkingdata['Departure Time'])

# %%
#check if object has successfully been converted to datetime
parkingdata.dtypes
# Out:
# Area Name                                         object
# Street Name                                       object
# Between Street 1                                  object
# Between Street 2                                  object
# Side Of Street                                     int64
# Street Marker                                     object
# Arrival Time                              datetime64[ns]
# Departure Time                            datetime64[ns]
# Duration of Parking Event (in seconds)             int64
# Sign                                              object
# In Violation?                                      int64
# Street ID                                          int64
# Device ID                                          int64
# dtype: object

# %%
parkingdata.head(5)
# Out:
#          Area Name        Street Name  Between Street 1    Between Street 2  \
# 0            BANKS      MARKET STREET     FLINDERS LANE     FLINDERS STREET
# 1        CHINATOWN     RUSSELL STREET     BOURKE STREET   LT COLLINS STREET
# 2         COURTNEY   ELIZABETH STREET     PELHAM STREET  QUEENSBERRY STREET
# 3  PRINCES THEATRE  EXHIBITION STREET  LT BOURKE STREET       BOURKE STREET
# 4  PRINCES THEATRE  EXHIBITION STREET     BOURKE STREET   LT COLLINS STREET
#
#    Side Of Street Street Marker        Arrival Time      Departure Time  \
# 0               5         1263W 2011-01-10 00:01:10 2011-01-10 00:02:44
# 1               2          742E 2011-01-10 00:01:11 2011-01-10 03:58:20
# 2               2         4744E 2011-01-10 00:01:11 2011-01-10 11:00:19
# 3               2          452E 2011-01-10 00:01:13 2011-01-10 00:37:42
# 4               5          429W 2011-01-10 00:01:14 2011-01-10 05:28:10
#
#    Duration of Parking Event (in seconds)                        Sign  \
# 0                                      94     2P DIS M-SUN 0:00-23:59
# 1                                   14229       4P DIS AOT 12:00-7:30
# 2                                   39548     2P DIS M-SUN 0:00-23:59
# 3                                    2189     2P DIS M-SUN 0:00-23:59
# 4                                   19616  TKT AREA M-SUN 0:00 - 7:30
#
#    In Violation?  Street ID  Device ID
# 0              0        957       1667
# 1              0       1221        525
# 2              1        627       3202
# 3              0        647        201
# 4              0        647        176

# %%
parkingdata.tail(5)
# Out:
#                 Area Name      Street Name  Between Street 1  \
# 12208173        CHINATOWN   RUSSELL STREET  LT BOURKE STREET
# 12208174        CHINATOWN   RUSSELL STREET     BOURKE STREET
# 12208175      CITY SQUARE    FLINDERS LANE  ELIZABETH STREET
# 12208176      CITY SQUARE    FLINDERS LANE  ELIZABETH STREET
# 12208177  PRINCES THEATRE  LONSDALE STREET    RUSSELL STREET
#
#            Between Street 2  Side Of Street Street Marker        Arrival Time  \
# 12208173      BOURKE STREET               2          770E 2012-09-30 23:47:56
# 12208174  LT COLLINS STREET               5          765W 2012-09-30 23:48:34
# 12208175    SWANSTON STREET               4         1777S 2012-09-30 23:48:41
# 12208176    SWANSTON STREET               4         1775S 2012-09-30 23:49:43
# 12208177  EXHIBITION STREET               4         2843S 2012-09-30 23:52:29
#
#               Departure Time  Duration of Parking Event (in seconds)  \
# 12208173 2012-09-30 23:57:52                                     596
# 12208174 2012-09-30 23:50:02                                      88
# 12208175 2012-09-30 23:51:57                                     196
# 12208176 2012-09-30 23:52:54                                     191
# 12208177 2012-09-30 23:59:00                                     391
#
#                              Sign  In Violation?  Street ID  Device ID
# 12208173  2P DIS M-SUN 0:00-23:59              0       1221       7815
# 12208174  2P DIS M-SUN 0:00-23:59              0       1221        689
# 12208175  2P DIS M-SUN 0:00-23:59              0        669       6758
# 12208176  2P DIS M-SUN 0:00-23:59              0        669       1407
# 12208177    2P DIS AOT 0:00-23:59              0        894       6954

# %% [markdown]
# ## Data Visualisation

# %%
def add_value_labels(ax, spacing=5):
    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'

        # Use Y value as label and format number with one decimal place
        label = "{:.1f}".format(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va)                      # Vertically align label differently for
                                        # positive and negative values.

# %% [markdown]
# ### Most popular parking street in 4 hour interval

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 0) & (parkingdata['Arrival Time'].dt.hour <= 3)
between0and4 = parkingdata.loc[mask]
mostPopular = between0and4['Street Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#4EB0DB', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking streets between 12am and 4am')
ax.set_xlabel('Street Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 4) & (parkingdata['Arrival Time'].dt.hour <= 7)
between4and8 = parkingdata.loc[mask]
mostPopular = between4and8['Street Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#4EB0DB', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking streets between 4am and 8am')
ax.set_xlabel('Street Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 8) & (parkingdata['Arrival Time'].dt.hour <= 11)
between8and12 = parkingdata.loc[mask]
mostPopular = between8and12['Street Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#4EB0DB', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking streets between 8am and 12pm')
ax.set_xlabel('Street Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 12) & (parkingdata['Arrival Time'].dt.hour <= 15)
between12and16 = parkingdata.loc[mask]
mostPopular = between12and16['Street Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#4EB0DB', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking streets between 12pm and 4pm')
ax.set_xlabel('Street Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 16) & (parkingdata['Arrival Time'].dt.hour <= 19)
between16and20 = parkingdata.loc[mask]
mostPopular = between16and20['Street Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#4EB0DB', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking streets between 4pm and 8pm')
ax.set_xlabel('Street Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 20) & (parkingdata['Arrival Time'].dt.hour <= 23)
between20and00 = parkingdata.loc[mask]
mostPopular = between20and00['Street Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#4EB0DB', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking streets between 8pm and 12am')
ax.set_xlabel('Street Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %% [markdown]
# ### Most popular parking area in 4 hour interval

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 0) & (parkingdata['Arrival Time'].dt.hour <= 3)
between0and4 = parkingdata.loc[mask]
mostPopular = between0and4['Area Name'].value_counts(normalize=True)*100
ax = mostPopularSorted.T.plot(kind = 'bar', color='#35BE91', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking areas between 12am and 4am')
ax.set_xlabel('Area Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 4) & (parkingdata['Arrival Time'].dt.hour <= 7)
between4and8 = parkingdata.loc[mask]
mostPopular = between4and8['Area Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#35BE91', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking areas between 4am and 8am')
ax.set_xlabel('Area Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 8) & (parkingdata['Arrival Time'].dt.hour <= 11)
between8and12 = parkingdata.loc[mask]
mostPopular = between8and12['Area Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#35BE91', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking areas between 8am and 12pm')
ax.set_xlabel('Area Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 12) & (parkingdata['Arrival Time'].dt.hour <= 15)
between12and16 = parkingdata.loc[mask]
mostPopular = between12and16['Area Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#35BE91', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking areas between 12pm and 4pm')
ax.set_xlabel('Area Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 16) & (parkingdata['Arrival Time'].dt.hour <= 19)
between16and20 = parkingdata.loc[mask]
mostPopular = between16and20['Area Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar', color='#35BE91', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking areas between 4pm and 8pm')
ax.set_xlabel('Area Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %%
mask = (parkingdata['Arrival Time'].dt.hour >= 20) & (parkingdata['Arrival Time'].dt.hour <= 23)
between20and00 = parkingdata.loc[mask]
mostPopular = between20and00['Area Name'].value_counts(normalize=True)*100
mostPopularSorted = mostPopular.sort_values(ascending=False).head(10)
ax = mostPopularSorted.T.plot(kind = 'bar',color='#35BE91', figsize=(10,5))
ax.set_title('Figure: Showing the top 10 popular parking areas between 8pm and 12am')
ax.set_xlabel('Area Name')
ax.set_ylabel('Percentage of parking events')
add_value_labels(ax)

# %% [markdown]
# ### Frequency of violation by month (2011)

# %%
#Selecting only the rows which have infringement
onlyInfringe = parkingdata.loc[parkingdata['In Violation?'] == 1, :]
onlyInfringe.head(10)
# Out:
#           Area Name         Street Name  Between Street 1    Between Street 2  \
# 2          COURTNEY    ELIZABETH STREET     PELHAM STREET  QUEENSBERRY STREET
# 12             RACV       BOURKE STREET    WILLIAM STREET        QUEEN STREET
# 13        CHINATOWN    ELIZABETH STREET  LT BOURKE STREET       BOURKE STREET
# 19            HYATT       SPRING STREET     FLINDERS LANE     FLINDERS STREET
# 21          THE MAC    ELIZABETH STREET   LA TROBE STREET  LT LONSDALE STREET
# 24      MAGISTRATES  LT LONSDALE STREET    SPENCER STREET         KING STREET
# 26          THE MAC    A'BECKETT STREET  ELIZABETH STREET     SWANSTON STREET
# 27  PRINCES THEATRE       BOURKE STREET    RUSSELL STREET   EXHIBITION STREET
# 29           COUNTY     LONSDALE STREET       KING STREET      WILLIAM STREET
# 30      CITY SQUARE      RUSSELL STREET    COLLINS STREET       FLINDERS LANE
#
#     Side Of Street Street Marker        Arrival Time      Departure Time  \
# 2                2         4744E 2011-01-10 00:01:11 2011-01-10 11:00:19
# 12               4         2417S 2011-01-10 00:01:17 2011-01-10 07:24:42
# 13               2          946E 2011-01-10 00:01:18 2011-01-10 06:13:22
# 19               2            2E 2011-01-10 00:01:20 2011-01-10 23:59:00
# 21               2          972E 2011-01-10 00:01:21 2011-01-10 00:27:44
# 24               3         3578N 2011-01-10 00:01:22 2011-01-10 23:59:00
# 26               4         5975S 2011-01-10 00:01:23 2011-01-10 14:20:45
# 27               4         2381S 2011-01-10 00:01:24 2011-01-10 03:36:42
# 29               1         C3150 2011-01-10 00:01:24 2011-01-10 00:02:37
# 30               1          C650 2011-01-10 00:01:24 2011-01-10 00:03:07
#
#     Duration of Parking Event (in seconds)  \
# 2                                    39548
# 12                                   26605
# 13                                   22324
# 19                                   86260
# 21                                    1583
# 24                                   86258
# 26                                   51562
# 27                                   12918
# 29                                      73
# 30                                     103
#
#                                      Sign  In Violation?  Street ID  Device ID
# 2                 2P DIS M-SUN 0:00-23:59              1        627       3202
# 12                2P DIS M-SUN 0:00-23:59              1        123       1338
# 13   P/ (NO PARKING) AOT M-SUN 12:00-7:30              1        627        565
# 19                2P DIS M-SUN 0:00-23:59              1       1288          7
# 21                  1/4P M-SUN 0:00-23:59              1        627        596
# 24                      4P DIS ONLY M-SUN              1        926       1559
# 26                      4P DIS ONLY M-SUN              1          5       2455
# 27                   P10 M-SUN 0:00-23:59              1        123       1401
# 29  S/ NO STOP AUTH VEH M-SUN 00:00-23:59              1        894       2038
# 30               S/ NO STOP AOT 0:00-7:30              1       1221        479

# %%
#Separating the month number from the Departure Time column for further analysis
onlyInfringe['Month Number'] = onlyInfringe['Departure Time'].dt.month
onlyInfringe['Month Number'].value_counts()
# Out:
# C:\Users\drago\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 10    174741
# 3     141777
# 7     141400
# 12    141058
# 11    140358
# 6     138454
# 5     137793
# 8     137302
# 4     130557
# 9     129249
# 2     128250
# 1     127567
# Name: Month Number, dtype: int64

# %%
#Creating a histogram to show the frequency of infringement each month of the year 2011

plt.figure(figsize=(11,7))
_ = sns.distplot(onlyInfringe['Month Number'], kde = False, bins = 12, hist_kws = {"alpha": 1}, color = 'r')
_ = plt.title("Frequency of infringement for each month of 2011")

# %% [markdown]
# ### Categories of P Type Parking Violations

# %%
#Checking all the values of Sign feature
onlyInfringe['Sign'].value_counts()
# Out:
# 1P MTR M-SAT 7:30-19:30                   411584
# 1/2P MTR M-SAT 7:30-19:30                 133125
# 2P MTR M-SAT 7:30-20:30                    92177
# 1P SUN 7:30-18:30                          72707
# 1/2P M-SAT 7:30-19:30                      56923
# 1P TKT A M-SAT 7:30-19:30                  40724
# 1P TKT A M-F 7:30-18:30                    36831
# 2P SUN 7:30-18:30                          35392
# 2P TKT A M-SAT 7:30-20:30                  27352
# 32                                    8303
# 34                                    4143
#
#                                     Sign  In Violation?  Street ID  Device ID  \
# 2                2P DIS M-SUN 0:00-23:59              1        627       3202
# 12               2P DIS M-SUN 0:00-23:59              1        123       1338
# 13  P/ (NO PARKING) AOT M-SUN 12:00-7:30              1        627        565
# 19               2P DIS M-SUN 0:00-23:59              1       1288          7
# 21                 1/4P M-SUN 0:00-23:59              1        627        596
# 24                     4P DIS ONLY M-SUN              1        926       1559
# 26                     4P DIS ONLY M-SUN              1          5       2455
# 27                  P10 M-SUN 0:00-23:59              1        123       1401
# 32                1P AOT M-SAT 0:00-7:30              1        907       1294
# 34                  P10 M-SUN 0:00-23:59              1        669       1417
#
#     Month Number
# 2              1
# 12             1
# 13             1
# 19             1
# 21             1
# 24             1
# 26             1
# 27             1
# 32             1
# 34             1

# %%
#Checking values of the Sign column of the new dataframe
pSignInfringe['Sign'].value_counts()
# Out:
# 1P MTR M-SAT 7:30-19:30                  411584
# 1/2P MTR M-SAT 7:30-19:30                133125
# 2P MTR M-SAT 7:30-20:30                   92177
# 1P SUN 7:30-18:30                         72707
# 1/2P M-SAT 7:30-19:30                     56923
# 1P TKT A M-SAT 7:30-19:30                 40724
# 1P TKT A M-F 7:30-18:30                   36831
# 2P SUN 7:30-18:30                         35392
# 2P TKT A M-SAT 7:30-20:30                 27352
# 2P TKT A M-F 7:30-18:30                   26065
# 2P DIS M-SUN 0:00-23:59                   21594
# 1P TKT A RPA M-F 7:30-18:30               20828
# 4P MTR M-F 7:30-18:30                     17515
# 1P M-F 7:30-18:30                         14570
# 1P MTR M-SAT 7:30-18:30                   14456
# 1P MTR M-SAT 6:00-19:30                   14307
# 1/4P M-F 7:30-18:30                       13396
# 1/2P TKT A M-SAT 7:30-19:30               13036
# 1/4P M-SAT 7:30-19:30                     12364
# 1P MTR M-F 7:30-16:00                     12299
# 1P MTR M-F 7:30-18:30                     11881
# 2P MTR M-F 7:30-18:30                     10960
# P/ 5 M-SAT 7:30-19:30                     10620
# 1/2P RPA M-SUN 7:30-18:30                 10255
# 1/2P M-F 7:30-18:30                        9297
# 1P RPA M-F 7:30-18:30                      9127
# P10 M-SUN 0:00-23:59                       8710
# P/ 5 M-SUN 0:00-23:59                      8649
# 1P TKT A M-SAT 6:00-19:30                  8489
# 1P TKT A M-F 9:30-19:30                    8159
# 1P RPA M-SUN 7:30-23:00                    7699
# 1P A RPE M-F 7:30-18:30                    7495
# 1P MTR M-F 10:00-16:00                     7170
# 1/2P MTR M-F 9:30-16:00                    7067
# 2P MTR M-SAT 7:30-18:30                    6676
# 1/2P MTR M-F 7:30-16:30                    6581
# 2P MTR M-F 9:30-20:30                      6521
# 2P M-F 7:30-18:30                          6515
# 1P M-SAT 7:30-19:30                        6495
# 2P TKT A M-SAT 7:30-18:30                  6019
# 1/2P RPA M-F 7:30-18:30                    5836
# 2P MTR RPA M-F 7:30-18:30                  5749
# 1P MTR RPA M-SUN 7:30-23:00                5700
# 1P TKT A M-SAT 7:30-18:30                  5398
# 1P MTR M-F 9:30-19:30                      5099
# 2P DIS AOT 00:00-16:00                      151
# 1/2P DIS M-F 10:00-16:00                    122
# 1/2P DIS M-F 19:00-22:00                    110
# 1/4P M-F 18:30-19:30                        108
# 2P TKT A M-F 18:00-20:30                     91
# 2P M-F 20:30-23:00                           84
# 2P MTR M-F 16:30-20:30                       78
# P10 M-F 19:00-19:30                          77
# 4P DIS AOT 12:00-7:30                        76
# 2P DIS AOT 21:30-23:59                       74
# 4P DIS M-SUN 7:30-18:30                      71
# 4P DIS AOT 19:30-23:59                       67
# 2P M-SAT 20:30-23:00                         65
# 2P DIS SUN 7:30-18:30                        63
# 2P DIS M-SAT 7:30-18:30                      63
# P/ (NO PARKING) AOT SUN 18:30-23:59          56
# 1P DIS M-SUN 7:00-18:30                      52
# 4P DIS SUN 7:30-18:30                        52
# 2P DIS S-S 7:30-22:00                        50
# 2P DIS AOT 19:30-23:59                       49
# 1P MTR SAT 7:30-12:00                        45
# 2P DIS SAT 7:30-19:30                        39
# 2P DIS M-SAT 7:30-19:30                      34
# 2P DIS AOT 12:00-7:30                        25
# 2P DIS SAT 7:30-20:30                        17
# 2P RPA SAT 7:30-23:00                         6
# 1/4P SAT 7:30-12:00                           4
# 2P DIS SAT 7:30-12:30                         3
# 2P DIS 00:00-7.30                             2
# Name: Sign, dtype: int64

# %%
#Creating a new feature based on the parking type of each P based parking sign among Meter, Ticket or Others
pSignInfringe['Parking Type'] = pSignInfringe.Sign.apply(lambda x: "Meter" if 'MTR' in x else ("Ticket" if "TKT" in x else "Others"))
pSignInfringe.head(10)
# Out:
# C:\Users\drago\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Area Name         Street Name  Between Street 1    Between Street 2  \
# 2          COURTNEY    ELIZABETH STREET     PELHAM STREET  QUEENSBERRY STREET
# 12             RACV       BOURKE STREET    WILLIAM STREET        QUEEN STREET
# 13        CHINATOWN    ELIZABETH STREET  LT BOURKE STREET       BOURKE STREET
# 19            HYATT       SPRING STREET     FLINDERS LANE     FLINDERS STREET
# 21          THE MAC    ELIZABETH STREET   LA TROBE STREET  LT LONSDALE STREET
# 24      MAGISTRATES  LT LONSDALE STREET    SPENCER STREET         KING STREET
# 26          THE MAC    A'BECKETT STREET  ELIZABETH STREET     SWANSTON STREET
# 27  PRINCES THEATRE       BOURKE STREET    RUSSELL STREET   EXHIBITION STREET
# 32  PRINCES THEATRE    LT BOURKE STREET    RUSSELL STREET   EXHIBITION STREET
# 34      CITY SQUARE       FLINDERS LANE   SWANSTON STREET      RUSSELL STREET
#
#     Side Of Street Street Marker        Arrival Time      Departure Time  \
# 2                2         4744E 2011-01-10 00:01:11 2011-01-10 11:00:19
# 12               4         2417S 2011-01-10 00:01:17 2011-01-10 07:24:42
# 13               2          946E 2011-01-10 00:01:18 2011-01-10 06:13:22
# 19               2            2E 2011-01-10 00:01:20 2011-01-10 23:59:00
# 21               2          972E 2011-01-10 00:01:21 2011-01-10 00:27:44
# 24               3         3578N 2011-01-10 00:01:22 2011-01-10 23:59:00
# 26               4         5975S 2011-01-10 00:01:23 2011-01-10 14:20:45
# 27               4         2381S 2011-01-10 00:01:24 2011-01-10 03:36:42
# 32               4         2531S 2011-01-10 00:01:25 2011-01-10 02:19:48
# 34               4         1767S 2011-01-10 00:01:25 2011-01-10 01:10:28
#
#     Duration of Parking Event (in seconds)  \
# 2                                    39548
# 12                                   26605
# 13                                   22324
# 19                                   86260
# 21                                    1583
# 24                                   86258
# 26                                   51562
# 27                                   12918
# 32                                    8303
# 34                                    4143
#
#                                     Sign  In Violation?  Street ID  Device ID  \
# 2                2P DIS M-SUN 0:00-23:59              1        627       3202
# 12               2P DIS M-SUN 0:00-23:59              1        123       1338
# 13  P/ (NO PARKING) AOT M-SUN 12:00-7:30              1        627        565
# 19               2P DIS M-SUN 0:00-23:59              1       1288          7
# 21                 1/4P M-SUN 0:00-23:59              1        627        596
# 24                     4P DIS ONLY M-SUN              1        926       1559
# 26                     4P DIS ONLY M-SUN              1          5       2455
# 27                  P10 M-SUN 0:00-23:59              1        123       1401
# 32                1P AOT M-SAT 0:00-7:30              1        907       1294
# 34                  P10 M-SUN 0:00-23:59              1        669       1417
#
#     Month Number Parking Type
# 2              1       Others
# 12             1       Others
# 13             1       Others
# 19             1       Others
# 21             1       Others
# 24             1       Others
# 26             1       Others
# 27             1       Others
# 32             1       Others
# 34             1       Others

# %%
#Creating a pie chart based on which type of parking had more infringements

plt.figure(figsize=(10,8))
plt.pie(pSignInfringe['Parking Type'].value_counts(), labels = pSignInfringe['Parking Type'].unique(), colors = ('c', 'm', 'r'), startangle = 45, autopct = "%1.1f%%", explode = (0,0,0.08), textprops={'fontsize': 14})
plt.title("Percentage of infringement based on P based parking type")
plt.show()

# %% [markdown]
# ### Streets with the highest amount (Perecentage) of violiations in a  given time period (every 4 Hours)

# %%
mostInfring = parkingdata[parkingdata['In Violation?'] == 1]
mostInfring.head(10)
# Out:
#           Area Name         Street Name  Between Street 1    Between Street 2  \
# 2          COURTNEY    ELIZABETH STREET     PELHAM STREET  QUEENSBERRY STREET
# 12             RACV       BOURKE STREET    WILLIAM STREET        QUEEN STREET
# 13        CHINATOWN    ELIZABETH STREET  LT BOURKE STREET       BOURKE STREET
# 19            HYATT       SPRING STREET     FLINDERS LANE     FLINDERS STREET
# 21          THE MAC    ELIZABETH STREET   LA TROBE STREET  LT LONSDALE STREET
# 24      MAGISTRATES  LT LONSDALE STREET    SPENCER STREET         KING STREET
# 26          THE MAC    A'BECKETT STREET  ELIZABETH STREET     SWANSTON STREET
# 27  PRINCES THEATRE       BOURKE STREET    RUSSELL STREET   EXHIBITION STREET
# 29           COUNTY     LONSDALE STREET       KING STREET      WILLIAM STREET
# 30      CITY SQUARE      RUSSELL STREET    COLLINS STREET       FLINDERS LANE
#
#     Side Of Street Street Marker        Arrival Time      Departure Time  \
# 2                2         4744E 2011-01-10 00:01:11 2011-01-10 11:00:19
# 12               4         2417S 2011-01-10 00:01:17 2011-01-10 07:24:42
# 13               2          946E 2011-01-10 00:01:18 2011-01-10 06:13:22
# 19               2            2E 2011-01-10 00:01:20 2011-01-10 23:59:00
# 21               2          972E 2011-01-10 00:01:21 2011-01-10 00:27:44
# 24               3         3578N 2011-01-10 00:01:22 2011-01-10 23:59:00
# 26               4         5975S 2011-01-10 00:01:23 2011-01-10 14:20:45
# 27               4         2381S 2011-01-10 00:01:24 2011-01-10 03:36:42
# 29               1         C3150 2011-01-10 00:01:24 2011-01-10 00:02:37
# 30               1          C650 2011-01-10 00:01:24 2011-01-10 00:03:07
#
#     Duration of Parking Event (in seconds)  \
# 2                                    39548
# 12                                   26605
# 13                                   22324
# 19                                   86260
# 21                                    1583
# 24                                   86258
# 26                                   51562
# 27                                   12918
# 29                                      73
# 30                                     103
#
#                                      Sign  In Violation?  Street ID  Device ID
# 2                 2P DIS M-SUN 0:00-23:59              1        627       3202
# 12                2P DIS M-SUN 0:00-23:59              1        123       1338
# 13   P/ (NO PARKING) AOT M-SUN 12:00-7:30              1        627        565
# 19                2P DIS M-SUN 0:00-23:59              1       1288          7
# 21                  1/4P M-SUN 0:00-23:59              1        627        596
# 24                      4P DIS ONLY M-SUN              1        926       1559
# 26                      4P DIS ONLY M-SUN              1          5       2455
# 27                   P10 M-SUN 0:00-23:59              1        123       1401
# 29  S/ NO STOP AUTH VEH M-SUN 00:00-23:59              1        894       2038
# 30               S/ NO STOP AOT 0:00-7:30              1       1221        479

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 0) & (mostInfring['Arrival Time'].dt.hour <= 3)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Street Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 streets with the most violations between 12AM and 3:59AM')
visulization.set_xlabel('Street Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 4) & (mostInfring['Arrival Time'].dt.hour <= 7)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Street Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 streets with the most violations between 4AM and 7:59AM')
visulization.set_xlabel('Street Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 8) & (mostInfring['Arrival Time'].dt.hour <= 11)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Street Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 streets with the most violations between 8AM and 11:59AM')
visulization.set_xlabel('Street Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 12) & (mostInfring['Arrival Time'].dt.hour <= 15)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Street Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 streets with the most violations between 12PM and 3:59PM')
visulization.set_xlabel('Street Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 16) & (mostInfring['Arrival Time'].dt.hour <= 19)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Street Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 streets with the most violations between 4PM and 7:59PM')
visulization.set_xlabel('Street Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 20) & (mostInfring['Arrival Time'].dt.hour <= 20)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Street Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 streets with the most violations between 8PM and 11:59PM')
visulization.set_xlabel('Street Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %% [markdown]
# ### Areas with the highest amount (Perecentage) of violiations in a  given time period (every 4 Hours)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 0) & (mostInfring['Arrival Time'].dt.hour <= 3)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Area Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 areas with the most violations between 12AM and 3:59AM')
visulization.set_xlabel('Area Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 4) & (mostInfring['Arrival Time'].dt.hour <= 7)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Area Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 areas with the most violations between 4AM and 7:59AM')
visulization.set_xlabel('Area Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 8) & (mostInfring['Arrival Time'].dt.hour <= 11)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Area Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 areas with the most violations between 8AM and 11:59AM')
visulization.set_xlabel('Area Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 12) & (mostInfring['Arrival Time'].dt.hour <= 15)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Area Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 areas with the most violations between 12PM and 3:59PM')
visulization.set_xlabel('Area Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 16) & (mostInfring['Arrival Time'].dt.hour <= 19)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Area Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 areas with the most violations between 4PM and 7:59PM')
visulization.set_xlabel('Area Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %%
mask = (mostInfring['Arrival Time'].dt.hour >= 20) & (mostInfring['Arrival Time'].dt.hour <= 23)
timeRange = mostInfring.loc[mask]
mostInfringed = timeRange['Area Name'].value_counts(normalize = True)*100
mostInfringedSorted = mostInfringed.sort_values(ascending = False).head(10)

visulization = mostInfringedSorted.T.plot(kind = 'bar')
visulization.set_title('Top 10 areas with the most violations between 8PM and :59PM')
visulization.set_xlabel('Area Name')
visulization.set_ylabel('Percentage of violations in time frame')
add_value_labels(visulization)

# %% [markdown]
# ## What is the busiest hour for each area

# %%
Bhour = parkingdata
Bhour['Arrival Time'] = pd.DatetimeIndex(Bhour['Arrival Time'])
Bhour.set_index(keys='Arrival Time', inplace=True)

# %%
start = datetime.time(0,0,0)
end = datetime.time(3,59,59)
Bhour0 = Bhour.between_time(start,end)
Bhour0
# Out:
#                            Area Name        Street Name  Between Street 1  \
# Arrival Time
# 2011-01-10 00:01:10            BANKS      MARKET STREET     FLINDERS LANE
# 2011-01-10 00:01:11        CHINATOWN     RUSSELL STREET     BOURKE STREET
# 2011-01-10 00:01:11         COURTNEY   ELIZABETH STREET     PELHAM STREET
# 2011-01-10 00:01:13  PRINCES THEATRE  EXHIBITION STREET  LT BOURKE STREET
# 2011-01-10 00:01:14  PRINCES THEATRE  EXHIBITION STREET     BOURKE STREET
# ...                              ...                ...               ...
# 2012-09-30 03:47:43      CITY SQUARE     COLLINS STREET   SWANSTON STREET
# 2012-09-30 03:49:41          SPENCER      FLINDERS LANE    SPENCER STREET
# 2012-09-30 03:52:03        CHINATOWN  LT COLLINS STREET  ELIZABETH STREET
# 2012-09-30 03:58:02      CITY SQUARE      FLINDERS LANE  ELIZABETH STREET
# 2012-09-30 03:58:56        CHINATOWN     RUSSELL STREET  LT BOURKE STREET
#
#                        Between Street 2  Side Of Street Street Marker  \
# Arrival Time
# 2011-01-10 00:01:10     FLINDERS STREET               5         1263W
# 2011-01-10 00:01:11   LT COLLINS STREET               2          742E
# 2011-01-10 00:01:11  QUEENSBERRY STREET               2         4744E
# 2011-01-10 00:01:13       BOURKE STREET               2          452E
# 2011-01-10 00:01:14   LT COLLINS STREET               5          429W
# ...                                 ...             ...           ...
# 2012-09-30 03:47:43      RUSSELL STREET               3         1950N
# 2012-09-30 03:49:41         KING STREET               3         1864N
# 2012-09-30 03:52:03     SWANSTON STREET               4         2197S
# 2012-09-30 03:58:02     SWANSTON STREET               4         1773S
# 2012-09-30 03:58:56       BOURKE STREET               2          770E
#
#                          Departure Time  \
# Arrival Time
# 2011-01-10 00:01:10 2011-01-10 00:02:44
# 2011-01-10 00:01:11 2011-01-10 03:58:20
# 2011-01-10 00:01:11 2011-01-10 11:00:19
# 2011-01-10 00:01:13 2011-01-10 00:37:42
# 2011-01-10 00:01:14 2011-01-10 05:28:10
# ...                                 ...
# 2012-09-30 03:47:43 2012-09-30 04:11:25
# 2012-09-30 03:49:41 2012-09-30 06:11:31
# 2012-09-30 03:52:03 2012-09-30 03:55:18
# 2012-09-30 03:58:02 2012-09-30 03:59:58
# 2012-09-30 03:58:56 2012-09-30 04:00:39
#
#                      Duration of Parking Event (in seconds)  \
# Arrival Time
# 2011-01-10 00:01:10                                      94
# 2011-01-10 00:01:11                                   14229
# 2011-01-10 00:01:11                                   39548
# 2011-01-10 00:01:13                                    2189
# 2011-01-10 00:01:14                                   19616
# ...                                                     ...
# 2012-09-30 03:47:43                                    1422
# 2012-09-30 03:49:41                                    8510
# 2012-09-30 03:52:03                                     195
# 2012-09-30 03:58:02                                     116
# 2012-09-30 03:58:56                                     103
#
#                                                   Sign  In Violation?  \
# Arrival Time
# 2011-01-10 00:01:10            2P DIS M-SUN 0:00-23:59              0
# 2011-01-10 00:01:11              4P DIS AOT 12:00-7:30              0
# 2011-01-10 00:01:11            2P DIS M-SUN 0:00-23:59              1
# 2011-01-10 00:01:13            2P DIS M-SUN 0:00-23:59              0
# 2011-01-10 00:01:14         TKT AREA M-SUN 0:00 - 7:30              0
# ...                                                ...            ...
# 2012-09-30 03:47:43  P/(NO PARKING) M-SUN 0:00 - 23:59              1
# 2012-09-30 03:49:41            2P DIS M-SUN 0:00-23:59              1
# 2012-09-30 03:52:03            2P DIS M-SUN 0:00-23:59              0
# 2012-09-30 03:58:02            2P DIS M-SUN 0:00-23:59              0
# 2012-09-30 03:58:56            2P DIS M-SUN 0:00-23:59              0
#
#                      Street ID  Device ID
# Arrival Time
# 2011-01-10 00:01:10        957       1667
# 2011-01-10 00:01:11       1221        525
# 2011-01-10 00:01:11        627       3202
# 2011-01-10 00:01:13        647        201
# 2011-01-10 00:01:14        647        176
# ...                        ...        ...
# 2012-09-30 03:47:43        528       5361
# 2012-09-30 03:49:41        669       7834
# 2012-09-30 03:52:03        911       5063
# 2012-09-30 03:58:02        669       5053
# 2012-09-30 03:58:56       1221       7815
#
# [51214 rows x 12 columns]

# %%
bplot = Bhour0['Area Name'].value_counts()
bplot.plot(kind = 'bar')
plt.title('Figure 1: Where people are parking between midnight and 4am ')
plt.xlabel('Street Marker')
plt.ylabel('Number of parking events')
plt.show()

# %%
start = datetime.time(4,0,0)
end = datetime.time(7,59,59)
Bhour1 = Bhour.between_time(start,end)
Bhour1
# Out:
#                            Area Name       Street Name    Between Street 1  \
# Arrival Time
# ...                                       ...            ...        ...
# 2012-09-30 07:59:19         1P SUN 7:30-18:30              0        123
# 2012-09-30 07:59:38   2P DIS M-SUN 0:00-23:59              0       1288
# 2012-09-30 07:59:39         1P SUN 7:30-18:30              0        123
# 2012-09-30 07:59:40         1P SUN 7:30-18:30              0        528
# 2012-09-30 07:59:40         2P SUN 6:00-18:30              0       1171
#
#                      Device ID
# Arrival Time
# 2011-01-10 04:02:31       1294
# 2011-01-10 04:02:34        479
# 2011-01-10 04:02:47       2440
# 2011-01-10 04:03:16        872
# 2011-01-10 04:05:23       1826
# ...                        ...
# 2012-09-30 07:59:19       7706
# 2012-09-30 07:59:38       6073
# 2012-09-30 07:59:39       1561
# 2012-09-30 07:59:40       1183
# 2012-09-30 07:59:40       2997
#
# [806626 rows x 12 columns]

# %%
bplot = Bhour1['Area Name'].value_counts()
bplot.plot(kind = 'bar')
plt.title('Figure 2: Where people are parking between 4am and 8am ')
plt.xlabel('Street Marker')
plt.ylabel('Number of parking events')
plt.show()

# %%
start = datetime.time(8,0,0)
end = datetime.time(11,59,59)
Bhour2 = Bhour.between_time(start,end)
Bhour2
# Out:
#                            Area Name        Street Name   Between Street 1  \
# Arrival Time
# 2011-01-10 08:00:04          THE MAC    LA TROBE STREET   ELIZABETH STREET
# 2011-01-10 08:00:06            BANKS       QUEEN STREET    FLINDERS STREET
# 2011-01-10 08:00:07           TITLES       QUEEN STREET    LA TROBE STREET
# 2011-01-10 08:00:08  VICTORIA MARKET    FRANKLIN STREET     WILLIAM STREET
# 2011-01-10 08:00:16          SPENCER     SPENCER STREET      BOURKE STREET
# ...                              ...                ...                ...
# 2012-09-30 11:59:52          THE MAC    LA TROBE STREET   ELIZABETH STREET
# 2012-09-30 11:59:53  VICTORIA MARKET    FRANKLIN STREET      WILLAM STREET
# 2012-09-30 11:59:56            HYATT  LT COLLINS STREET  EXHIBITION STREET
# 2012-09-30 11:59:58           TITLES   A'BECKETT STREET       QUEEN STREET
# 2012-09-30 11:59:59         JOLIMONT    CATHEDRAL PLACE    GISBORNE STREET
#
#                        Between Street 2  Side Of Street Street Marker  \
# Arrival Time
# 2011-01-10 08:00:04     SWANSTON STREET               3         3768N
# 2011-01-10 08:00:06       FLINDERS LANE               1         C1046
# 2011-01-10 08:00:07  LT LONSDALE STREET               1         C1260
# 2011-01-10 08:00:08        QUEEN STREET               1         C6946
# 2011-01-10 08:00:16   LT COLLINS STREET               2         1526E
# ...                                 ...             ...           ...
# 2012-09-30 11:59:52     SWANSTON STREET               4         3755S
# 2012-09-30 11:59:53        QUEEN STREET               1         C6932
# 2012-09-30 11:59:56       SPRING STREET               4         2153S
# 2012-09-30 11:59:58    ELIZABETH STREET               3         5994N
# 2012-09-30 11:59:59    LANSDOWNE STREET               3        12422N
#
#                          Departure Time  \
# Arrival Time
# 2011-01-10 08:00:04 2011-01-10 08:01:15
# 2011-01-10 08:00:06 2011-01-10 08:56:22
# 2011-01-10 08:00:07 2011-01-10 08:16:45
# 2011-01-10 08:00:08 2011-01-10 08:02:10
# 2011-01-10 08:00:16 2011-01-10 08:17:40
# ...                                 ...
# 2012-09-30 11:59:52 2012-09-30 15:45:02
# 2012-09-30 11:59:53 2012-09-30 13:32:07
# 2012-09-30 11:59:56 2012-09-30 12:43:54
# 2012-09-30 11:59:58 2012-09-30 14:22:48
# 2012-09-30 11:59:59 2012-09-30 15:21:27
#
#                      Duration of Parking Event (in seconds)  \
# Arrival Time
# 2011-01-10 08:00:04                                      71
# 2011-01-10 08:00:06                                    3376
# 2011-01-10 08:00:07                                     998
# 2011-01-10 08:00:08                                     122
# 2011-01-10 08:00:16                                    1044
# ...                                                     ...
# 2012-09-30 11:59:52                                   13510
# 2012-09-30 11:59:53                                    5534
# 2012-09-30 11:59:56                                    2638
# 2012-09-30 11:59:58                                    8570
# 2012-09-30 11:59:59                                   12088
#
#                                           Sign  In Violation?  Street ID  \
# Arrival Time
# 2011-01-10 08:00:04  1/2P TKT A SAT 7:30-19:30              0        856
# 2011-01-10 08:00:06    1P MTR M-SAT 7:30-19:30              0       1171
# 2011-01-10 08:00:07    1P MTR M-SAT 7:30-19:30              0       1171
# 2011-01-10 08:00:08    2P MTR M-SAT 7:30-20:30              0        681
# 2011-01-10 08:00:16      2P MTR SAT 7:30-20:30              0       1285
# ...                                        ...            ...        ...
# 2012-09-30 11:59:52          1P SUN 7:30-18:30              1        856
# 2012-09-30 11:59:53          2P SUN 7:30-18:30              0        681
# 2012-09-30 11:59:56          1P SUN 7:30-18:30              0        911
# 2012-09-30 11:59:58          2P SUN 7:30-18:30              1          5
# 2012-09-30 11:59:59          2P SUN 7:30-18:00              1        178
#
#                      Device ID
# Arrival Time
# 2011-01-10 08:00:04       1512
# 2011-01-10 08:00:06        629
# 2011-01-10 08:00:07        734
# 2011-01-10 08:00:08       2935
# 2011-01-10 08:00:16        768
# ...                        ...
# 2012-09-30 11:59:52       6138
# 2012-09-30 11:59:53       6897
# 2012-09-30 11:59:56       5005
# 2012-09-30 11:59:58       2374
# 2012-09-30 11:59:59       6261
#
# [3991022 rows x 12 columns]

# %%
bplot = Bhour2['Area Name'].value_counts()
bplot.plot(kind = 'bar')
plt.title('Figure 3: Where people are parking between 8am and 12pm ')
plt.xlabel('Street Marker')
plt.ylabel('Number of parking events')
plt.show()

# %%
start = datetime.time(12,0,0)
end = datetime.time(15,59,59)
Bhour3 = Bhour.between_time(start,end)
Bhour3
# Out:
#                        Area Name        Street Name   Between Street 1  \
# Arrival Time
# 2011-01-10 12:00:00        HYATT      FLINDERS LANE  EXHIBITION STREET
# 2011-01-10 12:00:01      SUPREME    LONSDALE STREET     WILLIAM STREET
# 2011-01-10 12:00:06       TITLES    LA TROBE STREET       QUEEN STREET
# 2011-01-10 12:00:07      SPENCER     COLLINS STREET     SPENCER STREET
# 2011-01-10 12:00:11        HYATT     COLLINS STREET  EXHIBITION STREET
# ...                          ...                ...                ...
# 2012-09-30 15:59:51     COURTNEY   O'CONNELL STREET      COBDEN STREET
# 2012-09-30 15:59:52        HYATT  EXHIBITION STREET     COLLINS STREET
# 2011-01-10 16:00:04                                     119
# ...                                                     ...
# 2012-09-30 19:51:33                                    5611
# 2012-09-30 19:54:01                                     331
# 2012-09-30 19:54:55                                     111
# 2012-09-30 19:56:34                                     218
# 2012-09-30 19:59:10                                    1377
#
#                                                      Sign  In Violation?  \
# Arrival Time
# 2011-01-10 16:00:00  PERMIT ZONE AUTH VEH SAT 16:00-23:59              0
# 2011-01-10 16:00:00  PERMIT ZONE AUTH VEH SAT 16:00-23:59              0
# 2011-01-10 16:00:00  PERMIT ZONE AUTH VEH SAT 16:00-23:59              0
# 2011-01-10 16:00:02                  P10 M-SAT 7:30-19:30              1
# 2011-01-10 16:00:04                  P10 M-SUN 0:00-23:59              0
# ...                                                   ...            ...
# 2012-09-30 19:51:33                 1P AOT SUN 0:00-23:59              1
# 2012-09-30 19:54:01                 2P DIS AOT 0:00-23:59              0
# 2012-09-30 19:54:55                2P DIS AOT 00:00-23:59              0
# 2012-09-30 19:56:34                 1P RPE SUN 7:30-23:00              0
# 2012-09-30 19:59:10                 1P RPE SUN 7:30-23:00              0
#
#                      Street ID  Device ID
# Arrival Time
# 2011-01-10 16:00:00       1171       2949
# 2011-01-10 16:00:00       1171       3034
# 2011-01-10 16:00:00       1171       3116
# 2011-01-10 16:00:02        681       2904
# 2011-01-10 16:00:04        669       1432
# ...                        ...        ...
# 2012-09-30 19:51:33        907       7173
# 2012-09-30 19:54:01       1428       7289
# 2012-09-30 19:54:55        856       5716
# 2012-09-30 19:56:34        818       5982
# 2012-09-30 19:59:10        818       6001
#
# [3022988 rows x 12 columns]

# %%
bplot = Bhour4['Area Name'].value_counts()
bplot.plot(kind = 'bar')
plt.title('Figure 5: Where people are parking between 4pm and 8pm ')
plt.xlabel('Street Marker')
plt.ylabel('Number of parking events')
plt.show()

# %%
start = datetime.time(20,0,0)
end = datetime.time(23,59,59)
Bhour5 = Bhour.between_time(start,end)
Bhour5
# Out:
#                            Area Name        Street Name  Between Street 1  \
# Arrival Time
# 2011-01-10 20:00:12           RIALTO      CHURCH STREET     BOURKE STREET
# 2011-01-10 20:00:16          REGENCY  EXHIBITION STREET   LA TROBE STREET
# 2011-01-10 20:00:26           RIALTO        KING STREET     BOURKE STREET
# 2011-01-10 20:00:33          THE MAC    FRANKLIN STREET   SWANSTON STREET
# 2011-01-10 20:00:37           TITLES    LA TROBE STREET      QUEEN STREET
# ...                              ...                ...               ...
# 2012-09-30 23:47:56        CHINATOWN     RUSSELL STREET  LT BOURKE STREET
# 2012-09-30 23:48:34        CHINATOWN     RUSSELL STREET     BOURKE STREET
# 2012-09-30 23:48:41      CITY SQUARE      FLINDERS LANE  ELIZABETH STREET
# 2012-09-30 23:49:43      CITY SQUARE      FLINDERS LANE  ELIZABETH STREET
# 2012-09-30 23:52:29  PRINCES THEATRE    LONSDALE STREET    RUSSELL STREET
#
#                        Between Street 2  Side Of Street Street Marker  \
# Arrival Time
# 2011-01-10 20:00:12   LT COLLINS STREET               5         2259W
# 2011-01-10 20:00:16  LT LONSDALE STREET               2          618E
# 2011-01-10 20:00:26   LT COLLINS STREET               2         1452E
# 2011-01-10 20:00:33     VICTORIA STREET               1         C6450
# 2011-01-10 20:00:37    ELIZABETH STREET               4         3793S
# ...                                 ...             ...           ...
# 2012-09-30 23:47:56       BOURKE STREET               2          770E
# 2012-09-30 23:48:34   LT COLLINS STREET               5          765W
# 2012-09-30 23:48:41     SWANSTON STREET               4         1777S
# 2012-09-30 23:49:43     SWANSTON STREET               4         1775S
# 2012-09-30 23:52:29   EXHIBITION STREET               4         2843S
#
#                          Departure Time  \
# Arrival Time
# 2011-01-10 20:00:12 2011-01-10 20:16:11
# 2011-01-10 20:00:16 2011-01-10 20:30:00
# 2011-01-10 20:00:26 2011-01-10 20:01:32
# 2011-01-10 20:00:33 2011-01-10 20:30:00
# 2011-01-10 20:00:37 2011-01-10 20:04:33
# ...                                 ...
# 2012-09-30 23:47:56 2012-09-30 23:57:52
# 2012-09-30 23:48:34 2012-09-30 23:50:02
# 2012-09-30 23:48:41 2012-09-30 23:51:57
# 2012-09-30 23:49:43 2012-09-30 23:52:54
# 2012-09-30 23:52:29 2012-09-30 23:59:00
#
#                      Duration of Parking Event (in seconds)  \
# Arrival Time
# 2011-01-10 20:00:12                                     959
# 2011-01-10 20:00:16                                    1784
# 2011-01-10 20:00:26                                      66
# 2011-01-10 20:00:33                                    1767
# 2011-01-10 20:00:37                                     236
# ...                                                     ...
# 2012-09-30 23:47:56                                     596
# 2012-09-30 23:48:34                                      88
# 2012-09-30 23:48:41                                     196
# 2012-09-30 23:49:43                                     191
# 2012-09-30 23:52:29                                     391
#
#                                                 Sign  In Violation?  \
# Arrival Time
# 2011-01-10 20:00:12          P MTR M-SAT 19:30-20:30              0
# 2011-01-10 20:00:16            2P MTR SAT 7:30-20:30              0
# 2011-01-10 20:00:26  S/ NO STOP AOT BUSES 0:00-23:59              1
# 2011-01-10 20:00:33          2P MTR M-SAT 7:30-20:30              0
# 2011-01-10 20:00:37        P TKT A M-SAT 19:30-20:30              0
# ...                                              ...            ...
# 2012-09-30 23:47:56          2P DIS M-SUN 0:00-23:59              0
# 2012-09-30 23:48:34          2P DIS M-SUN 0:00-23:59              0
# 2012-09-30 23:48:41          2P DIS M-SUN 0:00-23:59              0
# 2012-09-30 23:49:43          2P DIS M-SUN 0:00-23:59              0
# 2012-09-30 23:52:29            2P DIS AOT 0:00-23:59              0
#
#                      Street ID  Device ID
# Arrival Time
# 2011-01-10 20:00:12        200       1691
# 2011-01-10 20:00:16        647        186
# 2011-01-10 20:00:26        839        886
# 2011-01-10 20:00:33        681       2815
# 2011-01-10 20:00:37        856       2190
# ...                        ...        ...
# 2012-09-30 23:47:56       1221       7815
# 2012-09-30 23:48:34       1221        689
# 2012-09-30 23:48:41        669       6758
# 2012-09-30 23:49:43        669       1407
# 2012-09-30 23:52:29        894       6954
#
# [186260 rows x 12 columns]

# %%
bplot = Bhour5['Area Name'].value_counts()
bplot.plot(kind = 'bar')
plt.title('Figure 6: Where people are parking between 8pm and midnight ')
plt.xlabel('Street Marker')
plt.ylabel('Number of parking events')
plt.show()
